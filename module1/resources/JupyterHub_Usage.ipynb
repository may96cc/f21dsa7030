# %% [markdown]
# # JupyterHub Usage Instructions
#
# **Important Note:** Changing the name of a notebook will _un-link_ it from your daily Schedule.ipynb for the course.

# %% [markdown]
# JupterHub allows interactive code execution.  The active cell is bordered, as show below.
#
# ![screen](../images/JH_Running_cells_1.png)
#
# ## <span style="">You try: Click in the cell below and then click the `run cell` button (shown above)

# %%
print("Hello JupyterHub")

# %% [markdown]
# ** Note:** The `In[ ]` changed to have a number present. Then the output was rendered below.

# %% [markdown]
# ![screen](../images/JH_Running_cells_2.png)
#
# ## <span style="">You try: Click in the cell below and then simultaneously press [SHIFT] + [ENTER].

# %%
print("Hello JupyterHub, SHIFT + ENTER run me!")

# %% [markdown]
# # Take the time to take a tour of JupyterHub
#
# From the Help menu, select User Interface Tour
#
# ![screen](../images/JH_UI_Tour.png)

# %% [markdown]
# # Keyboard Shortcuts are available as well
#
# ![screen](../images/JH_Keyboard_Shortcuts.png)

# %% [markdown]
# # Important Keyboard shortcuts
# ## 1. To insert one code cell above the current cell  press [ESC] + [a]
# ## 2. To insert one code cell below the current cell  press [ESC] + [b]
# ## 3. To delete the current code cell press [ESC] + [x]

# %% [markdown]
# # You try:

# %%
#insert one code cell above this cell by pressing [ESC]+[a]

# %%
#insert once code cell below this cell by pressing [ESC]+[b]

# %%
#delete this cell by pressing [ESC]+[x]

# %% [markdown]
# # Opening a Terminal for Git commands
#
# ![terminal](../images/JH_Terminal_Launch.png)

# %% [markdown]
# # Getting help within Jupyter
# ## If you'd like to know what are all the methods availiable for a particular library just press [tab] after the library name(or it's alias in the example shown below) followed by the dot.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## You can get the syntax along with examples of a method of a particular library simply pressing  [SHIFT] + [tab] by moving the cursor inside the braces() of that method as shown:
# ![image.png](attachment:image.png)
