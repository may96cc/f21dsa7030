# %% [markdown]
# # Basic Statistics Practice
#
# Please remember to use the `EXPLAIN` before you execute a query to help avoid unnecessary load on the DBMS and indefinite waits by you for results.
#
# Therefore, for each question, we are providing a cell for the `EXPLAIN` as well as the final SQL.
#
#
# ## Our practice schema:
#
# A PDF of the _Entity-Relationship Diagrams_ (ERD) is available [here](https://web.dsa.missouri.edu/static/PDF/DVD_Rental_ERD2.pdf).
# Printing it out is recommended.

# %%
# %load_ext sql
# %sql postgres://dsa_ro_user:readonly@pgsql.dsa.lan/dvdrental
# Out:
# 'Connected: dsa_ro_user@dvdrental'

# %%
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 0 rows affected.
# []

# %% [markdown]
# # 1
#
# ### List the average length of the movies (film.length) in the database.

# %%
# %%sql
# EXPLAIN
# SELECT AVG(length)
# FROM film ;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 2 rows affected.
# [('Aggregate  (cost=66.50..66.51 rows=1 width=32)',),
#  ('  ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=2)',)]

# %%
# %%sql
# SELECT AVG(length)
# FROM film ;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 1 rows affected.
# [(Decimal('115.2720000000000000'),)]

# %% [markdown]
# [Helpful Hints](https://youtu.be/yMrP0cr_rqo)
#
#
# ---
#
# # 2
#
# ### List the number of rows in the payment table.

# %%
# %%sql
# EXPLAIN
# SELECT count(*)
# FROM payment  ;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 2 rows affected.
# [('Aggregate  (cost=290.45..290.46 rows=1 width=8)',),
#  ('  ->  Seq Scan on payment  (cost=0.00..253.96 rows=14596 width=0)',)]

# %%
# %%sql
# SELECT count(*)
# FROM payment ;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 1 rows affected.
# [(14596,)]

# %% [markdown]
# # 3
#
# ### List each category (`category.name`) and the number of films in that category.

# %%
# %%sql
# EXPLAIN
# SELECT name, count(*)
# FROM category
# INNER JOIN film_category
# ON category.category_id = film_category.category_id
# GROUP BY name ;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 7 rows affected.
# [('HashAggregate  (cost=25.67..25.83 rows=16 width=76)',),
#  ('  Group Key: category.name',),
#  ('  ->  Hash Join  (cost=1.36..20.67 rows=1000 width=68)',),
#  ('        Hash Cond: (film_category.category_id = category.category_id)',),
#  ('        ->  Seq Scan on film_category  (cost=0.00..16.00 rows=1000 width=2)',),
#  ('        ->  Hash  (cost=1.16..1.16 rows=16 width=72)',),
#  ('              ->  Seq Scan on category  (cost=0.00..1.16 rows=16 width=72)',)]

# %%
# %%sql
# SELECT name, count(*)
# FROM category
# INNER JOIN film_category
# ON category.category_id = film_category.category_id
# GROUP BY name ;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 16 rows affected.
# [('Family', 69),
#  ('Games', 61),
#  ('Animation', 66),
#  ('Classics', 57),
#  ('Documentary', 68),
#  ('New', 63),
#  ('Sports', 74),
#  ('Children', 60),
#  ('Music', 51),
#  ('Travel', 57),
#  ('Foreign', 73),
#  ('Drama', 62),
#  ('Horror', 56),
#  ('Action', 64),
#  ('Sci-Fi', 61),
#  ('Comedy', 58)]

# %% [markdown]
# [Helpful Hints](https://youtu.be/YRMI8myh9WY)
#
#
# ---
#
# # 4
#
# ### List each film title and the number of actors in that film.

# %%
# %%sql
# EXPLAIN
# SELECT title, count(*)
# FROM film JOIN film_actor
# ON film.film_id = film_actor.film_id
# GROUP BY title   ;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 7 rows affected.
# [('HashAggregate  (cost=202.82..212.82 rows=1000 width=23)',),
#  ('  Group Key: film.title',),
#  ('  ->  Hash Join  (cost=76.50..175.51 rows=5462 width=15)',),
#  ('        Hash Cond: (film_actor.film_id = film.film_id)',),
#  ('        ->  Seq Scan on film_actor  (cost=0.00..84.62 rows=5462 width=2)',),
#  ('        ->  Hash  (cost=64.00..64.00 rows=1000 width=19)',),
#  ('              ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=19)',)]

# %%
# %%sql
# SELECT title, count(*)
# FROM film JOIN film_actor
# ON film.film_id = film_actor.film_id
# GROUP BY title ;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 997 rows affected.
# [('Graceland Dynamite', 6),
#  ('Opus Ice', 4),
#  ('Braveheart Human', 4),
#  ('Wonderful Drop', 4),
#  ('Rush Goodfellas', 5),
#  ('Purple Movie', 8),
#  ('Minority Kiss', 1),
#  ('Luke Mummy', 9),
#  ('Fantasy Troopers', 9),
#  ('Grinch Massage', 6),
#  ('Gaslight Crusade', 5),
#  ('Microcosmos Paradise', 6),
#  ('Saturn Name', 2),
#  ('Memento Zoolander', 6),
#  ('Sunset Racer', 3),
#  ('Zoolander Fiction', 5),
#  ('Carol Texas', 7),
#  ('Stepmom Dream', 4),
#  ('Minds Truman', 6),
#  ('Gump Date', 6),
#  ('Arabia Dogma', 12),
#  ('Baked Cleopatra', 1),
#  ('Closer Bang', 6),
#  ('Enough Raging', 9),
#  ('Grosse Wonderful', 4),
#  ('Innocent Usual', 3),
#  ('Sleepless Monsoon', 4),
#  ('Suit Walls', 5),
#  ('Wizard Coldblooded', 9),
#  ('Lonely Elephant', 12),
#  ('Victory Academy', 5),
#  ('Bedazzled Married', 7),
#  ('Tadpole Park', 8),
#  ('Maker Gables', 11),
#  ('Private Drop', 5),
#  ('Worker Tarzan', 9),
#  ('Gosford Donnie', 3),
#  ('Annie Identity', 3),
#  ('Drop Waterfront', 8),
#  ('Lesson Cleopatra', 12),
#  ('Wanda Chamber', 7),
#  ('Dwarfs Alter', 1),
#  ('Garden Island', 3),
#  ('Graduate Lord', 2),
#  ('Patriot Roman', 4),
#  ('Novocaine Flight', 6),
#  ('Necklace Outbreak', 8),
#  ('Menagerie Rushmore', 2),
#  ('Sleeping Suspects', 4),
#  ('Uncut Suicides', 7),
#  ('Midnight Westward', 9),
#  ('Rock Instinct', 8),
#  ('Jersey Sassy', 9),
#  ('Magnificent Chitty', 7),
#  ('Clones Pinocchio', 5),
#  ('Insects Stone', 4),
#  ('Giant Troopers', 1),
#  ('Loser Hustler', 5),
#  ('Heavyweights Beast', 5),
#  ('Boondock Ballroom', 13),
#  ('Entrapment Satisfaction', 4),
#  ('Firehouse Vietnam', 5),
#  ('Core Suit', 4),
#  ('Butch Panther', 3),
#  ('Cyclone Family', 3),
#  ('Cabin Flash', 4),
#  ('Jaws Harry', 5),
#  ('Fellowship Autumn', 7),
#  ('Bowfinger Gables', 5),
#  ('Birdcage Casper', 4),
#  ('Forever Candidate', 1),
#  ('Dangerous Uptown', 8),
#  ('Guys Falcon', 5),
#  ('Warlock Werewolf', 6),
#  ('None Spiking', 6),
#  ('Bringing Hysterical', 2),
#  ('Haunting Pianist', 5),
#  ('Agent Truman', 7),
#  ('Motions Details', 8),
#  ('Tenenbaums Command', 5),
#  ('Secrets Paradise', 6),
#  ('Tarzan Videotape', 3),
#  ('Double Wrath', 8),
#  ('Greatest North', 6),
#  ('Birch Antitrust', 6),
#  ('Sense Greek', 7),
#  ('Walls Artist', 5),
#  ('Invasion Cyclone', 7),
#  ('Secretary Rouge', 6),
#  ('Congeniality Quest', 3),
#  ('Daughter Madigan', 4),
#  ('Crossroads Casualties', 8),
#  ('Canyon Stock', 6),
#  ('Reef Salute', 4),
#  ('French Holiday', 7),
#  ('Rugrats Shakespeare', 6),
#  ('Highball Potter', 5),
#  ('Papi Necklace', 3),
#  ('Translation Summer', 3),
#  ('Peak Forever', 5),
#  ('Tycoon Gathering', 6),
#  ('Loverboy Attacks', 9),
#  ('Earring Instinct', 5),
#  ('Ship Wonderland', 8),
#  ('Rouge Squad', 4),
#  ('Clue Grail', 6),
#  ('Wonderland Christmas', 5),
#  ('Finding Anaconda', 5),
#  ('Thin Sagebrush', 2),
#  ('Nash Chocolat', 7),
#  ('Wrath Mile', 4),
#  ('Harold French', 7),
#  ('Forrest Sons', 5),
#  ('Pure Runner', 2),
#  ('Witches Panic', 4),
#  ('Turn Star', 3),
#  ('Anthem Luke', 2),
#  ('Duffel Apocalypse', 3),
#  ('Shrek License', 3),
#  ('Heaven Freedom', 10),
#  ('Impossible Prejudice', 3),
#  ('Peach Innocent', 5),
#  ('Dazed Punk', 6),
#  ('Frisco Forrest', 9),
#  ('Reds Pocus', 5),
#  ('Music Boondock', 3),
#  ('Chisum Behavior', 4),
#  ('Volcano Texas', 5),
#  ('Daisy Menagerie', 7),
#  ('Lost Bird', 3),
#  ('Caribbean Liberty', 8),
#  ('Conversation Downhill', 3),
#  ('Lambs Cincinatti', 15),
#  ('Escape Metropolis', 4),
#  ('Dumbo Lust', 9),
#  ('Pizza Jumanji', 5),
#  ('Hills Neighbors', 6),
#  ('Truman Crazy', 6),
#  ('Chance Resurrection', 6),
#  ('Candidate Perdition', 4),
#  ('Spiking Element', 6),
#  ('Fight Jawbreaker', 3),
#  ('Apache Divine', 4),
#  ('Shining Roses', 5),
#  ('Ishtar Rocketeer', 4),
#  ('Flying Hook', 8),
#  ('Desperate Trainspotting', 4),
#  ('Greedy Roots', 8),
#  ('Forrester Comancheros', 3),
#  ('Dirty Ace', 5),
#  ('Trading Pinocchio', 3),
#  ('Graffiti Love', 6),
#  ('Paths Control', 5),
#  ('Amelie Hellfighters', 6),
#  ('Pickup Driving', 5),
#  ('Panic Club', 3),
#  ('Crazy Home', 13),
#  ('Forward Temple', 3),
#  ('Vertigo Northwest', 4),
#  ('Jericho Mulan', 4),
#  ('Gunfighter Mussolini', 4),
#  ('Bilko Anonymous', 3),
#  ('Blade Polish', 5),
#  ('Spice Sorority', 11),
#  ('Massage Image', 9),
#  ('Home Pity', 6),
#  ('Boulevard Mob', 8),
#  ('Dalmations Sweden', 6),
#  ('Hunter Alter', 4),
#  ('Zorro Ark', 3),
#  ('Silence Kane', 4),
#  ('Taxi Kick', 6),
#  ('Resurrection Silverado', 5),
#  ('Suspects Quills', 8),
#  ('Dracula Crystal', 13),
#  ('Harper Dying', 4),
#  ('Simon North', 3),
#  ('Vacation Boondock', 6),
#  ('Chitty Lock', 13),
#  ('Ballroom Mockingbird', 7),
#  ('Legally Secretary', 6),
#  ('Gladiator Westward', 6),
#  ('Barefoot Manchurian', 8),
#  ('Cruelty Unforgiven', 2),
#  ('Smoking Barbarella', 6),
#  ('Soldiers Evolution', 9),
#  ('Robbers Joon', 5),
#  ('Telemark Heartbreakers', 11),
#  ('Westward Seabiscuit', 6),
#  ('Notorious Reunion', 2),
#  ('Million Ace', 5),
#  ('Ali Forever', 5),
#  ('Coneheads Smoochy', 9),
#  ('Suicides Silence', 3),
#  ('Bird Independence', 2),
#  ('Intrigue Worst', 7),
#  ('Mask Peach', 11),
#  ('Scissorhands Slums', 5),
#  ('Boiled Dares', 8),
#  ('Majestic Floats', 5),
#  ('Past Suicides', 6),
#  ('Masked Bubble', 3),
#  ('Bull Shawshank', 8),
#  ('Gunfight Moon', 4),
#  ('Sagebrush Clueless', 7),
#  ('Reap Unfaithful', 4),
#  ('Lock Rear', 2),
#  ('Beethoven Exorcist', 6),
#  ('Vietnam Smoochy', 2),
#  ('Breaking Home', 6),
#  ('Runaway Tenenbaums', 3),
#  ('Head Stranger', 2),
#  ('Quest Mussolini', 5),
#  ('Ace Goldfinger', 4),
#  ('Dancing Fever', 6),
#  ('Image Princess', 11),
#  ('Fool Mockingbird', 2),
#  ('Panther Reds', 5),
#  ('Holocaust Highball', 5),
#  ('Bright Encounters', 4),
#  ('Adaptation Holes', 5),
#  ('Deceiver Betrayed', 4),
#  ('Antitrust Tomatoes', 7),
#  ('Fatal Haunted', 6),
#  ('Sons Interview', 6),
#  ('Yentl Idaho', 1),
#  ('Modern Dorado', 5),
#  ('Rage Games', 7),
#  ('Monsoon Cause', 5),
#  ('Uprising Uptown', 5),
#  ('Jason Trap', 5),
#  ('Sweet Brotherhood', 6),
#  ('Crusade Honey', 9),
#  ('Arachnophobia Rollercoaster', 8),
#  ('Stallion Sundance', 7),
#  ('Crossing Divorce', 2),
#  ('Creatures Shakespeare', 3),
#  ('Easy Gladiator', 3),
#  ('Snatchers Montezuma', 9),
#  ('Shock Cabin', 1),
#  ('Island Exorcist', 3),
#  ('Seattle Expecations', 6),
#  ('Liberty Magnificent', 7),
#  ('Gun Bonnie', 5),
#  ('Alabama Devil', 9),
#  ('Train Bunch', 4),
#  ('Identity Lover', 4),
#  ('Clyde Theory', 4),
#  ('Troopers Metal', 5),
#  ('Primary Glass', 7),
#  ('Frankenstein Stranger', 2),
#  ('Excitement Eve', 8),
#  ('Affair Prejudice', 5),
#  ('Impact Aladdin', 3),
#  ('Fury Murder', 4),
#  ('Deep Crusade', 7),
#  ('Sierra Divide', 5),
#  ('Dinosaur Secretary', 6),
#  ('Kill Brotherhood', 5),
#  ('Muppet Mile', 8),
#  ('Mosquito Armageddon', 4),
#  ('Freedom Cleopatra', 5),
#  ('Jungle Closer', 6),
#  ('Indian Love', 10),
#  ('Glass Dying', 4),
#  ('Born Spinal', 9),
#  ('Life Twisted', 8),
#  ('Massacre Usual', 3),
#  ('Kissing Dolls', 3),
#  ('Greek Everyone', 4),
#  ('Meet Chocolate', 6),
#  ('Dorado Notting', 4),
#  ('Titans Jerk', 7),
#  ('Hanging Deep', 7),
#  ('Streetcar Intentions', 7),
#  ('Hardly Robbers', 3),
#  ('War Notting', 9),
#  ('Diary Panic', 4),
#  ('Instinct Airport', 11),
#  ('Bikini Borrowers', 2),
#  ('Rebel Airport', 6),
#  ('Flamingos Connecticut', 9),
#  ('Cincinatti Whisperer', 4),
#  ('Trainspotting Strangers', 4),
#  ('Pelican Comforts', 5),
#  ('Madre Gables', 4),
#  ('Lord Arizona', 6),
#  ('Feathers Metal', 9),
#  ('Hook Chariots', 4),
#  ('Groove Fiction', 7),
#  ('Window Side', 4),
#  ('Silverado Goldfinger', 5),
#  ('Mannequin Worst', 5),
#  ('Willow Tracy', 2),
#  ('Hocus Frida', 3),
#  ('Natural Stock', 4),
#  ('Karate Moon', 8),
#  ('Roses Treasure', 5),
#  ('Racer Egg', 6),
#  ('Jawbreaker Brooklyn', 5),
#  ('Alice Fantasia', 4),
#  ('Mixed Doors', 6),
#  ('Potter Connecticut', 7),
#  ('Order Betrayed', 7),
#  ('Mighty Luck', 8),
#  ('Sabrina Midnight', 4),
#  ('Roxanne Rebel', 5),
#  ('Fidelity Devil', 4),
#  ('Madness Attacks', 7),
#  ('Mussolini Spoilers', 7),
#  ('Star Operation', 5),
#  ('Vanilla Day', 2),
#  ('Bunch Minds', 8),
#  ('Sweethearts Suspects', 5),
#  ('Lola Agent', 6),
#  ('Won Dares', 5),
#  ('Reunion Witches', 7),
#  ('Unfaithful Kill', 8),
#  ('Encino Elf', 6),
#  ('Hustler Party', 4),
#  ('Rollercoaster Bringing', 3),
#  ('Spirit Flintstones', 11),
#  ('Details Packer', 2),
#  ('Pianist Outfield', 5),
#  ('Luck Opus', 6),
#  ('Butterfly Chocolat', 7),
#  ('Mallrats United', 5),
#  ('Queen Luke', 6),
#  ('Desire Alien', 7),
#  ('Glory Tracy', 6),
#  ('Bound Cheaper', 2),
#  ('Academy Dinosaur', 10),
#  ('Igby Maker', 5),
#  ('Gentlemen Stage', 8),
#  ('Pollock Deliverance', 6),
#  ('Sleuth Orient', 7),
#  ('Freddy Storm', 3),
#  ('Odds Boogie', 5),
#  ('Prejudice Oleander', 10),
#  ('Cowboy Doom', 5),
#  ('Valentine Vanishing', 2),
#  ('Show Lord', 2),
#  ('Confidential Interview', 2),
#  ('Armageddon Lost', 7),
#  ('Edge Kissing', 3),
#  ('Grail Frankenstein', 5),
#  ('Half Outfield', 6),
#  ('Love Suicides', 4),
#  ('Seven Swarm', 7),
#  ('Oscar Gold', 6),
#  ('Lies Treatment', 7),
#  ('Chocolat Harry', 5),
#  ('Wind Phantom', 3),
#  ('Casablanca Super', 4),
#  ('Random Go', 13),
#  ('Newsies Story', 8),
#  ('Knock Warlock', 6),
#  ('Leathernecks Dwarfs', 7),
#  ('Joon Northwest', 2),
#  ('Pajama Jawbreaker', 5),
#  ('Stage World', 2),
#  ('American Circus', 5),
#  ('Rear Trading', 8),
#  ('Siege Madre', 7),
#  ('Angels Life', 9),
#  ('Crooked Frogmen', 6),
#  ('Jingle Sagebrush', 2),
#  ('Tramp Others', 6),
#  ('Artist Coldblooded', 7),
#  ('Beverly Outlaw', 4),
#  ('Doom Dancing', 8),
#  ('Mine Titans', 2),
#  ('Hunting Musketeers', 5),
#  ('Rings Heartbreakers', 11),
#  ('Lights Deer', 2),
#  ('Mars Roman', 7),
#  ('Champion Flatliners', 4),
#  ('Temple Attraction', 5),
#  ('Roman Punk', 2),
#  ('Dragon Squad', 8),
#  ('Moulin Wake', 3),
#  ('Fiction Christmas', 8),
#  ('Princess Giant', 5),
#  ('Empire Malkovich', 9),
#  ('Fish Opus', 2),
#  ('Tequila Past', 3),
#  ('Rocketeer Mother', 7),
#  ('Theory Mermaid', 6),
#  ('Divine Resurrection', 5),
#  ('Manchurian Curtain', 2),
#  ('Casper Dragonfly', 5),
#  ('Mulan Moon', 5),
#  ('Newton Labyrinth', 4),
#  ('Bubble Grosse', 3),
#  ('Lebowski Soldiers', 3),
#  ('Berets Agent', 10),
#  ('Searchers Wait', 4),
#  ('South Wait', 2),
#  ('Uptown Young', 7),
#  ('Center Dinosaur', 4),
#  ('Spartacus Cheaper', 3),
#  ('Wedding Apollo', 10),
#  ('Dawn Pond', 6),
#  ('Perfect Groove', 6),
#  ('Ties Hunger', 6),
#  ('Satisfaction Confidential', 5),
#  ('Speed Suit', 6),
#  ('Halloween Nuts', 7),
#  ('Vision Torque', 5),
#  ('Blackout Private', 5),
#  ('Iron Moon', 8),
#  ('Bonnie Holocaust', 9),
#  ('Coma Head', 3),
#  ('Disciple Mother', 7),
#  ('Vanishing Rocky', 5),
#  ('Floats Garden', 5),
#  ('Paris Weekend', 6),
#  ('Bill Others', 6),
#  ('Expendable Stallion', 4),
#  ('Mob Duffel', 6),
#  ('Patton Interview', 9),
#  ('Club Graffiti', 4),
#  ('Alien Center', 6),
#  ('Jade Bunch', 8),
#  ('Network Peak', 3),
#  ('Name Detective', 3),
#  ('Outfield Massacre', 4),
#  ('Watership Frontier', 6),
#  ('Trojan Tomorrow', 8),
#  ('Apocalypse Flamingos', 5),
#  ('Cat Coneheads', 4),
#  ('Varsity Trip', 3),
#  ('Strangelove Desire', 9),
#  ('Egypt Tenenbaums', 5),
#  ('Pirates Roxanne', 1),
#  ('Divorce Shining', 6),
#  ('Vampire Whale', 5),
#  ('Oz Liaisons', 11),
#  ('Ghostbusters Elf', 1),
#  ('Traffic Hobbit', 4),
#  ('Whale Bikini', 5),
#  ('Nuts Ties', 2),
#  ('Moonwalker Fool', 7),
#  ('Cheaper Clyde', 2),
#  ('Watch Tracy', 5),
#  ('Lust Lock', 7),
#  ('Citizen Shrek', 8),
#  ('Command Darling', 8),
#  ('Heartbreakers Bright', 5),
#  ('Patient Sister', 4),
#  ('Outbreak Divine', 5),
#  ('Bed Highball', 5),
#  ('Requiem Tycoon', 8),
#  ('National Story', 7),
#  ('Jeepers Wedding', 6),
#  ('Frida Slipper', 5),
#  ('Mourning Purple', 7),
#  ('Language Cowboy', 6),
#  ('Doors President', 9),
#  ('Barbarella Streetcar', 5),
#  ('Hoosiers Birdcage', 10),
#  ('Blindness Gun', 3),
#  ('Maltese Hope', 1),
#  ('Chamber Italian', 7),
#  ('Moon Bunch', 1),
#  ('Tomatoes Hellfighters', 9),
#  ('Army Flintstones', 7),
#  ('Wonka Sea', 2),
#  ('Hedwig Alter', 4),
#  ('Honey Ties', 5),
#  ('Hurricane Affair', 3),
#  ('Nightmare Chill', 2),
#  ('Matrix Snowman', 3),
#  ('Shootist Superfly', 3),
#  ('Hanky October', 3),
#  ('Orient Closer', 4),
#  ('Lawrence Love', 2),
#  ('Usual Untouchables', 5),
#  ('Squad Fish', 5),
#  ('Shakespeare Saddle', 6),
#  ('Shepherd Midsummer', 5),
#  ('Wisdom Worker', 7),
#  ('African Egg', 5),
#  ('Family Sweet', 9),
#  ('Wait Cider', 9),
#  ('October Submarine', 5),
#  ('World Leathernecks', 8),
#  ('Encounters Curtain', 4),
#  ('California Birds', 2),
#  ('Apollo Teen', 8),
#  ('Brooklyn Desert', 5),
#  ('Dream Pickup', 4),
#  ('Phantom Glory', 2),
#  ('Arizona Bang', 4),
#  ('Midsummer Groundhog', 2),
#  ('Alaska Phantom', 7),
#  ('Stampede Disturbing', 6),
#  ('Attraction Newton', 4),
#  ('Earth Vision', 3),
#  ('Telegraph Voyage', 7),
#  ('Clueless Bucket', 8),
#  ('King Evolution', 6),
#  ('Hall Cassidy', 5),
#  ('Slums Duck', 3),
#  ('Desert Poseidon', 5),
#  ('Bride Intrigue', 1),
#  ('Wardrobe Phantom', 8),
#  ('Gangs Pride', 4),
#  ('Games Bowfinger', 8),
#  ('Sensibility Rear', 6),
#  ('Pluto Oleander', 7),
#  ('Homicide Peach', 8),
#  ('Kick Savannah', 6),
#  ('Darko Dorado', 4),
#  ('Ladybugs Armageddon', 4),
#  ('Lion Uncut', 3),
#  ('Creepers Kane', 6),
#  ('Superfly Trip', 7),
#  ('Song Hedwig', 5),
#  ('President Bang', 5),
#  ('Loathing Legally', 5),
#  ('Northwest Polish', 8),
#  ('Gilmore Boiled', 6),
#  ('Tracy Cider', 3),
#  ('Doctor Grail', 6),
#  ('Wars Pluto', 4),
#  ('Jumanji Blade', 6),
#  ('Noon Papi', 6),
#  ('Bang Kwai', 7),
#  ('Disturbing Scarface', 4),
#  ('Robbery Bright', 2),
#  ('Vanished Garden', 2),
#  ('Dolls Rage', 1),
#  ('Borrowers Bedazzled', 7),
#  ('Crystal Breaking', 5),
#  ('Tootsie Pilot', 5),
#  ('Spy Mile', 8),
#  ('Operation Operation', 3),
#  ('Destiny Saturday', 7),
#  ('Homeward Cider', 7),
#  ('Galaxy Sweethearts', 3),
#  ('Sorority Queen', 4),
#  ('Groundhog Uncut', 7),
#  ('Santa Paris', 6),
#  ('Pittsburgh Hunchback', 5),
#  ('Hyde Doctor', 6),
#  ('Open African', 9),
#  ('Jacket Frisco', 10),
#  ('Untouchables Sunrise', 5),
#  ('Sugar Wonka', 5),
#  ('Videotape Arsenic', 5),
#  ('English Bulworth', 5),
#  ('Chill Luck', 5),
#  ('Packer Madigan', 1),
#  ('Metropolis Coma', 6),
#  ('Chainsaw Uptown', 2),
#  ('Autumn Crow', 3),
#  ('Roots Remember', 10),
#  ('Divide Monster', 6),
#  ('Frost Head', 7),
#  ('Saints Bride', 10),
#  ('Lucky Flying', 10),
#  ('Caddyshack Jedi', 7),
#  ('Airport Pollock', 4),
#  ('Raiders Antitrust', 6),
#  ('Express Lonely', 8),
#  ('Date Speed', 4),
#  ('Happiness United', 5),
#  ('Thief Pelican', 7),
#  ('Moonshine Cabin', 5),
#  ('Submarine Bed', 11),
#  ('Clerks Angels', 4),
#  ('Unforgiven Zoolander', 7),
#  ('Amadeus Holy', 6),
#  ('Musketeers Wait', 1),
#  ('Malkovich Pet', 7),
#  ('Heavenly Gun', 6),
#  ('Chaplin License', 6),
#  ('Anything Savannah', 3),
#  ('Elizabeth Shane', 3),
#  ('Outlaw Hanky', 7),
#  ('Blues Instinct', 4),
#  ('Maiden Home', 8),
#  ('Torque Bound', 5),
#  ('Airplane Sierra', 5),
#  ('Weekend Personal', 10),
#  ('Werewolf Lola', 7),
#  ('Bucket Brotherhood', 6),
#  ('Hellfighters Sierra', 12),
#  ('Bear Graceland', 3),
#  ('School Jacket', 8),
#  ('Strangers Graffiti', 5),
#  ('Zhivago Core', 6),
#  ('Inch Jet', 5),
#  ('Driver Annie', 8),
#  ('Tourist Pelican', 3),
#  ('Beneath Rush', 7),
#  ('Goodfellas Salute', 8),
#  ('Conquerer Nuts', 6),
#  ('Polish Brooklyn', 10),
#  ('Elf Murder', 5),
#  ('Japanese Run', 9),
#  ('Stagecoach Armageddon', 6),
#  ('Ark Ridgemont', 3),
#  ('Hanover Galaxy', 7),
#  ('Italian African', 2),
#  ('Rainbow Shock', 6),
#  ('Amistad Midsummer', 4),
#  ('League Hellfighters', 6),
#  ('Fever Empire', 3),
#  ('Trip Newton', 4),
#  ('Reign Gentlemen', 3),
#  ('Perdition Fargo', 5),
#  ('Flatliners Killer', 9),
#  ('Villain Desperate', 2),
#  ('Spinal Rocky', 8),
#  ('Early Home', 6),
#  ('Clockwork Paradise', 5),
#  ('Jet Neighbors', 6),
#  ('Breakfast Goldfinger', 5),
#  ('Sunrise League', 5),
#  ('Paradise Sabrina', 4),
#  ('Speakeasy Date', 3),
#  ('Wash Heavenly', 5),
#  ('Tights Dawn', 5),
#  ('Backlash Undefeated', 7),
#  ('Sea Virgin', 8),
#  ('Legend Jedi', 4),
#  ('Control Anthem', 3),
#  ('Cider Desire', 5),
#  ('Prix Undefeated', 7),
#  ('Behavior Runaway', 5),
#  ('Downhill Enough', 4),
#  ('Dances None', 5),
#  ('Fargo Gandhi', 5),
#  ('Volume House', 5),
#  ('Gandhi Kwai', 8),
#  ('Kentuckian Giant', 4),
#  ('Fiddler Lost', 11),
#  ('Rules Human', 5),
#  ('Super Wyoming', 3),
#  ('Aladdin Calendar', 8),
#  ('Exorcist Sting', 5),
#  ('Magic Mallrats', 4),
#  ('Harry Idaho', 6),
#  ('Basic Easy', 6),
#  ('Orange Grapes', 5),
#  ('Contact Anonymous', 5),
#  ('Cassidy Wyoming', 7),
#  ('Kane Exorcist', 5),
#  ('Sweden Shining', 5),
#  ('Mission Zoolander', 5),
#  ('Model Fish', 8),
#  ('Alone Trip', 8),
#  ('Youth Kick', 5),
#  ('Town Ark', 4),
#  ('Darling Breaking', 2),
#  ('Crow Grease', 10),
#  ('Sun Confessions', 5),
#  ('Day Unfaithful', 5),
#  ('Pilot Hoosiers', 7),
#  ('Psycho Shrunk', 1),
#  ('Philadelphia Wife', 2),
#  ('Wife Turn', 6),
#  ('Holes Brannigan', 11),
#  ('Valley Packer', 4),
#  ('Coldblooded Darling', 4),
#  ('Horror Reign', 5),
#  ('Color Philadelphia', 7),
#  ('Banger Pinocchio', 6),
#  ('Streak Ridgemont', 3),
#  ('Steel Santa', 3),
#  ('Teen Apollo', 5),
#  ('Bulworth Commandments', 4),
#  ('Neighbors Charade', 7),
#  ('Trap Guys', 7),
#  ('Boogie Amelie', 6),
#  ('Grit Clockwork', 3),
#  ('Haunted Antitrust', 5),
#  ('Eagles Panky', 6),
#  ('Shane Darkness', 3),
#  ('Stone Fire', 1),
#  ('Effect Gladiator', 7),
#  ('Young Language', 5),
#  ('Candles Grapes', 7),
#  ('Darn Forrester', 9),
#  ('Hotel Happiness', 4),
#  ('Chinatown Gladiator', 10),
#  ('Splendor Patton', 10),
#  ('Alamo Videotape', 4),
#  ('Hunger Roof', 1),
#  ('Independence Hotel', 9),
#  ('Arsenic Independence', 3),
#  ('Hysterical Grail', 9),
#  ('Mermaid Insects', 6),
#  ('Brannigan Sunrise', 2),
#  ('Unbreakable Karate', 8),
#  ('High Encino', 7),
#  ('Hamlet Wisdom', 5),
#  ('Lose Inch', 4),
#  ('Devil Desire', 5),
#  ('Everyone Craft', 5),
#  ('Hunchback Impossible', 2),
#  ('Virtual Spoilers', 3),
#  ('Run Pacific', 6),
#  ('Connecticut Tramp', 7),
#  ('Ice Crossing', 6),
#  ('Daddy Pittsburgh', 5),
#  ('Betrayed Rear', 4),
#  ('Factory Dragon', 6),
#  ('Analyze Hoosiers', 5),
#  ('Working Microcosmos', 5),
#  ('Flintstones Happiness', 4),
#  ('Mod Secretary', 6),
#  ('Ferris Mother', 1),
#  ('Fire Wolves', 5),
#  ('Lawless Vision', 4),
#  ('Splash Gump', 10),
#  ('Comancheros Enemy', 5),
#  ('Jumping Wrath', 8),
#  ('Shawshank Bubble', 10),
#  ('Voice Peach', 3),
#  ('Waterfront Deliverance', 6),
#  ('Personal Ladybugs', 9),
#  ('Wrong Behavior', 9),
#  ('Cause Date', 6),
#  ('Bugsy Song', 2),
#  ('Montezuma Command', 2),
#  ('Curtain Videotape', 3),
#  ('Worst Banger', 4),
#  ('Holiday Games', 6),
#  ('Fireball Philadelphia', 5),
#  ('Eve Resurrection', 6),
#  ('Gables Metropolis', 8),
#  ('Talented Homicide', 5),
#  ('Words Hunter', 6),
#  ('Records Zorro', 8),
#  ('Element Freddy', 4),
#  ('Spirited Casualties', 5),
#  ('Egg Igby', 5),
#  ('Seabiscuit Punk', 3),
#  ('Magnolia Forrester', 7),
#  ('Cupboard Sinners', 8),
#  ('Tuxedo Mile', 3),
#  ('Beach Heartbreakers', 7),
#  ('Human Graffiti', 4),
#  ('Louisiana Harry', 3),
#  ('Donnie Alley', 7),
#  ('Something Duck', 3),
#  ('Pity Bound', 5),
#  ('Evolution Alter', 6),
#  ('Hope Tootsie', 4),
#  ('Treatment Jekyll', 5),
#  ('Flash Wars', 7),
#  ('Crowds Telemark', 4),
#  ('Pocus Pulp', 5),
#  ('Voyage Legally', 5),
#  ('Trouble Date', 8),
#  ('Sky Miracle', 12),
#  ('Alley Evolution', 5),
#  ('Hollywood Anonymous', 6),
#  ('Coast Rainbow', 10),
#  ('Mummy Creatures', 13),
#  ('Room Roman', 2),
#  ('Dozen Lion', 6),
#  ('Casualties Encino', 5),
#  ('Frontier Cabin', 6),
#  ('Velvet Terminator', 9),
#  ('Money Harold', 7),
#  ('Sling Luke', 3),
#  ('Pacific Amistad', 8),
#  ('Eyes Driving', 5),
#  ('Wasteland Divine', 6),
#  ('Dares Pluto', 10),
#  ('Gleaming Jawbreaker', 8),
#  ('Fantasia Park', 3),
#  ('Saturday Lambs', 9),
#  ('Beast Hunchback', 5),
#  ('Commandments Express', 4),
#  ('Roof Champion', 5),
#  ('Kramer Chocolate', 8),
#  ('Pinocchio Simon', 11),
#  ('Catch Amistad', 5),
#  ('Wolves Desire', 6),
#  ('Wyoming Storm', 6),
#  ('Maguire Apache', 4),
#  ('Carrie Bunch', 7),
#  ('Jeopardy Encino', 5),
#  ('Labyrinth League', 6),
#  ('Juggler Hardly', 9),
#  ('Brotherhood Blanket', 5),
#  ('Poseidon Forever', 6),
#  ('Texas Watch', 6),
#  ('Women Dorado', 5),
#  ('Strictly Scarface', 4),
#  ('Charade Duffel', 3),
#  ('Summer Scarface', 8),
#  ('Lolita World', 1),
#  ('Mile Mulan', 3),
#  ('Rocky War', 3),
#  ('Cleopatra Devil', 7),
#  ('Kiss Glory', 7),
#  ('Pride Alamo', 4),
#  ('Jedi Beneath', 4),
#  ('Ridgemont Submarine', 5),
#  ('Chariots Conspiracy', 2),
#  ('Redemption Comforts', 5),
#  ('Informer Double', 3),
#  ('Scarface Bang', 7),
#  ('Titanic Boondock', 12),
#  ('Interview Liaisons', 5),
#  ('Smoochy Control', 2),
#  ('Steers Armageddon', 4),
#  ('Runner Madigan', 8),
#  ('Range Moonwalker', 4),
#  ('Remember Diary', 4),
#  ('Wild Apollo', 4),
#  ('Go Purple', 3),
#  ('Jekyll Frogmen', 3),
#  ('Opposite Necklace', 6),
#  ('Pet Haunting', 7),
#  ('Scalawag Duck', 5),
#  ('Enemy Odds', 4),
#  ('Camelot Vacation', 2),
#  ('Illusion Amelie', 7),
#  ('Chocolate Duck', 7),
#  ('Bingo Talented', 5),
#  ('Twisted Pirates', 3),
#  ('Gold River', 2),
#  ('Miracle Virtual', 1),
#  ('Dude Blindness', 7),
#  ('Undefeated Dalmations', 3),
#  ('Kwai Homeward', 5),
#  ('Insider Arizona', 9),
#  ('Campus Remember', 3),
#  ('Jerk Paycheck', 8),
#  ('Baby Hall', 8),
#  ('Killer Innocent', 5),
#  ('Sassy Packer', 3),
#  ('Sleepy Japanese', 6),
#  ('Blanket Beverly', 4),
#  ('Treasure Command', 7),
#  ('Platoon Instinct', 5),
#  ('Chicken Hellfighters', 2),
#  ('Pulp Beverly', 7),
#  ('Quills Bull', 4),
#  ('Shrunk Divine', 4),
#  ('Dragonfly Strangers', 3),
#  ('Lady Stage', 8),
#  ('Virgin Daisy', 8),
#  ('Argonauts Town', 5),
#  ('Gorgeous Bingo', 7),
#  ('Storm Happiness', 8),
#  ('Stock Glass', 7),
#  ('Sinners Atlantis', 4),
#  ('Monterey Labyrinth', 6),
#  ('Hours Rage', 6),
#  ('Driving Polish', 7),
#  ('Grease Youth', 3),
#  ('West Lion', 9),
#  ('Ghost Groundhog', 5),
#  ('Snatch Slipper', 3),
#  ('Horn Working', 8),
#  ('Lovely Jingle', 6),
#  ('Hawk Chill', 7),
#  ('Terminator Club', 2),
#  ('Rushmore Mermaid', 7),
#  ('Deer Virginian', 3),
#  ('Alter Victory', 4),
#  ('Darkness War', 2),
#  ('Falcon Volume', 4),
#  ('Mother Oleander', 5),
#  ('Shanghai Tycoon', 8),
#  ('Attacks Hate', 4),
#  ('Paycheck Wait', 3),
#  ('Rider Caddyshack', 9),
#  ('Drifter Commandments', 7),
#  ('Swarm Gold', 6),
#  ('Married Go', 3),
#  ('Badman Dawn', 8),
#  ('License Weekend', 8),
#  ('United Pilot', 6),
#  ('Scorpion Apollo', 8),
#  ('Atlantis Cause', 9),
#  ('Timberland Sky', 4),
#  ('Feud Frogmen', 4),
#  ('Reservoir Adaptation', 8),
#  ('Celebrity Horn', 4),
#  ('Mystic Truman', 4),
#  ('Straight Hours', 3),
#  ('Holy Tadpole', 3),
#  ('Goldmine Tycoon', 7),
#  ('Punk Divorce', 7),
#  ('Oklahoma Jumanji', 9),
#  ('Extraordinary Conquerer', 7),
#  ('Godfather Diary', 6),
#  ('Liaisons Sweet', 6),
#  ('Chasing Fight', 5),
#  ('Others Soup', 4),
#  ('Wagon Jaws', 6),
#  ('Hobbit Alien', 8),
#  ('Gone Trouble', 5),
#  ('Anonymous Human', 9),
#  ('Metal Armageddon', 8),
#  ('Grapes Fury', 5),
#  ('Goldfinger Sensibility', 4),
#  ('Whisperer Giant', 3),
#  ('Sting Personal', 7),
#  ('Deliverance Mulholland', 3),
#  ('Craft Outfield', 6),
#  ('Dogma Family', 7),
#  ('Cranes Reservoir', 6),
#  ('Salute Apollo', 4),
#  ('Frogmen Breaking', 6),
#  ('Spoilers Hellfighters', 7),
#  ('Towers Hurricane', 4),
#  ('Potluck Mixed', 6),
#  ('Intentions Empire', 2),
#  ('Gilbert Pelican', 4),
#  ('Blood Argonauts', 4),
#  ('Durham Panky', 9),
#  ('Comforts Rush', 5),
#  ('Movie Shakespeare', 8),
#  ('House Dynamite', 9),
#  ('Sister Freddy', 3),
#  ('Madigan Dorado', 6),
#  ('Saddle Antitrust', 3),
#  ('Panky Submarine', 8),
#  ('Caper Motions', 7),
#  ('Side Ark', 6),
#  ('Wake Jaws', 5),
#  ('Raging Airplane', 3),
#  ('Stranger Strangers', 9),
#  ('Confessions Maguire', 4),
#  ('Monster Spartacus', 7),
#  ('Connection Microcosmos', 7),
#  ('Handicap Boondock', 7),
#  ('Duck Racer', 2),
#  ('Madison Trap', 5),
#  ('State Wasteland', 7),
#  ('Confused Candles', 6),
#  ('Muscle Bright', 5),
#  ('Hollow Jeopardy', 2),
#  ('Clash Freddy', 7),
#  ('Elephant Trojan', 5),
#  ('Sundance Invasion', 7),
#  ('Idols Snatchers', 8),
#  ('Snowman Rollercoaster', 3),
#  ('Conspiracy Spirit', 4),
#  ('Freaky Pocus', 5),
#  ('Soup Wisdom', 2),
#  ('Hate Handicap', 3),
#  ('Notting Speakeasy', 2),
#  ('Story Side', 5),
#  ('Ending Crowds', 5),
#  ('Mulholland Beast', 6),
#  ('Calendar Gunfight', 8),
#  ('Birds Perdition', 4),
#  ('Destination Jerk', 3),
#  ('Smile Earring', 8),
#  ('Maude Mod', 6),
#  ('Party Knock', 2),
#  ('Dying Maker', 2),
#  ('Fugitive Maguire', 11),
#  ('Tomorrow Hustler', 6),
#  ('Doubtfire Labyrinth', 5),
#  ('Park Citizen', 6),
#  ('Full Flatliners', 6),
#  ('Savannah Town', 6),
#  ('Dynamite Tarzan', 5),
#  ('Virginian Pluto', 8),
#  ('Expecations Natural', 3),
#  ('North Tequila', 5),
#  ('Oleander Clue', 10),
#  ('Anaconda Confessions', 5),
#  ('Chicago North', 8),
#  ('Circus Youth', 2),
#  ('Secret Groundhog', 3),
#  ('Murder Antitrust', 8),
#  ('Nemo Campus', 5),
#  ('Beauty Grease', 5),
#  ('Slipper Fidelity', 7),
#  ('Road Roxanne', 8),
#  ('Right Cranes', 7),
#  ('Intolerable Intentions', 6),
#  ('River Outlaw', 4),
#  ('Idaho Love', 6),
#  ('Detective Vision', 3),
#  ('Balloon Homeward', 6),
#  ('Christmas Moonshine', 3),
#  ('Mockingbird Hollywood', 3),
#  ('Lover Truman', 7),
#  ('Gathering Calendar', 3),
#  ('Drums Dynamite', 7),
#  ('Samurai Lion', 2),
#  ('Pond Seattle', 3),
#  ('Pearl Destiny', 4)]

# %% [markdown]
# # 5
#
# ### List each film title and the number of actors in that film, for films with more than 10 actors.

# %%
# %%sql
# EXPLAIN
# SELECT title, count(*)
# FROM film JOIN film_actor
# ON film.film_id = film_actor.film_id
# GROUP BY title
# HAVING count(*) > 10 ;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 8 rows affected.
# [('HashAggregate  (cost=216.48..226.48 rows=1000 width=23)',),
#  ('  Group Key: film.title',),
#  ('  Filter: (count(*) > 10)',),
#  ('  ->  Hash Join  (cost=76.50..175.51 rows=5462 width=15)',),
#  ('        Hash Cond: (film_actor.film_id = film.film_id)',),
#  ('        ->  Seq Scan on film_actor  (cost=0.00..84.62 rows=5462 width=2)',),
#  ('        ->  Hash  (cost=64.00..64.00 rows=1000 width=19)',),
#  ('              ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=19)',)]

# %%
# %%sql
# SELECT title, count(*)
# FROM film JOIN film_actor
# ON film.film_id = film_actor.film_id
# GROUP BY title
# HAVING count(*) > 10 ;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 27 rows affected.
# [('Arabia Dogma', 12),
#  ('Lonely Elephant', 12),
#  ('Maker Gables', 11),
#  ('Lesson Cleopatra', 12),
#  ('Boondock Ballroom', 13),
#  ('Lambs Cincinatti', 15),
#  ('Crazy Home', 13),
#  ('Spice Sorority', 11),
#  ('Dracula Crystal', 13),
#  ('Chitty Lock', 13),
#  ('Telemark Heartbreakers', 11),
#  ('Mask Peach', 11),
#  ('Image Princess', 11),
#  ('Instinct Airport', 11),
#  ('Spirit Flintstones', 11),
#  ('Random Go', 13),
#  ('Rings Heartbreakers', 11),
#  ('Oz Liaisons', 11),
#  ('Submarine Bed', 11),
#  ('Hellfighters Sierra', 12),
#  ('Fiddler Lost', 11),
#  ('Holes Brannigan', 11),
#  ('Sky Miracle', 12),
#  ('Mummy Creatures', 13),
#  ('Pinocchio Simon', 11),
#  ('Titanic Boondock', 12),
#  ('Fugitive Maguire', 11)]

# %% [markdown]
# [Helpful Hints](https://youtu.be/4dZJoRfP7Kw)
#
#
# ---
#
# # 6
#
# ### List the average length of the movies in the database, per `language_id`

# %%
# %%sql
# EXPLAIN
# SELECT language.language_id, AVG(length)
# FROM film RIGHT JOIN language
# ON film.language_id = language.language_id
# GROUP BY language.language_id ;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 7 rows affected.
# [('HashAggregate  (cost=74.62..74.69 rows=6 width=36)',),
#  ('  Group Key: language.language_id',),
#  ('  ->  Hash Right Join  (cost=1.14..69.62 rows=1000 width=6)',),
#  ('        Hash Cond: (film.language_id = language.language_id)',),
#  ('        ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=4)',),
#  ('        ->  Hash  (cost=1.06..1.06 rows=6 width=4)',),
#  ('              ->  Seq Scan on language  (cost=0.00..1.06 rows=6 width=4)',)]

# %%
# %%sql
# SELECT language.language_id, AVG(length)
# FROM film RIGHT JOIN language
# ON film.language_id = language.language_id
# GROUP BY language.language_id ;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 6 rows affected.
# [(6, None),
#  (1, Decimal('115.2720000000000000')),
#  (3, None),
#  (5, None),
#  (4, None),
#  (2, None)]

# %% [markdown]
# # 7
#
# ### List the average length of the movies in the database, per language name

# %%
# %%sql
# EXPLAIN
# SELECT DISTINCT(name),AVG(length)
# FROM film RIGHT JOIN language
# ON film.language_id = language.language_id
# GROUP BY name   ;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 10 rows affected.
# [('Unique  (cost=74.77..74.82 rows=6 width=116)',),
#  ('  ->  Sort  (cost=74.77..74.79 rows=6 width=116)',),
#  ('        Sort Key: language.name, (avg(film.length))',),
#  ('        ->  HashAggregate  (cost=74.62..74.69 rows=6 width=116)',),
#  ('              Group Key: language.name',),
#  ('              ->  Hash Right Join  (cost=1.14..69.62 rows=1000 width=86)',),
#  ('                    Hash Cond: (film.language_id = language.language_id)',),
#  ('                    ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=4)',),
#  ('                    ->  Hash  (cost=1.06..1.06 rows=6 width=88)',),
#  ('                          ->  Seq Scan on language  (cost=0.00..1.06 rows=6 width=88)',)]

# %%
# %%sql
# SELECT DISTINCT(name),AVG(length)
# FROM film RIGHT JOIN language
# ON film.language_id = language.language_id
# GROUP BY name  ;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 6 rows affected.
# [('English             ', Decimal('115.2720000000000000')),
#  ('French              ', None),
#  ('German              ', None),
#  ('Italian             ', None),
#  ('Japanese            ', None),
#  ('Mandarin            ', None)]

# %% [markdown]
# # 8
#
# ### List each film title and its average rental duration in days.
#
# **HINT** `return_date::date` casts the return _timestamp_ to date.  PostgreSQL can do date math natively.

# %%
# %%sql
# EXPLAIN
# SELECT title, AVG(return_date::timestamp - rental_date::timestamp) as rentalduration
# FROM film JOIN inventory
# ON film.film_id = inventory.film_id
# JOIN rental
# ON inventory.inventory_id = rental.inventory_id
# GROUP BY title  ;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 11 rows affected.
# [('HashAggregate  (cost=719.80..732.30 rows=1000 width=31)',),
#  ('  Group Key: film.title',),
#  ('  ->  Hash Join  (cost=204.57..599.47 rows=16044 width=31)',),
#  ('        Hash Cond: (inventory.film_id = film.film_id)',),
#  ('        ->  Hash Join  (cost=128.07..480.67 rows=16044 width=18)',),
#  ('              Hash Cond: (rental.inventory_id = inventory.inventory_id)',),
#  ('              ->  Seq Scan on rental  (cost=0.00..310.44 rows=16044 width=20)',),
#  ('              ->  Hash  (cost=70.81..70.81 rows=4581 width=6)',),
#  ('                    ->  Seq Scan on inventory  (cost=0.00..70.81 rows=4581 width=6)',),
#  ('        ->  Hash  (cost=64.00..64.00 rows=1000 width=19)',),
#  ('              ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=19)',)]

# %%
# %%sql
# SELECT title, AVG(return_date::timestamp - rental_date::timestamp) as average_rental_duration
# FROM film JOIN inventory
# ON film.film_id = inventory.film_id
# JOIN rental
# ON inventory.inventory_id = rental.inventory_id
# GROUP BY title   ;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 958 rows affected.
# [('Graceland Dynamite', datetime.timedelta(days=5, seconds=26100)),
#  ('Opus Ice', datetime.timedelta(days=4, seconds=81550, microseconds=909091)),
#  ('Braveheart Human', datetime.timedelta(days=4, seconds=1716)),
#  ('Wonderful Drop', datetime.timedelta(days=6, seconds=1880)),
#  ('Rush Goodfellas', datetime.timedelta(days=4, seconds=41632, microseconds=258064)),
#  ('Purple Movie', datetime.timedelta(days=3, seconds=86266, microseconds=153846)),
#  ('Minority Kiss', datetime.timedelta(days=4, seconds=85189, microseconds=90909)),
#  ('Luke Mummy', datetime.timedelta(days=5, seconds=642, microseconds=857142)),
#  ('Fantasy Troopers', datetime.timedelta(days=5, seconds=19966, microseconds=153846)),
#  ('Grinch Massage', datetime.timedelta(days=5, seconds=18604, microseconds=285715)),
#  ('Gaslight Crusade', datetime.timedelta(days=4, seconds=281, microseconds=250000)),
#  ('Microcosmos Paradise', datetime.timedelta(days=5, seconds=41316, microseconds=923077)),
#  ('Saturn Name', datetime.timedelta(days=5, seconds=32233, microseconds=846154)),
#  ('Memento Zoolander', datetime.timedelta(days=5, seconds=38404, microseconds=615385)),
#  ('Sunset Racer', datetime.timedelta(days=5, seconds=34440)),
#  ('Zoolander Fiction', datetime.timedelta(days=5, seconds=46884, microseconds=705883)),
#  ('Carol Texas', datetime.timedelta(days=5, seconds=13596, microseconds=666667)),
#  ('Stepmom Dream', datetime.timedelta(days=5, seconds=25089)),
#  ('Arabia Dogma', datetime.timedelta(days=4, seconds=54078, microseconds=461539)),
#  ('Minds Truman', datetime.timedelta(days=5, seconds=8007)),
#  ('Baked Cleopatra', datetime.timedelta(days=4, seconds=53264)),
#  ('Closer Bang', datetime.timedelta(days=4, seconds=76105, microseconds=714285)),
#  ('Enough Raging', datetime.timedelta(days=5, seconds=50064, microseconds=705882)),
#  ('Grosse Wonderful', datetime.timedelta(days=4, seconds=67965)),
#  ('Innocent Usual', datetime.timedelta(days=4, seconds=85216, microseconds=153846)),
#  ('Sleepless Monsoon', datetime.timedelta(days=4, seconds=80185, microseconds=263157)),
#  ('Suit Walls', datetime.timedelta(days=5, seconds=2055, microseconds=789474)),
#  ('Wizard Coldblooded', datetime.timedelta(days=4, seconds=1575)),
#  ('Lonely Elephant', datetime.timedelta(days=4, seconds=73132)),
#  ('Victory Academy', datetime.timedelta(days=4, seconds=7220)),
#  ('Bedazzled Married', datetime.timedelta(days=4, seconds=14432, microseconds=307692)),
#  ('Maker Gables', datetime.timedelta(days=5, seconds=28980)),
#  ('Private Drop', datetime.timedelta(days=4, seconds=82044)),
#  ('Worker Tarzan', datetime.timedelta(days=5, seconds=26904)),
#  ('Gosford Donnie', datetime.timedelta(days=4, seconds=40987, microseconds=500000)),
#  ('Drop Waterfront', datetime.timedelta(days=5, seconds=2853, microseconds=333333)),
#  ('Annie Identity', datetime.timedelta(days=4, seconds=28407, microseconds=272727)),
#  ('Lesson Cleopatra', datetime.timedelta(days=4, seconds=85414, microseconds=285714)),
#  ('Wanda Chamber', datetime.timedelta(days=5, seconds=28844)),
#  ('Dwarfs Alter', datetime.timedelta(days=5, seconds=2475)),
#  ('Garden Island', datetime.timedelta(days=5, seconds=4656)),
#  ('Graduate Lord', datetime.timedelta(days=5, seconds=28455)),
#  ('Patriot Roman', datetime.timedelta(days=5, seconds=50028, microseconds=750000)),
#  ('Novocaine Flight', datetime.timedelta(days=5, seconds=19841, microseconds=52632)),
#  ('Necklace Outbreak', datetime.timedelta(days=4, seconds=53716)),
#  ('Menagerie Rushmore', datetime.timedelta(days=5, seconds=42111, microseconds=428572)),
#  ('Sleeping Suspects', datetime.timedelta(days=4, seconds=77960, microseconds=869565)),
#  ('Uncut Suicides', datetime.timedelta(days=6, seconds=10598, microseconds=571428)),
#  ('Midnight Westward', datetime.timedelta(days=4, seconds=20313, microseconds=750000)),
#  ('Jersey Sassy', datetime.timedelta(days=5, seconds=80440)),
#  ('Rock Instinct', datetime.timedelta(days=5, seconds=4905, microseconds=882353)),
#  ('Magnificent Chitty', datetime.timedelta(days=6, seconds=25837, microseconds=500000)),
#  ('Clones Pinocchio', datetime.timedelta(days=4, seconds=59014, microseconds=736842)),
#  ('Insects Stone', datetime.timedelta(days=3, seconds=27035, microseconds=294118)),
#  ('Giant Troopers', datetime.timedelta(days=4, seconds=19045, microseconds=714285)),
#  ('Loser Hustler', datetime.timedelta(days=5, seconds=11900)),
#  ('Heavyweights Beast', datetime.timedelta(days=4, seconds=65848, microseconds=695652)),
#  ('Entrapment Satisfaction', datetime.timedelta(days=6, seconds=12196)),
#  ('Core Suit', datetime.timedelta(days=5, seconds=33620)),
#  ('Cyclone Family', datetime.timedelta(days=5, seconds=24475, microseconds=714285)),
#  ('Cabin Flash', datetime.timedelta(days=5, seconds=31292)),
#  ('Slacker Liaisons', datetime.timedelta(days=4, seconds=52983, microseconds=529412)),
#  ('Jaws Harry', datetime.timedelta(days=4, seconds=76795, microseconds=714286)),
#  ('Bowfinger Gables', datetime.timedelta(days=3, seconds=11138, microseconds=181818)),
#  ('Fellowship Autumn', datetime.timedelta(days=5, seconds=45290, microseconds=769231)),
#  ('Birdcage Casper', datetime.timedelta(days=5, seconds=25020)),
#  ('Forever Candidate', datetime.timedelta(days=4, seconds=56090, microseconds=769230)),
#  ('Dangerous Uptown', datetime.timedelta(days=6, seconds=12800)),
#  ('Guys Falcon', datetime.timedelta(days=4, seconds=68880)),
#  ('Warlock Werewolf', datetime.timedelta(days=4, seconds=20110)),
#  ('None Spiking', datetime.timedelta(days=5, seconds=8483, microseconds=76923)),
#  ('Bringing Hysterical', datetime.timedelta(days=5, seconds=68505)),
#  ('Haunting Pianist', datetime.timedelta(days=5, seconds=42861, microseconds=818182)),
#  ('Agent Truman', datetime.timedelta(days=5, seconds=75822, microseconds=857143)),
#  ('Motions Details', datetime.timedelta(days=4, seconds=64324)),
#  ('Tenenbaums Command', datetime.timedelta(days=3, seconds=15064, microseconds=615384)),
#  ('Tarzan Videotape', datetime.timedelta(days=4, seconds=47572, microseconds=500000)),
#  ('Secrets Paradise', datetime.timedelta(days=5, seconds=34086)),
#  ('Double Wrath', datetime.timedelta(days=5, seconds=28658, microseconds=400000)),
#  ('Birch Antitrust', datetime.timedelta(days=5, seconds=45556, microseconds=363636)),
#  ('Greatest North', datetime.timedelta(days=4, seconds=66324, microseconds=827586)),
#  ('Sense Greek', datetime.timedelta(days=4, seconds=48822, microseconds=857143)),
#  ('Secretary Rouge', datetime.timedelta(days=5, seconds=38733, microseconds=333333)),
#  ('Invasion Cyclone', datetime.timedelta(days=4, seconds=46755, microseconds=555556)),
#  ('Daughter Madigan', datetime.timedelta(days=5, seconds=58366, microseconds=666667)),
#  ('Congeniality Quest', datetime.timedelta(days=5, seconds=7720, microseconds=909091)),
#  ('Crossroads Casualties', datetime.timedelta(days=4, seconds=25562, microseconds=857142)),
#  ('Canyon Stock', datetime.timedelta(days=4, seconds=74920)),
#  ('Reef Salute', datetime.timedelta(days=5, seconds=41149, microseconds=90910)),
#  ('French Holiday', datetime.timedelta(days=5, seconds=11442, microseconds=352941)),
#  ('Rugrats Shakespeare', datetime.timedelta(days=4, seconds=50062)),
#  ('Highball Potter', datetime.timedelta(days=4, seconds=70682, microseconds=857143)),
#  ('Translation Summer', datetime.timedelta(days=4, seconds=53416)),
#  ('Papi Necklace', datetime.timedelta(days=5, seconds=30112, microseconds=500000)),
#  ('Tycoon Gathering', datetime.timedelta(days=6, seconds=44145)),
#  ('Peak Forever', datetime.timedelta(days=4, seconds=46242)),
#  ('Loverboy Attacks', datetime.timedelta(days=5, seconds=45005)),
#  ('Earring Instinct', datetime.timedelta(days=5, seconds=3925, microseconds=263157)),
#  ('Ship Wonderland', datetime.timedelta(days=2, seconds=85216)),
#  ('Rouge Squad', datetime.timedelta(days=4, seconds=52030)),
#  ('Clue Grail', datetime.timedelta(days=5, seconds=26254, microseconds=285714)),
#  ('Wonderland Christmas', datetime.timedelta(days=4, seconds=75019, microseconds=90909)),
#  ('Finding Anaconda', datetime.timedelta(days=5, seconds=4745)),
#  ('Thin Sagebrush', datetime.timedelta(days=5, seconds=44040)),
#  ('Nash Chocolat', datetime.timedelta(days=6, seconds=26424)),
#  ('Wrath Mile', datetime.timedelta(days=4, seconds=51912, microseconds=857143)),
#  ('Forrest Sons', datetime.timedelta(days=5, seconds=40880)),
#  ('Harold French', datetime.timedelta(days=3, seconds=1590)),
#  ('Pure Runner', datetime.timedelta(days=5, seconds=79948)),
#  ('Turn Star', datetime.timedelta(days=4, seconds=37388, microseconds=571428)),
#  ('Anthem Luke', datetime.timedelta(days=4, seconds=57064)),
#  ('Witches Panic', datetime.timedelta(days=5, seconds=49810)),
#  ('Duffel Apocalypse', datetime.timedelta(days=1, seconds=80022, microseconds=857142)),
#  ('Shrek License', datetime.timedelta(days=3, seconds=45630)),
#  ('Impossible Prejudice', datetime.timedelta(days=4, seconds=77297, microseconds=142857)),
#  ('Heaven Freedom', datetime.timedelta(days=4, seconds=84620)),
#  ('Peach Innocent', datetime.timedelta(days=5, seconds=58241, microseconds=538461)),
#  ('Frisco Forrest', datetime.timedelta(days=6, seconds=16402, microseconds=500000)),
#  ('Reds Pocus', datetime.timedelta(days=6, seconds=61700)),
#  ('Music Boondock', datetime.timedelta(days=4, seconds=77933, microseconds=684210)),
#  ('Chisum Behavior', datetime.timedelta(days=4, seconds=60609, microseconds=230769)),
#  ('Volcano Texas', datetime.timedelta(days=4, seconds=74620)),
#  ('Daisy Menagerie', datetime.timedelta(days=4, seconds=29973, microseconds=750000)),
#  ('Lost Bird', datetime.timedelta(days=6, seconds=5915)),
#  ('Conversation Downhill', datetime.timedelta(days=5, seconds=56572, microseconds=500000)),
#  ('Caribbean Liberty', datetime.timedelta(days=5, seconds=67700)),
#  ('Lambs Cincinatti', datetime.timedelta(days=5, seconds=4752)),
#  ('Escape Metropolis', datetime.timedelta(days=4, seconds=56428, microseconds=800000)),
#  ('Dumbo Lust', datetime.timedelta(days=4, seconds=77910)),
#  ('Pizza Jumanji', datetime.timedelta(days=4, seconds=45085, microseconds=714286)),
#  ('Hills Neighbors', datetime.timedelta(days=6, seconds=31125, microseconds=600000)),
#  ('Chance Resurrection', datetime.timedelta(days=5, seconds=7840)),
#  ('Truman Crazy', datetime.timedelta(days=4, seconds=61502, microseconds=608695)),
#  ('Candidate Perdition', datetime.timedelta(days=6, seconds=4994, microseconds=117647)),
#  ('Spiking Element', datetime.timedelta(days=4, seconds=47981, microseconds=538462)),
#  ('Fight Jawbreaker', datetime.timedelta(days=4, seconds=32625, microseconds=714285)),
#  ('Apache Divine', datetime.timedelta(days=4, seconds=23247, microseconds=96774)),
#  ('Shining Roses', datetime.timedelta(days=5, seconds=23400)),
#  ('Ishtar Rocketeer', datetime.timedelta(days=5, seconds=72737, microseconds=142857)),
#  ('Flying Hook', datetime.timedelta(days=5, seconds=83930, microseconds=526315)),
#  ('Desperate Trainspotting', datetime.timedelta(days=4, seconds=20040)),
#  ('Greedy Roots', datetime.timedelta(days=3, seconds=18994, microseconds=285714)),
#  ('Forrester Comancheros', datetime.timedelta(days=5, seconds=22901, microseconds=538462)),
#  ('Dirty Ace', datetime.timedelta(days=5, seconds=28384)),
#  ('Trading Pinocchio', datetime.timedelta(days=5, seconds=38790)),
#  ('Paths Control', datetime.timedelta(days=6, seconds=3480)),
#  ('Graffiti Love', datetime.timedelta(days=4, seconds=13884)),
#  ('Amelie Hellfighters', datetime.timedelta(days=4, seconds=75312)),
#  ('Pickup Driving', datetime.timedelta(days=6, seconds=4788, microseconds=750000)),
#  ('Panic Club', datetime.timedelta(days=5, seconds=25585, microseconds=714285)),
#  ('Crazy Home', datetime.timedelta(days=4, seconds=33453, microseconds=333333)),
#  ('Forward Temple', datetime.timedelta(days=5, seconds=51429, microseconds=375000)),
#  ('Vertigo Northwest', datetime.timedelta(days=4, seconds=74287, microseconds=500000)),
#  ('Jericho Mulan', datetime.timedelta(days=5, seconds=53777, microseconds=647059)),
#  ('Gunfighter Mussolini', datetime.timedelta(days=5, seconds=47835)),
#  ('Bilko Anonymous', datetime.timedelta(days=5, seconds=35506, microseconds=153847)),
#  ('Spice Sorority', datetime.timedelta(days=4, seconds=14799)),
#  ('Blade Polish', datetime.timedelta(days=4, seconds=6820)),
#  ('Massage Image', datetime.timedelta(days=5, seconds=15705)),
#  ('Home Pity', datetime.timedelta(days=6, seconds=19594, microseconds=285715)),
#  ('Boulevard Mob', datetime.timedelta(days=5, seconds=56054, microseconds=117648)),
#  ('Dalmations Sweden', datetime.timedelta(days=5, seconds=33153)),
#  ('Hunter Alter', datetime.timedelta(days=6, seconds=69960)),
#  ('Zorro Ark', datetime.timedelta(days=4, seconds=46585, microseconds=161291)),
#  ('Silence Kane', datetime.timedelta(days=5, seconds=17681, microseconds=250000)),
#  ('Taxi Kick', datetime.timedelta(days=4, seconds=49344, microseconds=705883)),
#  ('Resurrection Silverado', datetime.timedelta(days=4, seconds=38805, microseconds=714286)),
#  ('Suspects Quills', datetime.timedelta(days=5, seconds=5679, microseconds=310345)),
#  ('Dracula Crystal', datetime.timedelta(days=4, seconds=64188, microseconds=571428)),
#  ('Harper Dying', datetime.timedelta(days=5, seconds=58146)),
#  ('Simon North', datetime.timedelta(days=5, seconds=7790)),
#  ('Chitty Lock', datetime.timedelta(days=5, seconds=14271, microseconds=428572)),
#  ('Vacation Boondock', datetime.timedelta(days=4, seconds=68437, microseconds=142857)),
#  ('Ballroom Mockingbird', datetime.timedelta(days=4, seconds=46020)),
#  ('Legally Secretary', datetime.timedelta(days=4, seconds=12106, microseconds=666667)),
#  ('Barefoot Manchurian', datetime.timedelta(days=5, seconds=3700)),
#  ('Cruelty Unforgiven', datetime.timedelta(days=3, seconds=70945, microseconds=714286)),
#  ('Smoking Barbarella', datetime.timedelta(days=4, seconds=29890, microseconds=588235)),
#  ('Soldiers Evolution', datetime.timedelta(days=4, seconds=6307, microseconds=500000)),
#  ('Robbers Joon', datetime.timedelta(days=4, seconds=75160, microseconds=645161)),
#  ('Telemark Heartbreakers', datetime.timedelta(days=4, seconds=66220, microseconds=800000)),
#  ('Westward Seabiscuit', datetime.timedelta(days=5, seconds=67479, microseconds=230770)),
#  ('Million Ace', datetime.timedelta(days=4, seconds=78858)),
#  ('Notorious Reunion', datetime.timedelta(days=6, seconds=65657, microseconds=142857)),
#  ('Ali Forever', datetime.timedelta(days=4, seconds=54270)),
#  ('Coneheads Smoochy', datetime.timedelta(days=5, seconds=42727, microseconds=200000)),
#  ('Bird Independence', datetime.timedelta(days=5, seconds=49516, microseconds=363637)),
#  ('Intrigue Worst', datetime.timedelta(days=5, seconds=32141, microseconds=52632)),
#  ('Mask Peach', datetime.timedelta(days=5, seconds=16722, microseconds=352941)),
#  ('Scissorhands Slums', datetime.timedelta(days=3, seconds=41384)),
#  ('Boiled Dares', datetime.timedelta(days=4, seconds=53188)),
#  ('Majestic Floats', datetime.timedelta(days=6, seconds=13852, microseconds=941176)),
#  ('Past Suicides', datetime.timedelta(days=4, seconds=45729, microseconds=230770)),
#  ('Masked Bubble', datetime.timedelta(days=3, seconds=81237)),
#  ('Bull Shawshank', datetime.timedelta(days=4, seconds=63152)),
#  ('Reap Unfaithful', datetime.timedelta(days=5, seconds=29801, microseconds=250000)),
#  ('Gunfight Moon', datetime.timedelta(days=5, seconds=43622, microseconds=727272)),
#  ('Sagebrush Clueless', datetime.timedelta(days=6, seconds=39161, microseconds=250000)),
#  ('Beethoven Exorcist', datetime.timedelta(days=4, seconds=66190, microseconds=909091)),
#  ('Lock Rear', datetime.timedelta(days=4, seconds=12213, microseconds=750000)),
#  ('Vietnam Smoochy', datetime.timedelta(days=4, seconds=69296)),
#  ('Breaking Home', datetime.timedelta(days=4, seconds=19772, microseconds=307692)),
#  ('Runaway Tenenbaums', datetime.timedelta(days=4, seconds=74137, microseconds=500000)),
#  ('Head Stranger', datetime.timedelta(days=5, seconds=7344, microseconds=545455)),
#  ('Ace Goldfinger', datetime.timedelta(days=5, seconds=55530)),
#  ('Quest Mussolini', datetime.timedelta(days=4, seconds=23433)),
#  ('Dancing Fever', datetime.timedelta(days=6, seconds=21188, microseconds=888889)),
#  ('Image Princess', datetime.timedelta(days=5, seconds=222, microseconds=857143)),
#  ('Fool Mockingbird', datetime.timedelta(days=5, seconds=32355, microseconds=652174)),
#  ('Panther Reds', datetime.timedelta(days=4, seconds=83600)),
#  ('Holocaust Highball', datetime.timedelta(days=5, seconds=2318, microseconds=823529)),
#  ('Bright Encounters', datetime.timedelta(days=5, seconds=25541, microseconds=538462)),
#  ('Adaptation Holes', datetime.timedelta(days=3, seconds=40230)),
#  ('Deceiver Betrayed', datetime.timedelta(days=3, seconds=85177, microseconds=142857)),
#  ('Antitrust Tomatoes', datetime.timedelta(days=4, seconds=59370)),
#  ('Fatal Haunted', datetime.timedelta(days=5, seconds=25354, microseconds=285714)),
#  ('Sons Interview', datetime.timedelta(days=5, seconds=18710, microseconds=769230)),
#  ('Yentl Idaho', datetime.timedelta(days=4, seconds=68796, microseconds=521739)),
#  ('Modern Dorado', datetime.timedelta(days=5, seconds=12548)),
#  ('Monsoon Cause', datetime.timedelta(days=5, seconds=53866, microseconds=666667)),
#  ('Rage Games', datetime.timedelta(days=4, seconds=23156, microseconds=842105)),
#  ('Uprising Uptown', datetime.timedelta(days=5, seconds=15108, microseconds=750000)),
#  ('Jason Trap', datetime.timedelta(days=5, seconds=23238, microseconds=260870)),
#  ('Sweet Brotherhood', datetime.timedelta(days=4, seconds=80428)),
#  ('Crusade Honey', datetime.timedelta(days=6, seconds=44317, microseconds=500000)),
#  ('Arachnophobia Rollercoaster', datetime.timedelta(days=5, seconds=45625)),
#  ('Stallion Sundance', datetime.timedelta(days=3, seconds=12274, microseconds=285715)),
#  ('Creatures Shakespeare', datetime.timedelta(days=5, seconds=84017, microseconds=142857)),
#  ('Easy Gladiator', datetime.timedelta(days=6, seconds=1087, microseconds=826087)),
#  ('Snatchers Montezuma', datetime.timedelta(days=3, seconds=73806, microseconds=666667)),
#  ('Shock Cabin', datetime.timedelta(days=5, seconds=32794, microseconds=285714)),
#  ('Island Exorcist', datetime.timedelta(days=4, seconds=71912, microseconds=307692)),
#  ('Liberty Magnificent', datetime.timedelta(days=6, seconds=10025)),
#  ('Seattle Expecations', datetime.timedelta(days=5, seconds=36506, microseconds=86957)),
#  ('Gun Bonnie', datetime.timedelta(days=5, seconds=72232, microseconds=800000)),
#  ('Alabama Devil', datetime.timedelta(days=5, seconds=49560)),
#  ('Train Bunch', datetime.timedelta(days=3, seconds=30180)),
#  ('Identity Lover', datetime.timedelta(days=4, seconds=86086, microseconds=153846)),
#  ('Clyde Theory', datetime.timedelta(days=5, seconds=38850)),
#  ('Troopers Metal', datetime.timedelta(days=5, seconds=3330)),
#  ('Primary Glass', datetime.timedelta(days=4, seconds=35477, microseconds=777778)),
#  ('Excitement Eve', datetime.timedelta(days=4, seconds=66997, microseconds=142857)),
#  ('Affair Prejudice', datetime.timedelta(days=4, seconds=65520)),
#  ('Fury Murder', datetime.timedelta(days=5, seconds=10484, microseconds=210527)),
#  ('Impact Aladdin', datetime.timedelta(days=7, seconds=17333, microseconds=333333)),
#  ('Deep Crusade', datetime.timedelta(days=5, seconds=45387, microseconds=692307)),
#  ('Sierra Divide', datetime.timedelta(days=5, seconds=53468)),
#  ('Dinosaur Secretary', datetime.timedelta(days=5, seconds=53190)),
#  ('Freedom Cleopatra', datetime.timedelta(days=2, seconds=82920)),
#  ('Mosquito Armageddon', datetime.timedelta(days=5, seconds=10911, microseconds=428572)),
#  ('Jungle Closer', datetime.timedelta(days=5, seconds=47326, microseconds=666667)),
#  ('Indian Love', datetime.timedelta(days=5, seconds=48277, microseconds=500000)),
#  ('Glass Dying', datetime.timedelta(days=5, seconds=56151, microseconds=428571)),
#  ('Born Spinal', datetime.timedelta(days=4, seconds=12540)),
#  ('Life Twisted', datetime.timedelta(days=5, seconds=3042)),
#  ('Greek Everyone', datetime.timedelta(days=4, seconds=76905, microseconds=882353)),
#  ('Massacre Usual', datetime.timedelta(days=5, seconds=59660)),
#  ('Kissing Dolls', datetime.timedelta(days=4, seconds=68928)),
#  ('Meet Chocolate', datetime.timedelta(days=5, seconds=10870)),
#  ('Dorado Notting', datetime.timedelta(days=6, seconds=9104, microseconds=444444)),
#  ('Titans Jerk', datetime.timedelta(days=5, seconds=50267, microseconds=142857)),
#  ('Hanging Deep', datetime.timedelta(days=4, seconds=63116, microseconds=842105)),
#  ('Streetcar Intentions', datetime.timedelta(days=4, seconds=28867, microseconds=200000)),
#  ('Hardly Robbers', datetime.timedelta(days=6, seconds=81945)),
#  ('War Notting', datetime.timedelta(days=5, seconds=33805)),
#  ('Diary Panic', datetime.timedelta(days=4, seconds=49880)),
#  ('Instinct Airport', datetime.timedelta(days=4, seconds=7730)),
#  ('Bikini Borrowers', datetime.timedelta(days=5, seconds=86121, microseconds=176470)),
#  ('Rebel Airport', datetime.timedelta(days=4, seconds=79102, microseconds=500000)),
#  ('Flamingos Connecticut', datetime.timedelta(days=4, seconds=31925, microseconds=217391)),
#  ('Cincinatti Whisperer', datetime.timedelta(days=6, seconds=50395)),
#  ('Trainspotting Strangers', datetime.timedelta(days=5, seconds=21130, microseconds=909090)),
#  ('Pelican Comforts', datetime.timedelta(days=5, seconds=76017, microseconds=692308)),
#  ('Madre Gables', datetime.timedelta(days=6, seconds=70140)),
#  ('Lord Arizona', datetime.timedelta(days=5, seconds=6468)),
#  ('Feathers Metal', datetime.timedelta(days=5, seconds=61761, microseconds=818182)),
#  ('Hook Chariots', datetime.timedelta(days=5, seconds=16633, microseconds=846153)),
#  ('Groove Fiction', datetime.timedelta(days=6, seconds=29333, microseconds=333333)),
#  ('Window Side', datetime.timedelta(days=4, seconds=79412, microseconds=727273)),
#  ('Silverado Goldfinger', datetime.timedelta(days=6, seconds=61129, microseconds=90909)),
#  ('Mannequin Worst', datetime.timedelta(days=4, seconds=35784)),
#  ('Willow Tracy', datetime.timedelta(days=5, seconds=33641, microseconds=250000)),
#  ('Natural Stock', datetime.timedelta(days=4, seconds=62543, microseconds=76923)),
#  ('Karate Moon', datetime.timedelta(days=4, seconds=70257, microseconds=391304)),
#  ('Roses Treasure', datetime.timedelta(days=4, seconds=67461, microseconds=428571)),
#  ('Jawbreaker Brooklyn', datetime.timedelta(days=2, seconds=50610)),
#  ('Racer Egg', datetime.timedelta(days=4, seconds=64423, microseconds=333333)),
#  ('Mixed Doors', datetime.timedelta(days=5, seconds=82365)),
#  ('Potter Connecticut', datetime.timedelta(days=5, seconds=11149, microseconds=411765)),
#  ('Mighty Luck', datetime.timedelta(days=5, seconds=50285)),
#  ('Sabrina Midnight', datetime.timedelta(days=4, seconds=49560)),
#  ('Roxanne Rebel', datetime.timedelta(days=4, seconds=28793, microseconds=684211)),
#  ('Fidelity Devil', datetime.timedelta(days=5, seconds=29048, microseconds=571429)),
#  ('Madness Attacks', datetime.timedelta(days=5, seconds=37221, microseconds=600000)),
#  ('Mussolini Spoilers', datetime.timedelta(days=4, seconds=3336)),
#  ('Star Operation', datetime.timedelta(days=5, seconds=46935)),
#  ('Vanilla Day', datetime.timedelta(days=5, seconds=49033, microseconds=333333)),
#  ('Bunch Minds', datetime.timedelta(days=5, seconds=45312)),
#  ('Sweethearts Suspects', datetime.timedelta(days=5, seconds=21765)),
#  ('Won Dares', datetime.timedelta(days=5, seconds=12233, microseconds=333333)),
#  ('Lola Agent', datetime.timedelta(days=5, seconds=28292, microseconds=500000)),
#  ('Reunion Witches', datetime.timedelta(days=4, seconds=2325)),
#  ('Encino Elf', datetime.timedelta(days=4, seconds=56893, microseconds=333333)),
#  ('Unfaithful Kill', datetime.timedelta(days=5, seconds=35865)),
#  ('Hustler Party', datetime.timedelta(days=6, seconds=43622, microseconds=727273)),
#  ('Spirit Flintstones', datetime.timedelta(days=4, seconds=17120)),
#  ('Rollercoaster Bringing', datetime.timedelta(days=5, seconds=79188)),
#  ('Details Packer', datetime.timedelta(days=5, seconds=51630)),
#  ('Pianist Outfield', datetime.timedelta(days=4, seconds=42594)),
#  ('Luck Opus', datetime.timedelta(days=4, seconds=73824)),
#  ('Butterfly Chocolat', datetime.timedelta(days=5, seconds=80452)),
#  ('Mallrats United', datetime.timedelta(days=5, seconds=51576)),
#  ('Desire Alien', datetime.timedelta(days=4, seconds=38467, microseconds=500000)),
#  ('Queen Luke', datetime.timedelta(days=5, seconds=28208, microseconds=571428)),
#  ('Glory Tracy', datetime.timedelta(days=3, seconds=58620)),
#  ('Bound Cheaper', datetime.timedelta(days=5, seconds=27208, microseconds=695652)),
#  ('Academy Dinosaur', datetime.timedelta(days=4, seconds=86151, microseconds=818182)),
#  ('Igby Maker', datetime.timedelta(days=5, seconds=35150)),
#  ('Gentlemen Stage', datetime.timedelta(days=5, seconds=18456, microseconds=521739)),
#  ('Pollock Deliverance', datetime.timedelta(days=4, seconds=53791, microseconds=764706)),
#  ('Sleuth Orient', datetime.timedelta(days=4, seconds=80605, microseconds=714286)),
#  ('Cowboy Doom', datetime.timedelta(days=3, seconds=32125, microseconds=714285)),
#  ('Prejudice Oleander', datetime.timedelta(days=5, seconds=44019)),
#  ('Odds Boogie', datetime.timedelta(days=5, seconds=27304)),
#  ('Freddy Storm', datetime.timedelta(days=5, seconds=25776, microseconds=521740)),
#  ('Valentine Vanishing', datetime.timedelta(days=5, seconds=61910)),
#  ('Show Lord', datetime.timedelta(days=4, seconds=20270, microseconds=400000)),
#  ('Confidential Interview', datetime.timedelta(days=5, seconds=11112, microseconds=413793)),
#  ('Armageddon Lost', datetime.timedelta(days=5, seconds=15918)),
#  ('Grail Frankenstein', datetime.timedelta(days=5, seconds=77860)),
#  ('Edge Kissing', datetime.timedelta(days=4, seconds=81348)),
#  ('Half Outfield', datetime.timedelta(days=4, seconds=64127, microseconds=500000)),
#  ('Love Suicides', datetime.timedelta(days=5, seconds=17010)),
#  ('Seven Swarm', datetime.timedelta(days=4, seconds=51588)),
#  ('Oscar Gold', datetime.timedelta(days=4, seconds=85953, microseconds=600000)),
#  ('Lies Treatment', datetime.timedelta(days=5, seconds=10697, microseconds=777778)),
#  ('Chocolat Harry', datetime.timedelta(days=5, seconds=57591)),
#  ('Wind Phantom', datetime.timedelta(days=4, seconds=71235, microseconds=652174)),
#  ('Casablanca Super', datetime.timedelta(days=4, seconds=29250)),
#  ('Random Go', datetime.timedelta(days=5, seconds=24240)),
#  ('Newsies Story', datetime.timedelta(days=5, seconds=43851, microseconds=428571)),
#  ('Leathernecks Dwarfs', datetime.timedelta(days=5, seconds=29348, microseconds=571428)),
#  ('Knock Warlock', datetime.timedelta(days=5, seconds=53680)),
#  ('Pajama Jawbreaker', datetime.timedelta(days=4, seconds=59734, microseconds=285714)),
#  ('Joon Northwest', datetime.timedelta(days=4, seconds=974, microseconds=117647)),
#  ('Stage World', datetime.timedelta(days=5, seconds=37584)),
#  ('American Circus', datetime.timedelta(days=5, seconds=36334, microseconds=285714)),
#  ('Rear Trading', datetime.timedelta(days=5, seconds=49076, microseconds=470588)),
#  ('Siege Madre', datetime.timedelta(days=5, seconds=13672)),
#  ('Angels Life', datetime.timedelta(days=5, seconds=28549, microseconds=90909)),
#  ('Crooked Frogmen', datetime.timedelta(days=5, seconds=16123, microseconds=636364)),
#  ('Jingle Sagebrush', datetime.timedelta(days=4, seconds=14173, microseconds=846154)),
#  ('Tramp Others', datetime.timedelta(days=5, seconds=6327)),
#  ('Artist Coldblooded', datetime.timedelta(days=5, seconds=34376, microseconds=250000)),
#  ('Beverly Outlaw', datetime.timedelta(days=5, seconds=21808, microseconds=571429)),
#  ('Doom Dancing', datetime.timedelta(days=6, seconds=25837, microseconds=142857)),
#  ('Hunting Musketeers', datetime.timedelta(days=5, seconds=4024)),
#  ('Mine Titans', datetime.timedelta(days=5, seconds=65595, microseconds=789473)),
#  ('Rings Heartbreakers', datetime.timedelta(days=5, seconds=79424)),
#  ('Lights Deer', datetime.timedelta(days=5, seconds=70462, microseconds=500000)),
#  ('Mars Roman', datetime.timedelta(days=5, seconds=34860)),
#  ('Champion Flatliners', datetime.timedelta(days=4, seconds=83155, microseconds=384616)),
#  ('Temple Attraction', datetime.timedelta(days=4, seconds=46845)),
#  ('Dragon Squad', datetime.timedelta(days=4, seconds=79870, microseconds=909091)),
#  ('Roman Punk', datetime.timedelta(days=5, seconds=33015)),
#  ('Moulin Wake', datetime.timedelta(days=5, seconds=66555)),
#  ('Fiction Christmas', datetime.timedelta(days=5, seconds=64389, microseconds=473684)),
#  ('Princess Giant', datetime.timedelta(days=5, seconds=26102, microseconds=307693)),
#  ('Empire Malkovich', datetime.timedelta(days=5, seconds=75768, microseconds=571429)),
#  ('Fish Opus', datetime.timedelta(days=4, seconds=78996)),
#  ('Tequila Past', datetime.timedelta(days=3, seconds=29120)),
#  ('Theory Mermaid', datetime.timedelta(days=5, seconds=60846)),
#  ('Rocketeer Mother', datetime.timedelta(days=5, seconds=33356, microseconds=363637)),
#  ('Divine Resurrection', datetime.timedelta(days=4, seconds=66265, microseconds=714286)),
#  ('Manchurian Curtain', datetime.timedelta(days=5, seconds=43368)),
#  ('Casper Dragonfly', datetime.timedelta(days=4, seconds=26505)),
#  ('Mulan Moon', datetime.timedelta(days=5, seconds=20325)),
#  ('Newton Labyrinth', datetime.timedelta(days=5, seconds=30914, microseconds=117647)),
#  ('Bubble Grosse', datetime.timedelta(days=4, seconds=37224)),
#  ('Berets Agent', datetime.timedelta(days=4, seconds=32466)),
#  ('Lebowski Soldiers', datetime.timedelta(days=4, seconds=29922, microseconds=857143)),
#  ('Searchers Wait', datetime.timedelta(days=5, seconds=15257, microseconds=142857)),
#  ('Uptown Young', datetime.timedelta(days=3, seconds=48685)),
#  ('South Wait', datetime.timedelta(days=5, seconds=27957, microseconds=142857)),
#  ('Center Dinosaur', datetime.timedelta(days=4, seconds=9033, microseconds=913043)),
#  ('Spartacus Cheaper', datetime.timedelta(days=5, seconds=34853, microseconds=333333)),
#  ('Wedding Apollo', datetime.timedelta(days=5, seconds=33594, microseconds=782608)),
#  ('Perfect Groove', datetime.timedelta(days=6, seconds=21998, microseconds=823529)),
#  ('Dawn Pond', datetime.timedelta(days=5, seconds=45766, microseconds=666667)),
#  ('Ties Hunger', datetime.timedelta(days=5, seconds=11405, microseconds=454546)),
#  ('Satisfaction Confidential', datetime.timedelta(days=5, seconds=25920)),
#  ('Speed Suit', datetime.timedelta(days=5, seconds=36620)),
#  ('Halloween Nuts', datetime.timedelta(days=4, seconds=76644)),
#  ('Vision Torque', datetime.timedelta(days=5, seconds=7174, microseconds=285715)),
#  ('Blackout Private', datetime.timedelta(days=4, seconds=21066, microseconds=666667)),
#  ('Iron Moon', datetime.timedelta(days=4, seconds=14830, microseconds=909091)),
#  ('Bonnie Holocaust', datetime.timedelta(days=4, seconds=24975)),
#  ('Coma Head', datetime.timedelta(days=4, seconds=41051, microseconds=538461)),
#  ('Disciple Mother', datetime.timedelta(days=3, seconds=58823, microseconds=333333)),
#  ('Vanishing Rocky', datetime.timedelta(days=4, seconds=47244, microseconds=705883)),
#  ('Paris Weekend', datetime.timedelta(days=5, seconds=79911, microseconds=428572)),
#  ('Bill Others', datetime.timedelta(days=4, seconds=75931, microseconds=578947)),
#  ('Mob Duffel', datetime.timedelta(days=5, seconds=40440)),
#  ('Expendable Stallion', datetime.timedelta(days=5, seconds=13005)),
#  ('Patton Interview', datetime.timedelta(days=4, seconds=81386, microseconds=86957)),
#  ('Club Graffiti', datetime.timedelta(days=4, seconds=57663, microseconds=529411)),
#  ('Alien Center', datetime.timedelta(days=4, seconds=74337, microseconds=272727)),
#  ('Jade Bunch', datetime.timedelta(days=4, seconds=27686, microseconds=666667)),
#  ('Network Peak', datetime.timedelta(days=5, seconds=47576, microseconds=129032)),
#  ('Name Detective', datetime.timedelta(days=4, seconds=48240)),
#  ('Outfield Massacre', datetime.timedelta(days=5, seconds=34632, microseconds=631579)),
#  ('Watership Frontier', datetime.timedelta(days=6, seconds=5490)),
#  ('Trojan Tomorrow', datetime.timedelta(days=3, seconds=46586, microseconds=666667)),
#  ('Apocalypse Flamingos', datetime.timedelta(days=4, seconds=21170)),
#  ('Cat Coneheads', datetime.timedelta(days=5, seconds=6132, microseconds=413793)),
#  ('Varsity Trip', datetime.timedelta(days=4, seconds=4612)),
#  ('Strangelove Desire', datetime.timedelta(days=6, seconds=14895)),
#  ('Egypt Tenenbaums', datetime.timedelta(days=6, seconds=6317, microseconds=647059)),
#  ('Pirates Roxanne', datetime.timedelta(days=5, seconds=2979)),
#  ('Divorce Shining', datetime.timedelta(days=4, seconds=22645, microseconds=714286)),
#  ('Vampire Whale', datetime.timedelta(days=4, seconds=74515)),
#  ('Oz Liaisons', datetime.timedelta(days=4, seconds=3580)),
#  ('Ghostbusters Elf', datetime.timedelta(days=5, seconds=8760)),
#  ('Traffic Hobbit', datetime.timedelta(days=3, seconds=34692)),
#  ('Whale Bikini', datetime.timedelta(days=6, seconds=16470)),
#  ('Nuts Ties', datetime.timedelta(days=5, seconds=2100)),
#  ('Moonwalker Fool', datetime.timedelta(days=6, seconds=10985)),
#  ('Cheaper Clyde', datetime.timedelta(days=5, seconds=53349)),
#  ('Watch Tracy', datetime.timedelta(days=4, seconds=68017, microseconds=500000)),
#  ('Lust Lock', datetime.timedelta(days=3, seconds=50972, microseconds=307692)),
#  ('Citizen Shrek', datetime.timedelta(days=5, seconds=10366, microseconds=153847)),
#  ('Command Darling', datetime.timedelta(days=6, seconds=25818, microseconds=750000)),
#  ('Heartbreakers Bright', datetime.timedelta(days=4, seconds=28398)),
#  ('Patient Sister', datetime.timedelta(days=4, seconds=21053, microseconds=684211)),
#  ('Outbreak Divine', datetime.timedelta(days=4, seconds=81871, microseconds=304347)),
#  ('Bed Highball', datetime.timedelta(days=5, seconds=49930)),
#  ('Requiem Tycoon', datetime.timedelta(days=4, seconds=78022, microseconds=105263)),
#  ('National Story', datetime.timedelta(days=4, seconds=41564, microseconds=210526)),
#  ('Jeepers Wedding', datetime.timedelta(days=5, seconds=30146, microseconds=250000)),
#  ('Frida Slipper', datetime.timedelta(days=5, seconds=44034)),
#  ('Mourning Purple', datetime.timedelta(days=4, seconds=64800)),
#  ('Language Cowboy', datetime.timedelta(days=4, seconds=71683, microseconds=636364)),
#  ('Doors President', datetime.timedelta(days=4, seconds=35382, microseconds=352941)),
#  ('Barbarella Streetcar', datetime.timedelta(days=5, seconds=65611, microseconds=200000)),
#  ('Hoosiers Birdcage', datetime.timedelta(days=4, seconds=75472, microseconds=500000)),
#  ('Blindness Gun', datetime.timedelta(days=5, seconds=8382, microseconds=857143)),
#  ('Maltese Hope', datetime.timedelta(days=4, seconds=43750, microseconds=909091)),
#  ('Chamber Italian', datetime.timedelta(days=6, seconds=56170)),
#  ('Tomatoes Hellfighters', datetime.timedelta(days=4, seconds=33771, microseconds=428572)),
#  ('Army Flintstones', datetime.timedelta(days=4, seconds=80538, microseconds=750000)),
#  ('Moon Bunch', datetime.timedelta(days=4, seconds=77451, microseconds=724137)),
#  ('Wonka Sea', datetime.timedelta(days=4, seconds=48200)),
#  ('Hedwig Alter', datetime.timedelta(days=4, seconds=14455)),
#  ('Honey Ties', datetime.timedelta(days=5, seconds=40067, microseconds=368421)),
#  ('Hurricane Affair', datetime.timedelta(days=5, seconds=21582, microseconds=500000)),
#  ('Nightmare Chill', datetime.timedelta(days=4, seconds=45799, microseconds=200000)),
#  ('Matrix Snowman', datetime.timedelta(days=3, seconds=69440)),
#  ('Shootist Superfly', datetime.timedelta(days=4, seconds=84667, microseconds=500000)),
#  ('Hanky October', datetime.timedelta(days=5, seconds=69396, microseconds=923076)),
#  ('Orient Closer', datetime.timedelta(days=4, seconds=21854, microseconds=117647)),
#  ('Lawrence Love', datetime.timedelta(days=4, seconds=44723, microseconds=76923)),
#  ('Flight Lies', datetime.timedelta(days=7, seconds=23395)),
#  ('Usual Untouchables', datetime.timedelta(days=3, seconds=43587, microseconds=692307)),
#  ('Squad Fish', datetime.timedelta(days=3, seconds=39377, microseconds=142857)),
#  ('Shakespeare Saddle', datetime.timedelta(days=5, seconds=47364, microseconds=545454)),
#  ('Shepherd Midsummer', datetime.timedelta(days=4, seconds=70164)),
#  ('Wisdom Worker', datetime.timedelta(days=5, seconds=3726, microseconds=666667)),
#  ('African Egg', datetime.timedelta(days=7, seconds=9212, microseconds=727272)),
#  ('Family Sweet', datetime.timedelta(days=4, seconds=57448, microseconds=888889)),
#  ('Wait Cider', datetime.timedelta(days=5, seconds=73868, microseconds=571429)),
#  ('October Submarine', datetime.timedelta(days=5, seconds=44258, microseconds=181819)),
#  ('World Leathernecks', datetime.timedelta(days=5, seconds=9120)),
#  ('Encounters Curtain', datetime.timedelta(days=4, seconds=72066, microseconds=315789)),
#  ('California Birds', datetime.timedelta(days=5, seconds=39255)),
#  ('Brooklyn Desert', datetime.timedelta(days=5, seconds=41088, microseconds=571428)),
#  ('Dream Pickup', datetime.timedelta(days=5, seconds=8465, microseconds=454545)),
#  ('Phantom Glory', datetime.timedelta(days=4, seconds=22480)),
#  ('Arizona Bang', datetime.timedelta(days=4, seconds=44185, microseconds=714285)),
#  ('Midsummer Groundhog', datetime.timedelta(days=4, seconds=40292, microseconds=727273)),
#  ('Alaska Phantom', datetime.timedelta(days=5, seconds=25423, microseconds=846154)),
#  ('Stampede Disturbing', datetime.timedelta(days=5, seconds=4680)),
#  ('Attraction Newton', datetime.timedelta(days=4, seconds=36072, microseconds=500000)),
#  ('Earth Vision', datetime.timedelta(days=5, seconds=56244, microseconds=545455)),
#  ('Telegraph Voyage', datetime.timedelta(days=6, seconds=43160)),
#  ('Clueless Bucket', datetime.timedelta(days=4, seconds=64572)),
#  ('King Evolution', datetime.timedelta(days=5, seconds=7040)),
#  ('Hall Cassidy', datetime.timedelta(days=4, seconds=86111, microseconds=250000)),
#  ('Slums Duck', datetime.timedelta(days=5, seconds=20170)),
#  ('Desert Poseidon', datetime.timedelta(days=4, seconds=46288, microseconds=421052)),
#  ('Bride Intrigue', datetime.timedelta(days=4, seconds=44573, microseconds=684210)),
#  ('Wardrobe Phantom', datetime.timedelta(days=4, seconds=75168, microseconds=888889)),
#  ('Gangs Pride', datetime.timedelta(days=4, seconds=41962, microseconds=222222)),
#  ('Games Bowfinger', datetime.timedelta(days=3, seconds=76722, microseconds=857143)),
#  ('Sensibility Rear', datetime.timedelta(days=4, seconds=17472)),
#  ('Pluto Oleander', datetime.timedelta(days=4, seconds=20006, microseconds=250000)),
#  ('Homicide Peach', datetime.timedelta(days=4, seconds=18755, microseconds=454546)),
#  ('Kick Savannah', datetime.timedelta(days=4, seconds=56084, microseconds=210526)),
#  ('Ladybugs Armageddon', datetime.timedelta(days=5, seconds=55890)),
#  ('Darko Dorado', datetime.timedelta(days=5, seconds=23710, microseconds=909091)),
#  ('Lion Uncut', datetime.timedelta(days=5, seconds=29403, microseconds=333333)),
#  ('Creepers Kane', datetime.timedelta(days=4, seconds=18287, microseconds=142857)),
#  ('Superfly Trip', datetime.timedelta(days=3, seconds=67452)),
#  ('Song Hedwig', datetime.timedelta(days=5, seconds=636)),
#  ('President Bang', datetime.timedelta(days=4, seconds=35142, microseconds=857143)),
#  ('Loathing Legally', datetime.timedelta(days=5, seconds=4626, microseconds=923077)),
#  ('Northwest Polish', datetime.timedelta(days=5, seconds=82596)),
#  ('Gilmore Boiled', datetime.timedelta(days=5, seconds=22731, microseconds=428571)),
#  ('Tracy Cider', datetime.timedelta(days=5, seconds=15542, microseconds=307692)),
#  ('Doctor Grail', datetime.timedelta(days=5, seconds=16371, microseconds=428571)),
#  ('Wars Pluto', datetime.timedelta(days=5, seconds=45276)),
#  ('Jumanji Blade', datetime.timedelta(days=4, seconds=18742, microseconds=500000)),
#  ('Noon Papi', datetime.timedelta(days=5, seconds=24137, microseconds=647059)),
#  ('Drumline Cyclone', datetime.timedelta(days=5, seconds=21403, microseconds=636364)),
#  ('Bang Kwai', datetime.timedelta(days=4, seconds=48800)),
#  ('Disturbing Scarface', datetime.timedelta(days=4, seconds=44732, microseconds=307692)),
#  ('Vanished Garden', datetime.timedelta(days=6, seconds=11090)),
#  ('Robbery Bright', datetime.timedelta(days=5, seconds=9576, microseconds=923077)),
#  ('Dolls Rage', datetime.timedelta(days=6, seconds=24106, microseconds=666667)),
#  ('Borrowers Bedazzled', datetime.timedelta(days=5, seconds=54357, microseconds=272727)),
#  ('Tootsie Pilot', datetime.timedelta(days=4, seconds=20248)),
#  ('Spy Mile', datetime.timedelta(days=5, seconds=9204, microseconds=444444)),
#  ('Destiny Saturday', datetime.timedelta(days=4, seconds=12386, microseconds=250000)),
#  ('Operation Operation', datetime.timedelta(days=4, seconds=49742, microseconds=307692)),
#  ('Homeward Cider', datetime.timedelta(days=3, seconds=43931, microseconds=250000)),
#  ('Galaxy Sweethearts', datetime.timedelta(days=4, seconds=27863, microseconds=333333)),
#  ('Sorority Queen', datetime.timedelta(days=4, seconds=10225)),
#  ('Groundhog Uncut', datetime.timedelta(days=5, seconds=31432, microseconds=941177)),
#  ('Santa Paris', datetime.timedelta(days=4, seconds=85614, microseconds=545455)),
#  ('Pittsburgh Hunchback', datetime.timedelta(days=6, seconds=33460)),
#  ('Hyde Doctor', datetime.timedelta(days=4, seconds=23532)),
#  ('Open African', datetime.timedelta(days=4, seconds=69200)),
#  ('Jacket Frisco', datetime.timedelta(days=4, seconds=78966, microseconds=666667)),
#  ('Untouchables Sunrise', datetime.timedelta(days=5, seconds=46357, microseconds=500000)),
#  ('Sugar Wonka', datetime.timedelta(days=3, seconds=59523, microseconds=529412)),
#  ('English Bulworth', datetime.timedelta(days=5, seconds=10600)),
#  ('Videotape Arsenic', datetime.timedelta(days=4, seconds=34994, microseconds=482759)),
#  ('Chill Luck', datetime.timedelta(days=4, seconds=78076, microseconds=363637)),
#  ('Packer Madigan', datetime.timedelta(days=4, seconds=33649, microseconds=90909)),
#  ('Metropolis Coma', datetime.timedelta(days=5, seconds=31684, microseconds=615385)),
#  ('Chainsaw Uptown', datetime.timedelta(days=4, seconds=65305, microseconds=714286)),
#  ('Divide Monster', datetime.timedelta(days=4, seconds=54560)),
#  ('Roots Remember', datetime.timedelta(days=5, seconds=5604, microseconds=705883)),
#  ('Autumn Crow', datetime.timedelta(days=5, seconds=16020)),
#  ('Frost Head', datetime.timedelta(days=5, seconds=51258, microseconds=620690)),
#  ('Saints Bride', datetime.timedelta(days=4, seconds=60330)),
#  ('Lucky Flying', datetime.timedelta(days=5, seconds=1989, microseconds=230770)),
#  ('Caddyshack Jedi', datetime.timedelta(days=4, seconds=55522, microseconds=500000)),
#  ('Airport Pollock', datetime.timedelta(days=5, seconds=4870)),
#  ('Happiness United', datetime.timedelta(days=5, seconds=204)),
#  ('Express Lonely', datetime.timedelta(days=4, seconds=17220)),
#  ('Date Speed', datetime.timedelta(days=5, seconds=72595, microseconds=384616)),
#  ('Thief Pelican', datetime.timedelta(days=5, seconds=21082, microseconds=105264)),
#  ('Moonshine Cabin', datetime.timedelta(days=5, seconds=11611, microseconds=428572)),
#  ('Submarine Bed', datetime.timedelta(days=4, seconds=22664)),
#  ('Clerks Angels', datetime.timedelta(days=5, seconds=17777, microseconds=142857)),
#  ('Unforgiven Zoolander', datetime.timedelta(days=5, seconds=35796, microseconds=666667)),
#  ('Amadeus Holy', datetime.timedelta(days=4, seconds=79851)),
#  ('Musketeers Wait', datetime.timedelta(days=4, seconds=52401, microseconds=176470)),
#  ('Malkovich Pet', datetime.timedelta(days=4, seconds=23990, microseconds=769230)),
#  ('Heavenly Gun', datetime.timedelta(days=5, seconds=25028, microseconds=571428)),
#  ('Chaplin License', datetime.timedelta(days=4, seconds=21645)),
#  ('Anything Savannah', datetime.timedelta(days=5, seconds=45626, microseconds=666667)),
#  ('Elizabeth Shane', datetime.timedelta(days=4, seconds=63504)),
#  ('Outlaw Hanky', datetime.timedelta(days=4, seconds=79624, microseconds=615385)),
#  ('Blues Instinct', datetime.timedelta(days=4, seconds=51728, microseconds=571428)),
#  ('Maiden Home', datetime.timedelta(days=4, seconds=49352, microseconds=500000)),
#  ('Torque Bound', datetime.timedelta(days=4, seconds=79121, microseconds=538462)),
#  ('Airplane Sierra', datetime.timedelta(days=4, seconds=50284)),
#  ('Weekend Personal', datetime.timedelta(days=4, seconds=81426, microseconds=666667)),
#  ('Werewolf Lola', datetime.timedelta(days=4, seconds=84608, microseconds=571428)),
#  ('Hellfighters Sierra', datetime.timedelta(days=4, seconds=23856)),
#  ('Bucket Brotherhood', datetime.timedelta(days=4, seconds=81945, microseconds=882353)),
#  ('School Jacket', datetime.timedelta(days=5, seconds=17400)),
#  ('Bear Graceland', datetime.timedelta(days=5, seconds=42908, microseconds=181818)),
#  ('Strangers Graffiti', datetime.timedelta(days=5, seconds=59011, microseconds=764706)),
#  ('Zhivago Core', datetime.timedelta(days=5, seconds=82087, microseconds=500000)),
#  ('Inch Jet', datetime.timedelta(days=4, seconds=54503, microseconds=333333)),
#  ('Driver Annie', datetime.timedelta(days=3, seconds=81391, microseconds=764706)),
#  ('Tourist Pelican', datetime.timedelta(days=4, seconds=84482, microseconds=727272)),
#  ('Beneath Rush', datetime.timedelta(days=4, seconds=40098)),
#  ('Goodfellas Salute', datetime.timedelta(days=5, seconds=18994, microseconds=838710)),
#  ('Conquerer Nuts', datetime.timedelta(days=4, seconds=26403, microseconds=750000)),
#  ('Polish Brooklyn', datetime.timedelta(days=4, seconds=72090)),
#  ('Elf Murder', datetime.timedelta(days=3, seconds=45342, microseconds=857143)),
#  ('Japanese Run', datetime.timedelta(days=4, seconds=21080)),
#  ('Stagecoach Armageddon', datetime.timedelta(days=4, seconds=78106, microseconds=153846)),
#  ('Hanover Galaxy', datetime.timedelta(days=4, seconds=38558, microseconds=823530)),
#  ('Italian African', datetime.timedelta(days=4, seconds=21330)),
#  ('Amistad Midsummer', datetime.timedelta(days=4, seconds=49791)),
#  ('League Hellfighters', datetime.timedelta(days=5, seconds=23230, microseconds=588235)),
#  ('Fever Empire', datetime.timedelta(days=5, seconds=65292)),
#  ('Trip Newton', datetime.timedelta(days=4, seconds=16275)),
#  ('Reign Gentlemen', datetime.timedelta(days=5, seconds=41091)),
#  ('Flatliners Killer', datetime.timedelta(days=5, seconds=20198, microseconds=181818)),
#  ('Spinal Rocky', datetime.timedelta(days=5, seconds=62303, microseconds=76923)),
#  ('Early Home', datetime.timedelta(days=6, seconds=7800)),
#  ('Clockwork Paradise', datetime.timedelta(days=5, seconds=6192)),
#  ('Jet Neighbors', datetime.timedelta(days=6, seconds=5430)),
#  ('Breakfast Goldfinger', datetime.timedelta(days=5, seconds=40447, microseconds=58823)),
#  ('Sunrise League', datetime.timedelta(days=4, seconds=73222, microseconds=500000)),
#  ('Paradise Sabrina', datetime.timedelta(days=5, seconds=25270)),
#  ('Speakeasy Date', datetime.timedelta(days=5, seconds=20180)),
#  ('Wash Heavenly', datetime.timedelta(days=4, seconds=56120, microseconds=869566)),
#  ('Tights Dawn', datetime.timedelta(days=5, seconds=21846, microseconds=923077)),
#  ('Backlash Undefeated', datetime.timedelta(days=6, seconds=17283, microseconds=157895)),
#  ('Sea Virgin', datetime.timedelta(days=4, seconds=64412, microseconds=727273)),
#  ('Legend Jedi', datetime.timedelta(days=6, seconds=1693, microseconds=333333)),
#  ('Control Anthem', datetime.timedelta(days=5, seconds=22851, microseconds=428571)),
#  ('Cider Desire', datetime.timedelta(days=5, seconds=22708, microseconds=421053)),
#  ('Prix Undefeated', datetime.timedelta(days=3, seconds=58009, microseconds=90909)),
#  ('Behavior Runaway', datetime.timedelta(days=5, seconds=28283, microseconds=76923)),
#  ('Dances None', datetime.timedelta(days=4, seconds=14180)),
#  ('Downhill Enough', datetime.timedelta(days=5, seconds=15576)),
#  ('Fargo Gandhi', datetime.timedelta(days=4, seconds=14470)),
#  ('Gandhi Kwai', datetime.timedelta(days=5, seconds=29244, microseconds=705882)),
#  ('Fiddler Lost', datetime.timedelta(days=4, seconds=69534)),
#  ('Rules Human', datetime.timedelta(days=6, seconds=45543, microseconds=750000)),
#  ('Super Wyoming', datetime.timedelta(days=6, seconds=4453, microseconds=846154)),
#  ('Aladdin Calendar', datetime.timedelta(days=4, seconds=69054, microseconds=782609)),
#  ('Magic Mallrats', datetime.timedelta(days=4, seconds=4611, microseconds=428571)),
#  ('Exorcist Sting', datetime.timedelta(days=5, seconds=20427, microseconds=692307)),
#  ('Harry Idaho', datetime.timedelta(days=5, seconds=46291, microseconds=34483)),
#  ('Basic Easy', datetime.timedelta(days=4, seconds=56415)),
# ...
#  ('Kramer Chocolate', datetime.timedelta(days=4, seconds=78513, microseconds=333333)),
#  ('Pinocchio Simon', datetime.timedelta(days=5, seconds=8838)),
#  ('Maguire Apache', datetime.timedelta(days=5, seconds=45100)),
#  ('Wolves Desire', datetime.timedelta(days=4, seconds=2357, microseconds=142857)),
#  ('Wyoming Storm', datetime.timedelta(days=4, seconds=48632, microseconds=307692)),
#  ('Carrie Bunch', datetime.timedelta(days=4, seconds=66080, microseconds=869566)),
#  ('Jeopardy Encino', datetime.timedelta(days=4, seconds=42288)),
#  ('Labyrinth League', datetime.timedelta(days=4, seconds=15460)),
#  ('Juggler Hardly', datetime.timedelta(days=5, seconds=44055, microseconds=483871)),
#  ('Brotherhood Blanket', datetime.timedelta(days=5, seconds=61451, microseconds=538461)),
#  ('Poseidon Forever', datetime.timedelta(days=5, seconds=32100)),
#  ('Texas Watch', datetime.timedelta(days=3, seconds=1440)),
#  ('Women Dorado', datetime.timedelta(days=4, seconds=12954, microseconds=545454)),
#  ('Strictly Scarface', datetime.timedelta(days=4, seconds=55338, microseconds=260870)),
#  ('Charade Duffel', datetime.timedelta(days=5, seconds=10196)),
#  ('Summer Scarface', datetime.timedelta(days=5, seconds=9144)),
#  ('Lolita World', datetime.timedelta(days=5, seconds=38088)),
#  ('Mile Mulan', datetime.timedelta(days=5, seconds=60687, microseconds=692307)),
#  ('Cleopatra Devil', datetime.timedelta(days=6, seconds=67, microseconds=58823)),
#  ('Rocky War', datetime.timedelta(days=4, seconds=76031, microseconds=250000)),
#  ('Kiss Glory', datetime.timedelta(days=5, seconds=6000)),
#  ('Pride Alamo', datetime.timedelta(days=3, seconds=28480)),
#  ('Jedi Beneath', datetime.timedelta(days=4, seconds=53990, microseconds=526316)),
#  ('Ridgemont Submarine', datetime.timedelta(days=6, seconds=942, microseconds=580645)),
#  ('Redemption Comforts', datetime.timedelta(days=5, seconds=18714)),
#  ('Chariots Conspiracy', datetime.timedelta(days=4, seconds=9745, microseconds=714286)),
#  ('Informer Double', datetime.timedelta(days=3, seconds=34092)),
#  ('Scarface Bang', datetime.timedelta(days=4, seconds=36017, microseconds=647059)),
#  ('Titanic Boondock', datetime.timedelta(days=4, seconds=58451, microseconds=428571)),
#  ('Interview Liaisons', datetime.timedelta(days=4, seconds=59718)),
#  ('Smoochy Control', datetime.timedelta(days=5, seconds=3943, microseconds=636363)),
#  ('Runner Madigan', datetime.timedelta(days=4, seconds=487, microseconds=500000)),
#  ('Steers Armageddon', datetime.timedelta(days=5, seconds=5344)),
#  ('Range Moonwalker', datetime.timedelta(days=4, seconds=11075, microseconds=555556)),
#  ('Remember Diary', datetime.timedelta(days=4, seconds=84393, microseconds=333333)),
#  ('Wild Apollo', datetime.timedelta(days=5, seconds=3492)),
#  ('Go Purple', datetime.timedelta(days=4, seconds=41127)),
#  ('Jekyll Frogmen', datetime.timedelta(days=5, seconds=12109, microseconds=411765)),
#  ('Pet Haunting', datetime.timedelta(days=5, seconds=11017, microseconds=500000)),
#  ('Opposite Necklace', datetime.timedelta(days=4, seconds=50975)),
#  ('Scalawag Duck', datetime.timedelta(days=4, seconds=6016, microseconds=875000)),
#  ('Enemy Odds', datetime.timedelta(days=4, seconds=78914, microseconds=482759)),
#  ('Camelot Vacation', datetime.timedelta(days=5, seconds=47420, microseconds=769231)),
#  ('Illusion Amelie', datetime.timedelta(days=4, seconds=81680)),
#  ('Bingo Talented', datetime.timedelta(days=5, seconds=60995, microseconds=172414)),
#  ('Twisted Pirates', datetime.timedelta(days=4, seconds=9065, microseconds=454546)),
#  ('Gold River', datetime.timedelta(days=5, seconds=15124, microseconds=285715)),
#  ('Miracle Virtual', datetime.timedelta(days=4, seconds=59986, microseconds=666667)),
#  ('Dude Blindness', datetime.timedelta(days=4, seconds=26786, microseconds=250000)),
#  ('Undefeated Dalmations', datetime.timedelta(days=4, seconds=58094, microseconds=285715)),
#  ('Kwai Homeward', datetime.timedelta(days=5, seconds=29066, microseconds=86956)),
#  ('Campus Remember', datetime.timedelta(days=6, seconds=13405, microseconds=263158)),
#  ('Insider Arizona', datetime.timedelta(days=4, seconds=2453, microseconds=333333)),
#  ('Baby Hall', datetime.timedelta(days=4, seconds=66847, microseconds=500000)),
#  ('Jerk Paycheck', datetime.timedelta(days=5, seconds=18585)),
#  ('Killer Innocent', datetime.timedelta(days=6, seconds=42620)),
#  ('Sassy Packer', datetime.timedelta(days=4, seconds=59058, microseconds=461539)),
#  ('Sleepy Japanese', datetime.timedelta(days=5, seconds=14724)),
#  ('Blanket Beverly', datetime.timedelta(days=6, seconds=13232, microseconds=727272)),
#  ('Platoon Instinct', datetime.timedelta(days=3, seconds=35606, microseconds=666667)),
#  ('Chicken Hellfighters', datetime.timedelta(days=4, seconds=54100, microseconds=909091)),
#  ('Pulp Beverly', datetime.timedelta(days=5, seconds=8273, microseconds=793104)),
#  ('Quills Bull', datetime.timedelta(days=4, seconds=39101, microseconds=250000)),
#  ('Shrunk Divine', datetime.timedelta(days=5, seconds=52461, microseconds=428571)),
#  ('Dragonfly Strangers', datetime.timedelta(days=4, seconds=71368, microseconds=235294)),
#  ('Lady Stage', datetime.timedelta(days=5, seconds=32865)),
#  ('Virgin Daisy', datetime.timedelta(days=4, seconds=83721, microseconds=176471)),
#  ('Gorgeous Bingo', datetime.timedelta(days=6, seconds=44316, microseconds=666667)),
#  ('Storm Happiness', datetime.timedelta(days=4, seconds=70382, microseconds=68966)),
#  ('Stock Glass', datetime.timedelta(days=3, seconds=56417, microseconds=142857)),
#  ('Sinners Atlantis', datetime.timedelta(days=5, seconds=31606, microseconds=363636)),
#  ('Monterey Labyrinth', datetime.timedelta(days=4, seconds=918, microseconds=461539)),
#  ('Hours Rage', datetime.timedelta(days=4, seconds=84918, microseconds=947369)),
#  ('Driving Polish', datetime.timedelta(days=4, seconds=73742, microseconds=857143)),
#  ('Grease Youth', datetime.timedelta(days=4, seconds=17797, microseconds=142857)),
#  ('West Lion', datetime.timedelta(days=4, seconds=86272, microseconds=500000)),
#  ('Ghost Groundhog', datetime.timedelta(days=5, seconds=35358)),
#  ('Snatch Slipper', datetime.timedelta(days=5, seconds=59059, microseconds=90909)),
#  ('Horn Working', datetime.timedelta(days=4, seconds=48180)),
#  ('Lovely Jingle', datetime.timedelta(days=4, seconds=39392, microseconds=307692)),
#  ('Hawk Chill', datetime.timedelta(days=5, seconds=2202, microseconds=857142)),
#  ('Terminator Club', datetime.timedelta(days=6, seconds=14560)),
#  ('Rushmore Mermaid', datetime.timedelta(days=3, seconds=24470)),
#  ('Deer Virginian', datetime.timedelta(days=5, seconds=38597, microseconds=142857)),
#  ('Alter Victory', datetime.timedelta(days=4, seconds=54422, microseconds=727273)),
#  ('Darkness War', datetime.timedelta(days=5, seconds=63909, microseconds=230769)),
#  ('Mother Oleander', datetime.timedelta(days=6, seconds=63214, microseconds=285714)),
#  ('Falcon Volume', datetime.timedelta(days=4, seconds=63588, microseconds=571429)),
#  ('Shanghai Tycoon', datetime.timedelta(days=3, seconds=82307, microseconds=142857)),
#  ('Attacks Hate', datetime.timedelta(days=5, seconds=64890)),
#  ('Paycheck Wait', datetime.timedelta(days=4, seconds=61308, microseconds=750000)),
#  ('Rider Caddyshack', datetime.timedelta(days=5, seconds=64456, microseconds=363637)),
#  ('Drifter Commandments', datetime.timedelta(days=4, seconds=50752, microseconds=173913)),
#  ('Swarm Gold', datetime.timedelta(days=4, seconds=82913, microseconds=76923)),
#  ('Married Go', datetime.timedelta(days=4, seconds=69726)),
#  ('Badman Dawn', datetime.timedelta(days=4, seconds=47231, microseconds=428572)),
#  ('License Weekend', datetime.timedelta(days=3, seconds=58114, microseconds=285714)),
#  ('United Pilot', datetime.timedelta(days=5, seconds=5378, microseconds=823530)),
#  ('Scorpion Apollo', datetime.timedelta(days=4, seconds=80188, microseconds=695652)),
#  ('Atlantis Cause', datetime.timedelta(days=4, seconds=61870)),
#  ('Timberland Sky', datetime.timedelta(days=5, seconds=70101, microseconds=290323)),
#  ('Feud Frogmen', datetime.timedelta(days=4, seconds=51146, microseconds=400000)),
#  ('Reservoir Adaptation', datetime.timedelta(days=6, seconds=3888)),
#  ('Celebrity Horn', datetime.timedelta(days=5, seconds=28890)),
#  ('Mystic Truman', datetime.timedelta(days=4, seconds=77280)),
#  ('Holy Tadpole', datetime.timedelta(days=5, seconds=41640)),
#  ('Straight Hours', datetime.timedelta(days=4, seconds=29496)),
#  ('Goldmine Tycoon', datetime.timedelta(days=5, seconds=33004, microseconds=444444)),
#  ('Punk Divorce', datetime.timedelta(days=4, seconds=48510)),
#  ('Oklahoma Jumanji', datetime.timedelta(days=5, seconds=5460)),
#  ('Extraordinary Conquerer', datetime.timedelta(days=5, seconds=16970)),
#  ('Godfather Diary', datetime.timedelta(days=4, seconds=49215)),
#  ('Liaisons Sweet', datetime.timedelta(days=4, seconds=50555, microseconds=454545)),
#  ('Chasing Fight', datetime.timedelta(days=5, seconds=52443, microseconds=157895)),
#  ('Others Soup', datetime.timedelta(days=4, seconds=83055, microseconds=652173)),
#  ('Wagon Jaws', datetime.timedelta(days=6, seconds=64554)),
#  ('Hobbit Alien', datetime.timedelta(days=5, seconds=61923, microseconds=870968)),
#  ('Anonymous Human', datetime.timedelta(days=4, seconds=73656, microseconds=923077)),
#  ('Gone Trouble', datetime.timedelta(days=6, seconds=11034)),
#  ('Metal Armageddon', datetime.timedelta(days=6, seconds=5628)),
#  ('Grapes Fury', datetime.timedelta(days=4, seconds=24374, microseconds=285715)),
#  ('Goldfinger Sensibility', datetime.timedelta(days=5, seconds=17030)),
#  ('Sting Personal', datetime.timedelta(days=5, seconds=16602, microseconds=857143)),
#  ('Whisperer Giant', datetime.timedelta(days=5, seconds=51000)),
#  ('Craft Outfield', datetime.timedelta(days=4, seconds=11782, microseconds=500000)),
#  ('Dogma Family', datetime.timedelta(days=4, seconds=65340)),
#  ('Cranes Reservoir', datetime.timedelta(days=5, seconds=7445, microseconds=454546)),
#  ('Salute Apollo', datetime.timedelta(days=4, seconds=60221, microseconds=739131)),
#  ('Frogmen Breaking', datetime.timedelta(days=5, seconds=12996)),
#  ('Spoilers Hellfighters', datetime.timedelta(days=4, seconds=29610)),
#  ('Towers Hurricane', datetime.timedelta(days=4, seconds=1254, microseconds=545455)),
#  ('Potluck Mixed', datetime.timedelta(days=4, seconds=16500)),
#  ('Intentions Empire', datetime.timedelta(days=4, seconds=45620)),
#  ('Gilbert Pelican', datetime.timedelta(days=6, seconds=56680)),
#  ('Durham Panky', datetime.timedelta(days=4, seconds=55636, microseconds=153846)),
#  ('Blood Argonauts', datetime.timedelta(days=5, seconds=58134)),
#  ('Comforts Rush', datetime.timedelta(days=4, seconds=46203, microseconds=529412)),
#  ('Movie Shakespeare', datetime.timedelta(days=4, seconds=78934, microseconds=615385)),
#  ('House Dynamite', datetime.timedelta(days=4, seconds=60602, microseconds=608696)),
#  ('Saddle Antitrust', datetime.timedelta(days=4, seconds=86378, microseconds=571429)),
#  ('Madigan Dorado', datetime.timedelta(days=5, seconds=9330)),
#  ('Caper Motions', datetime.timedelta(days=4, seconds=45950)),
#  ('Panky Submarine', datetime.timedelta(days=6, seconds=30428)),
#  ('Side Ark', datetime.timedelta(days=6, seconds=7895)),
#  ('Stranger Strangers', datetime.timedelta(days=4, seconds=33703, microseconds=636364)),
#  ('Raging Airplane', datetime.timedelta(days=4, seconds=67832, microseconds=307692)),
#  ('Confessions Maguire', datetime.timedelta(days=5, seconds=4534, microseconds=285715)),
#  ('Monster Spartacus', datetime.timedelta(days=5, seconds=2772, microseconds=857143)),
#  ('Connection Microcosmos', datetime.timedelta(days=5, seconds=1450)),
#  ('Handicap Boondock', datetime.timedelta(days=4, seconds=53389, microseconds=285714)),
#  ('Duck Racer', datetime.timedelta(days=4, seconds=18490)),
#  ('Madison Trap', datetime.timedelta(days=5, seconds=78160)),
#  ('State Wasteland', datetime.timedelta(days=5, seconds=45155)),
#  ('Confused Candles', datetime.timedelta(days=5, seconds=73722, microseconds=352941)),
#  ('Muscle Bright', datetime.timedelta(days=4, seconds=23348)),
#  ('Hollow Jeopardy', datetime.timedelta(days=4, seconds=26556)),
#  ('Clash Freddy', datetime.timedelta(days=5, seconds=4212)),
#  ('Elephant Trojan', datetime.timedelta(days=4, seconds=53558, microseconds=571428)),
#  ('Sundance Invasion', datetime.timedelta(days=5, seconds=1913, microseconds=333333)),
#  ('Idols Snatchers', datetime.timedelta(days=4, seconds=58488)),
#  ('Snowman Rollercoaster', datetime.timedelta(days=4, seconds=81182, microseconds=608695)),
#  ('Conspiracy Spirit', datetime.timedelta(days=4, seconds=864)),
#  ('Freaky Pocus', datetime.timedelta(days=3, seconds=71297, microseconds=647059)),
#  ('Soup Wisdom', datetime.timedelta(days=4, seconds=15930)),
#  ('Notting Speakeasy', datetime.timedelta(days=4, seconds=79584)),
#  ('Story Side', datetime.timedelta(days=4, seconds=36672, microseconds=857142)),
#  ('Ending Crowds', datetime.timedelta(days=4, seconds=54730, microseconds=909091)),
#  ('Mulholland Beast', datetime.timedelta(days=4, seconds=73760)),
#  ('Calendar Gunfight', datetime.timedelta(days=5, seconds=6245, microseconds=714286)),
#  ('Birds Perdition', datetime.timedelta(days=4, seconds=59600)),
#  ('Destination Jerk', datetime.timedelta(days=5, seconds=69682, microseconds=500000)),
#  ('Smile Earring', datetime.timedelta(days=6, seconds=61062)),
#  ('Maude Mod', datetime.timedelta(days=4, seconds=60420)),
#  ('Party Knock', datetime.timedelta(days=5, seconds=18895, microseconds=384616)),
#  ('Dying Maker', datetime.timedelta(days=4, seconds=7778, microseconds=823529)),
#  ('Fugitive Maguire', datetime.timedelta(days=4, seconds=2863, microseconds=636364)),
#  ('Tomorrow Hustler', datetime.timedelta(days=4, seconds=17239, microseconds=200000)),
#  ('Doubtfire Labyrinth', datetime.timedelta(days=4, seconds=29118)),
#  ('Full Flatliners', datetime.timedelta(days=3, seconds=66300)),
#  ('Park Citizen', datetime.timedelta(days=5, seconds=9585)),
#  ('Savannah Town', datetime.timedelta(days=5, seconds=27025)),
#  ('Dynamite Tarzan', datetime.timedelta(days=4, seconds=56452, microseconds=800000)),
#  ('Virginian Pluto', datetime.timedelta(days=4, seconds=33201, microseconds=428571)),
#  ('Expecations Natural', datetime.timedelta(days=5, seconds=25373, microseconds=333333)),
#  ('North Tequila', datetime.timedelta(days=3, seconds=85025, microseconds=454545)),
#  ('Oleander Clue', datetime.timedelta(days=6, seconds=47094)),
#  ('Anaconda Confessions', datetime.timedelta(days=4, seconds=38468, microseconds=571428)),
#  ('Chicago North', datetime.timedelta(days=5, seconds=45060)),
#  ('Circus Youth', datetime.timedelta(days=5, seconds=7032)),
#  ('Secret Groundhog', datetime.timedelta(days=4, seconds=65417, microseconds=142857)),
#  ('Murder Antitrust', datetime.timedelta(days=5, seconds=21790, microseconds=434783)),
#  ('Nemo Campus', datetime.timedelta(days=4, seconds=55354, microseconds=285715)),
#  ('Beauty Grease', datetime.timedelta(days=4, seconds=69894, microseconds=545454)),
#  ('Slipper Fidelity', datetime.timedelta(days=5, seconds=5370)),
#  ('Road Roxanne', datetime.timedelta(days=5, seconds=23210, microseconds=526316)),
#  ('Right Cranes', datetime.timedelta(days=5, seconds=1200)),
#  ('Intolerable Intentions', datetime.timedelta(days=4, seconds=57546, microseconds=666667)),
#  ('River Outlaw', datetime.timedelta(days=5, seconds=40822, microseconds=105263)),
#  ('Idaho Love', datetime.timedelta(days=4, seconds=3921, microseconds=176471)),
#  ('Detective Vision', datetime.timedelta(days=5, seconds=20010)),
#  ('Balloon Homeward', datetime.timedelta(days=5, seconds=51665, microseconds=217391)),
#  ('Christmas Moonshine', datetime.timedelta(days=5, seconds=35305, microseconds=714286)),
#  ('Lover Truman', datetime.timedelta(days=6, seconds=3156)),
#  ('Mockingbird Hollywood', datetime.timedelta(days=4, seconds=78367, microseconds=826087)),
#  ('Gathering Calendar', datetime.timedelta(days=4, seconds=23509, microseconds=90909)),
#  ('Drums Dynamite', datetime.timedelta(days=5, seconds=74884, microseconds=615385)),
#  ('Samurai Lion', datetime.timedelta(days=5, seconds=32824, microseconds=800000)),
#  ('Pond Seattle', datetime.timedelta(days=5, seconds=48612, microseconds=631579))]

# %% [markdown]
# # 9
#
# ### List the film title and the number of times it has been rented in each city (name and country).

# %%
# %%sql
# EXPLAIN
# SELECT title, city, country, count(*)
# FROM film JOIN inventory
# ON film.film_id = inventory.film_id
# JOIN rental
# ON inventory.inventory_id = rental.inventory_id
# JOIN customer
# ON customer.customer_id = rental.customer_id
# JOIN address
# ON customer.address_id = address.address_id
# JOIN city
# ON address.city_id = city.city_id
# JOIN country
# ON country.country_id = city.country_id
# GROUP BY title, city, country   ;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 27 rows affected.
# [('HashAggregate  (cost=996.90..1157.34 rows=16044 width=41)',),
#  ('  Group Key: film.title, city.city, country.country',),
#  ('  ->  Hash Join  (cost=270.57..836.46 rows=16044 width=33)',),
#  ('        Hash Cond: (city.country_id = country.country_id)',),
#  ('        ->  Hash Join  (cost=267.12..789.26 rows=16044 width=26)',),
#  ('              Hash Cond: (address.city_id = city.city_id)',),
#  ('              ->  Hash Join  (cost=248.62..728.34 rows=16044 width=17)',),
#  ('                    Hash Cond: (customer.address_id = address.address_id)',),
#  ('                    ->  Hash Join  (cost=227.05..664.36 rows=16044 width=17)',),
#  ('                          Hash Cond: (rental.customer_id = customer.customer_id)',),
#  ('                          ->  Hash Join  (cost=204.57..599.47 rows=16044 width=17)',),
#  ('                                Hash Cond: (inventory.film_id = film.film_id)',),
#  ('                                ->  Hash Join  (cost=128.07..480.67 rows=16044 width=4)',),
#  ('                                      Hash Cond: (rental.inventory_id = inventory.inventory_id)',),
#  ('                                      ->  Seq Scan on rental  (cost=0.00..310.44 rows=16044 width=6)',),
#  ('                                      ->  Hash  (cost=70.81..70.81 rows=4581 width=6)',),
#  ('                                            ->  Seq Scan on inventory  (cost=0.00..70.81 rows=4581 width=6)',),
#  ('                                ->  Hash  (cost=64.00..64.00 rows=1000 width=19)',),
#  ('                                      ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=19)',),
#  ('                          ->  Hash  (cost=14.99..14.99 rows=599 width=6)',),
#  ('                                ->  Seq Scan on customer  (cost=0.00..14.99 rows=599 width=6)',),
#  ('                    ->  Hash  (cost=14.03..14.03 rows=603 width=6)',),
#  ('                          ->  Seq Scan on address  (cost=0.00..14.03 rows=603 width=6)',),
#  ('              ->  Hash  (cost=11.00..11.00 rows=600 width=15)',),
#  ('                    ->  Seq Scan on city  (cost=0.00..11.00 rows=600 width=15)',),
#  ('        ->  Hash  (cost=2.09..2.09 rows=109 width=13)',),
#  ('              ->  Seq Scan on country  (cost=0.00..2.09 rows=109 width=13)',)]

# %%
# %%sql
# SELECT title, city, country, count(*)
# FROM film JOIN inventory
# ON film.film_id = inventory.film_id
# JOIN rental
# ON inventory.inventory_id = rental.inventory_id
# JOIN customer
# ON customer.customer_id = rental.customer_id
# JOIN address
# ON customer.address_id = address.address_id
# JOIN city
# ON address.city_id = city.city_id
# JOIN country
# ON country.country_id = city.country_id
# GROUP BY title, city, country  ;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 15827 rows affected.
# [('Greek Everyone', 'Tabuk', 'Saudi Arabia', 1),
#  ('Insider Arizona', 'Pak Kret', 'Thailand', 1),
#  ('Fiddler Lost', 'Kurashiki', 'Japan', 1),
#  ('Trap Guys', 'Atlixco', 'Mexico', 1),
#  ('Mosquito Armageddon', 'Sungai Petani', 'Malaysia', 1),
#  ('Fish Opus', 'Kilis', 'Turkey', 1),
#  ('Camelot Vacation', 'Cuautla', 'Mexico', 1),
#  ('Barbarella Streetcar', 'Uruapan', 'Mexico', 1),
#  ('Army Flintstones', 'Kurashiki', 'Japan', 1),
#  ('Wedding Apollo', 'Ciomas', 'Indonesia', 1),
#  ('Opus Ice', 'Maikop', 'Russian Federation', 1),
#  ('Maguire Apache', 'Chandrapur', 'India', 1),
#  ('High Encino', 'Tandil', 'Argentina', 1),
#  ('Brotherhood Blanket', 'Ivanovo', 'Russian Federation', 1),
#  ('Bugsy Song', 'Beni-Mellal', 'Morocco', 1),
#  ('Massacre Usual', 'Kansas City', 'United States', 1),
#  ('Detective Vision', 'Jamalpur', 'Bangladesh', 1),
#  ('Shrek License', 'Tsuyama', 'Japan', 1),
#  ('Amelie Hellfighters', 'Botshabelo', 'South Africa', 1),
#  ('Mummy Creatures', 'Valle de Santiago', 'Mexico', 1),
#  ('Zhivago Core', 'San Felipe de Puerto Plata', 'Dominican Republic', 1),
#  ('Homicide Peach', 'Hiroshima', 'Japan', 1),
#  ('Mod Secretary', 'Monclova', 'Mexico', 1),
#  ('Records Zorro', 'Molodetno', 'Belarus', 1),
#  ('Carol Texas', 'Peoria', 'United States', 1),
#  ('Darko Dorado', 'Brest', 'France', 1),
#  ('Storm Happiness', 'Yinchuan', 'China', 1),
#  ('Celebrity Horn', 'Fontana', 'United States', 1),
#  ('Grail Frankenstein', 'Gandhinagar', 'India', 1),
#  ('Butterfly Chocolat', 'Lengshuijiang', 'China', 1),
#  ('Goldmine Tycoon', 'Bchar', 'Algeria', 1),
#  ('Slacker Liaisons', 'Chisinau', 'Moldova', 1),
#  ('Unforgiven Zoolander', 'Ziguinchor', 'Senegal', 1),
#  ('African Egg', 'Rampur', 'India', 1),
#  ('Robbers Joon', 'Mexicali', 'Mexico', 1),
#  ('Oleander Clue', 'Davao', 'Philippines', 1),
#  ('Home Pity', 'Bamenda', 'Cameroon', 1),
#  ('Hanging Deep', 'Balaiha', 'Russian Federation', 1),
#  ('Candidate Perdition', 'Jining', 'China', 1),
#  ('Saturday Lambs', 'Tartu', 'Estonia', 1),
#  ('Murder Antitrust', 'Amersfoort', 'Netherlands', 1),
#  ('Name Detective', 'Zeleznogorsk', 'Russian Federation', 1),
#  ('Jaws Harry', 'Jhansi', 'India', 1),
#  ('Artist Coldblooded', 'Ogbomosho', 'Nigeria', 1),
#  ('Sugar Wonka', 'Kimchon', 'South Korea', 1),
#  ('Gun Bonnie', 'Esfahan', 'Iran', 1),
#  ('Half Outfield', 'Bijapur', 'India', 1),
#  ('Tuxedo Mile', 'Akron', 'United States', 1),
#  ('Pulp Beverly', 'Sorocaba', 'Brazil', 1),
#  ('Sweethearts Suspects', 'Ikerre', 'Nigeria', 1),
#  ('Moulin Wake', 'Hoshiarpur', 'India', 1),
#  ('Movie Shakespeare', 'Suihua', 'China', 1),
#  ('Baked Cleopatra', 'Vila Velha', 'Brazil', 1),
#  ('Ace Goldfinger', 'Soshanguve', 'South Africa', 1),
#  ('Story Side', 'A Corua (La Corua)', 'Spain', 1),
#  ('Timberland Sky', 'Vaduz', 'Liechtenstein', 1),
#  ('Horn Working', 'Tychy', 'Poland', 1),
#  ('English Bulworth', 'Kaliningrad', 'Russian Federation', 1),
#  ('Telemark Heartbreakers', 'Usolje-Sibirskoje', 'Russian Federation', 1),
#  ('Doubtfire Labyrinth', 'Kamjanets-Podilskyi', 'Ukraine', 1),
#  ('Beach Heartbreakers', 'Hsichuh', 'Taiwan', 1),
#  ('Lebowski Soldiers', 'Celaya', 'Mexico', 1),
#  ('Evolution Alter', 'Torren', 'Mexico', 1),
#  ('Uptown Young', 'Dayton', 'United States', 1),
#  ('Videotape Arsenic', 'Ogbomosho', 'Nigeria', 1),
#  ('Happiness United', 'Benin City', 'Nigeria', 1),
#  ('Paycheck Wait', 'Charlotte Amalie', 'Virgin Islands, U.S.', 1),
#  ('Velvet Terminator', 'Halisahar', 'India', 1),
#  ('Rocketeer Mother', 'Maring', 'Brazil', 2),
#  ('Gleaming Jawbreaker', 'al-Manama', 'Bahrain', 1),
#  ('Whisperer Giant', 'Halle/Saale', 'Germany', 2),
#  ('Gold River', 'Laredo', 'United States', 1),
#  ('Muscle Bright', 'Erlangen', 'Germany', 1),
#  ('Drop Waterfront', 'Nam Dinh', 'Vietnam', 1),
#  ('Closer Bang', 'Bhavnagar', 'India', 1),
#  ('Hanky October', 'Abha', 'Saudi Arabia', 1),
#  ('Darn Forrester', 'Ivanovo', 'Russian Federation', 1),
#  ('Liberty Magnificent', 'Alessandria', 'Italy', 1),
#  ('Shawshank Bubble', 'Zhoushan', 'China', 1),
#  ('Monterey Labyrinth', 'Ivanovo', 'Russian Federation', 1),
#  ('Telemark Heartbreakers', 'Saarbrcken', 'Germany', 1),
#  ('Enemy Odds', 'Uruapan', 'Mexico', 1),
#  ('Sierra Divide', 'Pathankot', 'India', 1),
#  ('Bringing Hysterical', 'El Alto', 'Bolivia', 1),
#  ('Rugrats Shakespeare', 'Omdurman', 'Sudan', 1),
#  ('Talented Homicide', 'Huaian', 'China', 1),
#  ('Texas Watch', 'So Bernardo do Campo', 'Brazil', 1),
#  ('Handicap Boondock', 'Tokat', 'Turkey', 1),
#  ('Disturbing Scarface', 'Urawa', 'Japan', 1),
#  ('Rugrats Shakespeare', 'Cam Ranh', 'Vietnam', 1),
#  ('Conquerer Nuts', 'Tambaram', 'India', 1),
#  ('Platoon Instinct', 'Koriyama', 'Japan', 1),
#  ('Telegraph Voyage', 'Mukateve', 'Ukraine', 1),
#  ('Movie Shakespeare', 'Koriyama', 'Japan', 1),
#  ('Caddyshack Jedi', 'Ktahya', 'Turkey', 1),
#  ('Entrapment Satisfaction', 'Sokoto', 'Nigeria', 1),
#  ('Network Peak', 'Fuyu', 'China', 1),
#  ('Spinal Rocky', 'Yaound', 'Cameroon', 1),
#  ('Durham Panky', 'Sorocaba', 'Brazil', 1),
#  ('Harper Dying', 'Juiz de Fora', 'Brazil', 1),
#  ('Attraction Newton', 'Batna', 'Algeria', 1),
#  ('Whale Bikini', 'Sal', 'Morocco', 1),
#  ('Panky Submarine', 'Jelets', 'Russian Federation', 1),
#  ('Patton Interview', 'Xinxiang', 'China', 1),
#  ('Groundhog Uncut', 'Laohekou', 'China', 1),
#  ('Arizona Bang', 'Hamilton', 'New Zealand', 1),
#  ('Sweethearts Suspects', 'Elista', 'Russian Federation', 1),
#  ('Metal Armageddon', 'Tongliao', 'China', 1),
#  ('Head Stranger', 'Nantou', 'Taiwan', 1),
#  ('Rider Caddyshack', 'Naju', 'South Korea', 1),
#  ('Window Side', 'Apeldoorn', 'Netherlands', 1),
#  ('Vacation Boondock', 'Benguela', 'Angola', 1),
#  ('Driver Annie', 'Coacalco de Berriozbal', 'Mexico', 1),
#  ('Jumping Wrath', 'Boa Vista', 'Brazil', 1),
#  ('Guys Falcon', 'Araatuba', 'Brazil', 1),
#  ('Matrix Snowman', 'Avellaneda', 'Argentina', 1),
#  ('Expecations Natural', 'Monclova', 'Mexico', 1),
#  ('South Wait', 'Osmaniye', 'Turkey', 1),
#  ('Valley Packer', 'Brescia', 'Italy', 1),
#  ('Straight Hours', 'Tanza', 'Philippines', 1),
#  ('Pollock Deliverance', 'Shikarpur', 'Pakistan', 1),
#  ('Gleaming Jawbreaker', 'Belm', 'Brazil', 1),
#  ('Uptown Young', 'Ogbomosho', 'Nigeria', 1),
#  ('Bull Shawshank', 'Vila Velha', 'Brazil', 1),
#  ('Detective Vision', 'Shimoga', 'India', 1),
#  ('Shakespeare Saddle', 'Belm', 'Brazil', 1),
#  ('Airport Pollock', 'Lublin', 'Poland', 1),
#  ('Camelot Vacation', 'Inegl', 'Turkey', 1),
#  ('Hall Cassidy', 'Lublin', 'Poland', 1),
#  ('Robbers Joon', 'Akron', 'United States', 1),
#  ('Cat Coneheads', 'Pudukkottai', 'India', 1),
#  ('Steers Armageddon', 'Abu Dhabi', 'United Arab Emirates', 1),
#  ('Horn Working', 'Kamarhati', 'India', 1),
#  ('Brotherhood Blanket', 'El Monte', 'United States', 1),
#  ('Silence Kane', 'Jastrzebie-Zdrj', 'Poland', 1),
#  ('Muscle Bright', 'Hamilton', 'New Zealand', 1),
#  ('Dogma Family', 'Santa Brbara dOeste', 'Brazil', 1),
#  ('Sleepy Japanese', 'Bilbays', 'Egypt', 1),
#  ('Bucket Brotherhood', 'Teboksary', 'Russian Federation', 1),
#  ('Deceiver Betrayed', 'Yuncheng', 'China', 1),
#  ('Desperate Trainspotting', 'Jaffna', 'Sri Lanka', 1),
#  ('Splendor Patton', 'Yangor', 'Nauru', 1),
#  ('Carrie Bunch', 'Valle de Santiago', 'Mexico', 1),
#  ('Philadelphia Wife', 'Sincelejo', 'Colombia', 1),
#  ('Mulholland Beast', 'Jedda', 'Saudi Arabia', 1),
#  ('Fargo Gandhi', 'Berhampore (Baharampur)', 'India', 1),
#  ('Newton Labyrinth', 'Isesaki', 'Japan', 1),
#  ('Purple Movie', 'Usolje-Sibirskoje', 'Russian Federation', 1),
#  ('Simon North', 'Kumbakonam', 'India', 1),
#  ('Scorpion Apollo', 'Lincoln', 'United States', 1),
#  ('Stagecoach Armageddon', 'Linz', 'Austria', 1),
#  ('Tourist Pelican', 'Dos Quebradas', 'Colombia', 1),
#  ('Smoking Barbarella', 'Bhopal', 'India', 1),
#  ('Daddy Pittsburgh', 'Cabuyao', 'Philippines', 1),
#  ('Excitement Eve', 'Toulon', 'France', 1),
#  ('Mussolini Spoilers', 'Bamenda', 'Cameroon', 1),
#  ('Working Microcosmos', 'Bilbays', 'Egypt', 1),
#  ('Side Ark', 'Baha Blanca', 'Argentina', 1),
#  ('Confused Candles', 'Boa Vista', 'Brazil', 1),
#  ('Creatures Shakespeare', 'Lancaster', 'United States', 1),
#  ('Scarface Bang', 'Peoria', 'United States', 1),
#  ('Hobbit Alien', 'Hidalgo', 'Mexico', 1),
#  ('Empire Malkovich', 'Toulon', 'France', 1),
#  ('Troopers Metal', 'Sanya', 'China', 1),
#  ('Autumn Crow', 'Blumenau', 'Brazil', 1),
#  ('Eyes Driving', 'Skikda', 'Algeria', 1),
#  ('Intentions Empire', 'Rockford', 'United States', 1),
#  ('Tarzan Videotape', 'Cavite', 'Philippines', 1),
#  ('Trap Guys', 'Omdurman', 'Sudan', 1),
#  ('Dogma Family', 'Greensboro', 'United States', 1),
#  ('Exorcist Sting', 'Allende', 'Mexico', 1),
#  ('Shakespeare Saddle', 'Teboksary', 'Russian Federation', 1),
#  ('Date Speed', 'Nantou', 'Taiwan', 1),
#  ('Lawless Vision', 'Usolje-Sibirskoje', 'Russian Federation', 1),
#  ('National Story', 'Citt del Vaticano', 'Holy See (Vatican City State)', 1),
#  ('Tracy Cider', 'Buenaventura', 'Colombia', 1),
#  ('Sweethearts Suspects', 'Mexicali', 'Mexico', 1),
#  ('Deceiver Betrayed', 'Rustenburg', 'South Africa', 1),
#  ('Forrester Comancheros', 'Daxian', 'China', 1),
#  ('Maiden Home', 'Purnea (Purnia)', 'India', 1),
#  ('Double Wrath', 'Ocumare del Tuy', 'Venezuela', 1),
#  ('Miracle Virtual', 'Leshan', 'China', 1),
#  ('Intentions Empire', 'Balurghat', 'India', 1),
#  ('Kissing Dolls', 'Portoviejo', 'Ecuador', 1),
#  ('Gorgeous Bingo', 'Amroha', 'India', 1),
#  ('California Birds', 'Lhokseumawe', 'Indonesia', 1),
#  ('Remember Diary', 'Pontianak', 'Indonesia', 1),
#  ('Finding Anaconda', 'Nabereznyje Telny', 'Russian Federation', 1),
#  ('Submarine Bed', 'Ilorin', 'Nigeria', 1),
#  ('Amistad Midsummer', 'Avellaneda', 'Argentina', 1),
#  ('Tomatoes Hellfighters', 'San Juan Bautista Tuxtepec', 'Mexico', 1),
#  ('Pure Runner', 'Skikda', 'Algeria', 1),
#  ('Ridgemont Submarine', 'Brest', 'France', 1),
#  ('Lonely Elephant', 'Guaruj', 'Brazil', 1),
#  ('Apache Divine', 'Okinawa', 'Japan', 1),
#  ('Wolves Desire', 'Loja', 'Ecuador', 1),
#  ('Harry Idaho', 'El Fuerte', 'Mexico', 1),
#  ('Roman Punk', 'Balikesir', 'Turkey', 1),
#  ('Escape Metropolis', 'Huixquilucan', 'Mexico', 1),
#  ('Pride Alamo', 'Vancouver', 'Canada', 1),
#  ('Lucky Flying', 'Naala-Porto', 'Mozambique', 1),
#  ('Handicap Boondock', 'Ocumare del Tuy', 'Venezuela', 1),
#  ('Durham Panky', 'Siegen', 'Germany', 1),
#  ('Tuxedo Mile', 'Jaroslavl', 'Russian Federation', 1),
#  ('Joon Northwest', 'Hohhot', 'China', 1),
#  ('Annie Identity', 'Zanzibar', 'Tanzania', 1),
#  ('Cider Desire', 'Mannheim', 'Germany', 1),
#  ('Jeopardy Encino', 'Ife', 'Nigeria', 1),
#  ('Cabin Flash', 'Yingkou', 'China', 1),
#  ('Gosford Donnie', 'Emeishan', 'China', 1),
#  ('Remember Diary', 'Hoshiarpur', 'India', 1),
#  ('Sunrise League', 'Pingxiang', 'China', 1),
#  ('Vision Torque', 'Juazeiro do Norte', 'Brazil', 1),
#  ('Invasion Cyclone', 'Charlotte Amalie', 'Virgin Islands, U.S.', 1),
#  ('South Wait', 'Hidalgo', 'Mexico', 1),
#  ('Blood Argonauts', 'Tychy', 'Poland', 1),
#  ('Magic Mallrats', 'Nador', 'Morocco', 1),
#  ('Lovely Jingle', 'Ivanovo', 'Russian Federation', 1),
#  ('Nightmare Chill', 'Mannheim', 'Germany', 1),
#  ('Fantasy Troopers', 'Phnom Penh', 'Cambodia', 1),
#  ('Butterfly Chocolat', 'Gingoog', 'Philippines', 1),
#  ('Spartacus Cheaper', 'Madiun', 'Indonesia', 1),
#  ('Atlantis Cause', 'Beni-Mellal', 'Morocco', 1),
#  ('Window Side', 'Vitria de Santo Anto', 'Brazil', 1),
#  ('Wedding Apollo', 'Jinchang', 'China', 1),
#  ('Wedding Apollo', 'Daxian', 'China', 1),
#  ('Matrix Snowman', 'Duisburg', 'Germany', 1),
#  ('Gangs Pride', 'Shanwei', 'China', 1),
#  ('Camelot Vacation', 'Tiefa', 'China', 1),
#  ('Meet Chocolate', 'Yerevan', 'Armenia', 1),
#  ('Sense Greek', 'Datong', 'China', 1),
#  ('Deer Virginian', 'Jamalpur', 'Bangladesh', 1),
#  ('Armageddon Lost', 'Hiroshima', 'Japan', 1),
#  ('Satisfaction Confidential', 'Salamanca', 'Mexico', 1),
#  ('Hills Neighbors', 'Qomsheh', 'Iran', 1),
#  ('Network Peak', 'Mwene-Ditu', 'Congo, The Democratic Republic of the', 1),
#  ('Darn Forrester', 'Santo Andr', 'Brazil', 1),
#  ('Ridgemont Submarine', 'Cape Coral', 'United States', 1),
#  ('Usual Untouchables', 'Stara Zagora', 'Bulgaria', 1),
#  ('Prix Undefeated', 'Eskisehir', 'Turkey', 1),
#  ('Murder Antitrust', 'Liepaja', 'Latvia', 1),
#  ('Paths Control', 'Yamuna Nagar', 'India', 1),
#  ('Rage Games', 'Po', 'Brazil', 1),
#  ('Magnolia Forrester', 'Niznekamsk', 'Russian Federation', 1),
#  ('Fool Mockingbird', 'Sincelejo', 'Colombia', 1),
#  ('Airport Pollock', 'Dhaka', 'Bangladesh', 1),
#  ('Affair Prejudice', 'Avellaneda', 'Argentina', 1),
#  ('Voyage Legally', 'Akishima', 'Japan', 1),
#  ('Dracula Crystal', 'Augusta-Richmond County', 'United States', 1),
#  ('Alaska Phantom', 'Nantou', 'Taiwan', 1),
#  ('Modern Dorado', 'Probolinggo', 'Indonesia', 1),
#  ('Wait Cider', 'Mysore', 'India', 1),
#  ('Turn Star', 'Tanauan', 'Philippines', 1),
#  ('Oleander Clue', 'Pavlodar', 'Kazakstan', 1),
#  ('Fool Mockingbird', 'Kursk', 'Russian Federation', 1),
#  ('Shepherd Midsummer', 'Mit Ghamr', 'Egypt', 1),
#  ('Casablanca Super', 'Hoshiarpur', 'India', 1),
#  ('Bound Cheaper', 'Tangail', 'Bangladesh', 1),
#  ('Intrigue Worst', 'Kitwe', 'Zambia', 1),
#  ('Suspects Quills', 'Bhilwara', 'India', 1),
#  ('Airport Pollock', 'Palghat (Palakkad)', 'India', 1),
#  ('Flying Hook', 'Higashiosaka', 'Japan', 1),
#  ('Drifter Commandments', 'Sanya', 'China', 1),
#  ('Ridgemont Submarine', 'Jinchang', 'China', 1),
#  ('Midsummer Groundhog', 'Vaduz', 'Liechtenstein', 1),
#  ('Temple Attraction', 'Aurora', 'United States', 1),
#  ('Nightmare Chill', 'Chapra', 'India', 1),
#  ('Satisfaction Confidential', 'Ogbomosho', 'Nigeria', 1),
#  ('Theory Mermaid', 'Madiun', 'Indonesia', 1),
#  ('Undefeated Dalmations', 'Yamuna Nagar', 'India', 1),
#  ('Massacre Usual', 'Memphis', 'United States', 1),
#  ('Taxi Kick', 'Asuncin', 'Paraguay', 1),
#  ('Ship Wonderland', 'Soshanguve', 'South Africa', 1),
#  ('Trap Guys', 'Jalib al-Shuyukh', 'Kuwait', 1),
#  ('Gold River', 'Xinxiang', 'China', 1),
#  ('Sleuth Orient', 'Jedda', 'Saudi Arabia', 1),
#  ('Island Exorcist', 'Sokoto', 'Nigeria', 1),
#  ('Redemption Comforts', 'Ede', 'Netherlands', 1),
#  ('Personal Ladybugs', 'Akishima', 'Japan', 1),
#  ('Clash Freddy', 'Dzerzinsk', 'Russian Federation', 1),
#  ('Zoolander Fiction', 'Shimonoseki', 'Japan', 1),
#  ('Pacific Amistad', 'Uluberia', 'India', 1),
#  ('Working Microcosmos', 'Malm', 'Sweden', 1),
#  ('Mask Peach', 'Yangor', 'Nauru', 1),
#  ('Crazy Home', 'Rockford', 'United States', 1),
#  ('Streetcar Intentions', 'Memphis', 'United States', 2),
#  ('Dalmations Sweden', 'Coacalco de Berriozbal', 'Mexico', 1),
#  ('Splash Gump', 'Zanzibar', 'Tanzania', 1),
#  ('Weekend Personal', 'Antofagasta', 'Chile', 1),
#  ('Japanese Run', 'Syrakusa', 'Italy', 1),
#  ('Gleaming Jawbreaker', 'Sincelejo', 'Colombia', 1),
#  ('Angels Life', 'Carmen', 'Mexico', 1),
#  ('Fool Mockingbird', 'Pjatigorsk', 'Russian Federation', 1),
#  ('Jericho Mulan', 'Touliu', 'Taiwan', 1),
#  ('Moulin Wake', 'Haiphong', 'Vietnam', 1),
#  ('Pilot Hoosiers', 'Skikda', 'Algeria', 1),
#  ('Samurai Lion', 'Vila Velha', 'Brazil', 1),
#  ('Satisfaction Confidential', 'Rajkot', 'India', 1),
#  ('Atlantis Cause', 'Abu Dhabi', 'United Arab Emirates', 1),
#  ('Secrets Paradise', 'Purwakarta', 'Indonesia', 1),
#  ('Pity Bound', 'Sultanbeyli', 'Turkey', 1),
#  ('Sun Confessions', 'Ashdod', 'Israel', 1),
#  ('Roots Remember', 'Shahr-e Kord', 'Iran', 1),
#  ('Pride Alamo', 'Shivapuri', 'India', 1),
#  ('Range Moonwalker', 'Jedda', 'Saudi Arabia', 1),
#  ('Oz Liaisons', 'Nakhon Sawan', 'Thailand', 1),
#  ('Titanic Boondock', 'Shikarpur', 'Pakistan', 1),
#  ('Core Suit', 'Bhilwara', 'India', 1),
#  ('Juggler Hardly', 'Monclova', 'Mexico', 1),
#  ('California Birds', 'Plock', 'Poland', 2),
#  ('Vision Torque', 'Imus', 'Philippines', 1),
#  ('Valentine Vanishing', 'Skikda', 'Algeria', 1),
#  ('Invasion Cyclone', 'Sullana', 'Peru', 1),
#  ('Virgin Daisy', 'Bhavnagar', 'India', 1),
#  ('Wolves Desire', 'Nuuk', 'Greenland', 1),
#  ('Frida Slipper', 'Sullana', 'Peru', 1),
#  ('Working Microcosmos', 'Sambhal', 'India', 1),
#  ('Anaconda Confessions', 'Molodetno', 'Belarus', 1),
#  ('Craft Outfield', 'Xintai', 'China', 1),
#  ('Garden Island', 'Papeete', 'French Polynesia', 1),
#  ('Bull Shawshank', 'Angra dos Reis', 'Brazil', 1),
#  ('Bowfinger Gables', 'Oyo', 'Nigeria', 1),
#  ('Snowman Rollercoaster', 'Tonghae', 'South Korea', 1),
#  ('Pure Runner', 'Nakhon Sawan', 'Thailand', 1),
#  ('Apache Divine', 'Carmen', 'Mexico', 1),
#  ('Casablanca Super', 'Gaziantep', 'Turkey', 1),
#  ('Storm Happiness', 'Lungtan', 'Taiwan', 1),
#  ('Pet Haunting', 'Cam Ranh', 'Vietnam', 1),
#  ('Voyage Legally', 'Qomsheh', 'Iran', 1),
#  ('Graduate Lord', 'Fukuyama', 'Japan', 1),
#  ('Affair Prejudice', 'Malm', 'Sweden', 1),
#  ('Women Dorado', 'Lhokseumawe', 'Indonesia', 1),
#  ('Star Operation', 'Shikarpur', 'Pakistan', 1),
#  ('Streak Ridgemont', 'Lungtan', 'Taiwan', 1),
#  ('Escape Metropolis', 'Tokat', 'Turkey', 1),
#  ('Shepherd Midsummer', 'Kabul', 'Afghanistan', 1),
#  ('Grit Clockwork', 'Madiun', 'Indonesia', 1),
#  ('Taxi Kick', 'Paarl', 'South Africa', 1),
#  ('Women Dorado', 'Sasebo', 'Japan', 1),
#  ('Won Dares', 'Araatuba', 'Brazil', 1),
#  ('Primary Glass', 'Kamjanets-Podilskyi', 'Ukraine', 1),
#  ('Queen Luke', 'Nha Trang', 'Vietnam', 1),
#  ('Escape Metropolis', 'Aurora', 'United States', 1),
#  ('Conversation Downhill', 'Avellaneda', 'Argentina', 1),
#  ('Madness Attacks', 'Xinxiang', 'China', 1),
#  ('Sundance Invasion', 'Uttarpara-Kotrung', 'India', 1),
#  ('Date Speed', 'Jinzhou', 'China', 1),
#  ('Grinch Massage', 'Usak', 'Turkey', 1),
#  ('Sabrina Midnight', 'Chiayi', 'Taiwan', 1),
#  ('Wrong Behavior', 'Belm', 'Brazil', 1),
#  ('Room Roman', 'Livorno', 'Italy', 1),
#  ('Torque Bound', 'Salinas', 'United States', 1),
#  ('Moonshine Cabin', 'Balaiha', 'Russian Federation', 2),
#  ('Kwai Homeward', 'Rizhao', 'China', 1),
#  ('Cabin Flash', 'Yaound', 'Cameroon', 1),
#  ('Maltese Hope', 'Rockford', 'United States', 1),
#  ('Impact Aladdin', 'Vitria de Santo Anto', 'Brazil', 1),
#  ('Saturday Lambs', 'Ljubertsy', 'Russian Federation', 1),
#  ('Kwai Homeward', 'Bratislava', 'Slovakia', 1),
#  ('Murder Antitrust', 'Nyeri', 'Kenya', 1),
#  ('Balloon Homeward', 'Udaipur', 'India', 1),
#  ('Circus Youth', 'Lipetsk', 'Russian Federation', 1),
#  ('Truman Crazy', 'Brescia', 'Italy', 1),
#  ('Dwarfs Alter', 'Hino', 'Japan', 1),
#  ('Vietnam Smoochy', 'Citrus Heights', 'United States', 1),
#  ('Magnolia Forrester', 'Ezhou', 'China', 1),
#  ('Affair Prejudice', 'Aparecida de Goinia', 'Brazil', 1),
#  ('Crazy Home', 'Xiangfan', 'China', 1),
#  ('Mod Secretary', 'Katihar', 'India', 1),
#  ('Money Harold', 'Cuautla', 'Mexico', 1),
#  ('Expendable Stallion', 'Inegl', 'Turkey', 1),
#  ('Velvet Terminator', 'Cuman', 'Venezuela', 1),
#  ('Jet Neighbors', 'Effon-Alaiye', 'Nigeria', 1),
#  ('Dorado Notting', 'Sharja', 'United Arab Emirates', 1),
#  ('Conversation Downhill', 'San Lorenzo', 'Paraguay', 1),
#  ('American Circus', 'Bergamo', 'Italy', 1),
#  ('License Weekend', 'Rae Bareli', 'India', 1),
#  ('Kane Exorcist', 'Garland', 'United States', 1),
#  ('Submarine Bed', 'Hanoi', 'Vietnam', 1),
#  ('Paris Weekend', 'Effon-Alaiye', 'Nigeria', 1),
#  ('Shanghai Tycoon', 'Allappuzha (Alleppey)', 'India', 1),
#  ('Tomatoes Hellfighters', 'Carmen', 'Mexico', 1),
#  ('Ladybugs Armageddon', 'Taguig', 'Philippines', 1),
#  ('Married Go', 'San Lorenzo', 'Paraguay', 1),
#  ('Banger Pinocchio', 'Binzhou', 'China', 1),
#  ('Story Side', 'Etawah', 'India', 1),
#  ('Murder Antitrust', 'Faaa', 'French Polynesia', 1),
#  ('Loathing Legally', 'Kurashiki', 'Japan', 1),
#  ('Kwai Homeward', 'Sogamoso', 'Colombia', 1),
#  ('Star Operation', 'Nakhon Sawan', 'Thailand', 1),
#  ('Punk Divorce', 'Florencia', 'Colombia', 1),
#  ('Expecations Natural', 'Newcastle', 'South Africa', 1),
#  ('Congeniality Quest', 'Uijongbu', 'South Korea', 1),
#  ('Camelot Vacation', 'Kamarhati', 'India', 1),
#  ('Jason Trap', 'Lengshuijiang', 'China', 1),
#  ('Jet Neighbors', 'Kowloon and New Kowloon', 'Hong Kong', 1),
#  ('Center Dinosaur', 'Gorontalo', 'Indonesia', 1),
#  ('Punk Divorce', 'Nakhon Sawan', 'Thailand', 1),
#  ('Bright Encounters', 'Songkhla', 'Thailand', 1),
#  ('Virtual Spoilers', 'Bhusawal', 'India', 1),
#  ('United Pilot', 'Ashdod', 'Israel', 1),
#  ('Airport Pollock', 'Portoviejo', 'Ecuador', 1),
#  ('Monster Spartacus', 'Fuyu', 'China', 1),
#  ('Garden Island', 'Bijapur', 'India', 1),
#  ('Pocus Pulp', 'Aurora', 'United States', 1),
#  ('Date Speed', 'Bhopal', 'India', 1),
#  ('Massage Image', 'Cape Coral', 'United States', 1),
#  ('Steers Armageddon', 'Kitwe', 'Zambia', 1),
#  ('Crooked Frogmen', 'Nezahualcyotl', 'Mexico', 1),
#  ('Forrest Sons', 'Parbhani', 'India', 1),
#  ('Bill Others', 'Jodhpur', 'India', 1),
#  ('Eagles Panky', 'Hodeida', 'Yemen', 1),
#  ('Sleeping Suspects', 'La Paz', 'Mexico', 1),
#  ('Greedy Roots', 'Bhopal', 'India', 1),
#  ('Sleuth Orient', 'La Paz', 'Mexico', 1),
#  ('Louisiana Harry', 'Jhansi', 'India', 1),
#  ('Balloon Homeward', 'Roanoke', 'United States', 1),
#  ('Ship Wonderland', 'Parbhani', 'India', 1),
#  ('Butterfly Chocolat', 'Bhusawal', 'India', 1),
#  ('Shock Cabin', 'Xiangfan', 'China', 1),
#  ('Strangers Graffiti', 'Caracas', 'Venezuela', 1),
#  ('Vacation Boondock', 'Nyeri', 'Kenya', 1),
#  ('Peach Innocent', 'Jurez', 'Mexico', 1),
#  ('Boogie Amelie', 'Valparai', 'India', 1),
#  ('Dying Maker', 'Goinia', 'Brazil', 1),
#  ('Rugrats Shakespeare', 'Cuauhtmoc', 'Mexico', 1),
#  ('Intentions Empire', 'Bayugan', 'Philippines', 1),
#  ('Analyze Hoosiers', 'Yuncheng', 'China', 1),
#  ('Network Peak', 'Sullana', 'Peru', 1),
#  ('Candles Grapes', 'Daugavpils', 'Latvia', 1),
#  ('Celebrity Horn', 'Hodeida', 'Yemen', 1),
#  ('Sinners Atlantis', 'Shenzhen', 'China', 1),
#  ('Lose Inch', 'Touliu', 'Taiwan', 1),
#  ('Newton Labyrinth', 'Ambattur', 'India', 1),
#  ('Conspiracy Spirit', 'Pjatigorsk', 'Russian Federation', 1),
#  ('Musketeers Wait', 'Coatzacoalcos', 'Mexico', 1),
#  ('Madness Attacks', 'Tambaram', 'India', 1),
#  ('Pirates Roxanne', 'Osmaniye', 'Turkey', 1),
#  ('Backlash Undefeated', 'Pontianak', 'Indonesia', 1),
#  ('Wind Phantom', 'Bchar', 'Algeria', 1),
#  ('Academy Dinosaur', 'Udaipur', 'India', 1),
#  ('Treatment Jekyll', 'Tafuna', 'American Samoa', 1),
#  ('Pond Seattle', 'Ueda', 'Japan', 2),
#  ('Vampire Whale', 'Pathankot', 'India', 1),
#  ('Excitement Eve', 'Bchar', 'Algeria', 1),
#  ('Mulholland Beast', 'Iwatsuki', 'Japan', 1),
#  ('Hustler Party', 'Nuuk', 'Greenland', 1),
#  ('Hollow Jeopardy', 'Saint-Denis', 'Runion', 1),
#  ('King Evolution', 'Plock', 'Poland', 1),
#  ('Ishtar Rocketeer', 'Kilis', 'Turkey', 1),
#  ('Forrester Comancheros', 'Charlotte Amalie', 'Virgin Islands, U.S.', 1),
#  ('Muscle Bright', 'Kurgan', 'Russian Federation', 1),
#  ('Harry Idaho', 'Salzburg', 'Austria', 1),
#  ('Confused Candles', 'Shaoguan', 'China', 1),
#  ('Secret Groundhog', 'Warren', 'United States', 1),
#  ('Nuts Ties', 'Aden', 'Yemen', 1),
#  ('Runaway Tenenbaums', 'Abu Dhabi', 'United Arab Emirates', 1),
#  ('Spinal Rocky', 'Barcelona', 'Venezuela', 1),
#  ('Tracy Cider', 'Jamalpur', 'Bangladesh', 1),
#  ('Smile Earring', 'Fontana', 'United States', 1),
#  ('Hamlet Wisdom', 'Rio Claro', 'Brazil', 1),
#  ('Daisy Menagerie', 'Tonghae', 'South Korea', 1),
#  ('Crooked Frogmen', 'Aurora', 'United States', 1),
#  ('Bingo Talented', 'Shubra al-Khayma', 'Egypt', 2),
#  ('Reap Unfaithful', 'Jinchang', 'China', 1),
#  ('Graffiti Love', 's-Hertogenbosch', 'Netherlands', 1),
#  ('Ridgemont Submarine', 'Shubra al-Khayma', 'Egypt', 1),
#  ('Driver Annie', 'Faaa', 'French Polynesia', 1),
#  ('Academy Dinosaur', 'Celaya', 'Mexico', 1),
#  ('Party Knock', 'Robamba', 'Ecuador', 1),
#  ('Madness Attacks', 'Masqat', 'Oman', 1),
#  ('Ending Crowds', 'Surakarta', 'Indonesia', 1),
#  ('Silverado Goldfinger', 'York', 'United Kingdom', 1),
#  ('Rugrats Shakespeare', 'Etawah', 'India', 1),
#  ('Comforts Rush', 'Ranchi', 'India', 1),
#  ('Outbreak Divine', 'Ourense (Orense)', 'Spain', 2),
#  ('Juggler Hardly', 'Hino', 'Japan', 1),
#  ('Annie Identity', 'Szkesfehrvr', 'Hungary', 1),
#  ('Cat Coneheads', 'Jelets', 'Russian Federation', 1),
#  ('Something Duck', 'Qalyub', 'Egypt', 1),
#  ('Lovely Jingle', 'Tabora', 'Tanzania', 2),
#  ('Packer Madigan', 'Tiefa', 'China', 1),
#  ('Alaska Phantom', 'Zhezqazghan', 'Kazakstan', 2),
#  ('Frisco Forrest', 'Xiangtan', 'China', 1),
#  ('Carrie Bunch', 'Chandrapur', 'India', 1),
#  ('Lose Inch', 'Santo Andr', 'Brazil', 1),
#  ('Divide Monster', 'Bhavnagar', 'India', 1),
#  ('Deep Crusade', 'Memphis', 'United States', 1),
#  ('Splendor Patton', 'Rio Claro', 'Brazil', 1),
#  ('Mother Oleander', 'Matamoros', 'Mexico', 1),
#  ('Videotape Arsenic', 'Gatineau', 'Canada', 1),
#  ('Past Suicides', 'Udaipur', 'India', 1),
#  ('Drums Dynamite', 'Hagonoy', 'Philippines', 1),
#  ('Story Side', 'Stockport', 'United Kingdom', 1),
#  ('Nash Chocolat', 'Sambhal', 'India', 1),
#  ('Lolita World', 'Hsichuh', 'Taiwan', 1),
#  ('Greek Everyone', 'Guadalajara', 'Mexico', 1),
#  ('Frida Slipper', 'Sumqayit', 'Azerbaijan', 1),
#  ('Creepers Kane', 'Ezhou', 'China', 1),
#  ('Horn Working', 'Warren', 'United States', 1),
#  ('Flintstones Happiness', 'Ambattur', 'India', 1),
#  ('Boogie Amelie', 'Jastrzebie-Zdrj', 'Poland', 1),
#  ('River Outlaw', 'Tabuk', 'Saudi Arabia', 1),
#  ('Bird Independence', 'Yangor', 'Nauru', 1),
#  ('Thief Pelican', 'Celaya', 'Mexico', 1),
#  ('Suit Walls', 'Baicheng', 'China', 1),
#  ('Heartbreakers Bright', 'Santo Andr', 'Brazil', 1),
#  ('Northwest Polish', 'Gijn', 'Spain', 1),
#  ('Whale Bikini', 'Yaound', 'Cameroon', 1),
#  ('Balloon Homeward', 'Bucuresti', 'Romania', 1),
#  ('Gandhi Kwai', 'Kolpino', 'Russian Federation', 1),
#  ('Perfect Groove', 'Araatuba', 'Brazil', 1),
#  ('Jedi Beneath', 'Lilongwe', 'Malawi', 1),
#  ('Cleopatra Devil', 'Luzinia', 'Brazil', 1),
#  ('Newton Labyrinth', 'Tsuyama', 'Japan', 1),
#  ('Beauty Grease', 'Kamarhati', 'India', 1),
#  ('Name Detective', 'Malm', 'Sweden', 1),
#  ('Metropolis Coma', 'Mandaluyong', 'Philippines', 1),
#  ('Fish Opus', 'Santa F', 'Argentina', 1),
#  ('Lebowski Soldiers', 'Munger (Monghyr)', 'India', 1),
#  ('Flight Lies', 'Robamba', 'Ecuador', 1),
#  ('Opus Ice', 'Brindisi', 'Italy', 1),
#  ('Tracy Cider', 'Guadalajara', 'Mexico', 1),
#  ('Run Pacific', 'Kragujevac', 'Yugoslavia', 1),
#  ('Gandhi Kwai', 'Yaound', 'Cameroon', 1),
#  ('Apache Divine', 'Oshawa', 'Canada', 1),
#  ('Road Roxanne', 'Arlington', 'United States', 1),
#  ('Massage Image', 'Maracabo', 'Venezuela', 1),
#  ('Innocent Usual', 'Santiago de los Caballeros', 'Dominican Republic', 1),
#  ('Torque Bound', 'Santiago de Compostela', 'Spain', 1),
#  ('Dalmations Sweden', 'Tongliao', 'China', 1),
#  ('Shepherd Midsummer', 'Jakarta', 'Indonesia', 1),
#  ('Jacket Frisco', 'Dongying', 'China', 1),
#  ('Attacks Hate', 'Ueda', 'Japan', 1),
#  ('Philadelphia Wife', 'Botosani', 'Romania', 1),
#  ('Sleeping Suspects', 'Johannesburg', 'South Africa', 1),
#  ('Neighbors Charade', 'Le Mans', 'France', 1),
#  ('Earth Vision', 'Celaya', 'Mexico', 1),
#  ('Outfield Massacre', 'Rockford', 'United States', 1),
#  ('Mallrats United', 'Matamoros', 'Mexico', 1),
#  ('Spoilers Hellfighters', 'Baiyin', 'China', 1),
#  ('Cupboard Sinners', 'Aurora', 'United States', 1),
#  ('Patriot Roman', 'Araatuba', 'Brazil', 1),
#  ('Dirty Ace', 'Ozamis', 'Philippines', 1),
#  ('Lies Treatment', 'Battambang', 'Cambodia', 1),
#  ('Heaven Freedom', 'Santa F', 'Argentina', 1),
#  ('Voice Peach', 'Ondo', 'Nigeria', 1),
#  ('National Story', 'Zanzibar', 'Tanzania', 1),
#  ('Juggler Hardly', 'Huixquilucan', 'Mexico', 1),
#  ('Divide Monster', 'Tabriz', 'Iran', 1),
#  ('Talented Homicide', 'Bhopal', 'India', 1),
#  ('Sugar Wonka', 'Namibe', 'Angola', 1),
#  ('Saddle Antitrust', 'Kalisz', 'Poland', 2),
#  ('Wrath Mile', 'Kakamigahara', 'Japan', 1),
#  ('Queen Luke', 'Novi Sad', 'Yugoslavia', 1),
#  ('Eagles Panky', 'Faaa', 'French Polynesia', 1),
#  ('Attraction Newton', 'Changzhou', 'China', 1),
#  ('Trip Newton', 'Tafuna', 'American Samoa', 1),
#  ('Sweethearts Suspects', 'Brindisi', 'Italy', 1),
#  ('Rear Trading', 'Southampton', 'United Kingdom', 1),
#  ('Island Exorcist', 'Lancaster', 'United States', 1),
#  ('Rocketeer Mother', 'Benguela', 'Angola', 1),
#  ('Mine Titans', 'Leshan', 'China', 1),
#  ('Caddyshack Jedi', 'Cam Ranh', 'Vietnam', 1),
#  ('Masked Bubble', 'San Felipe de Puerto Plata', 'Dominican Republic', 1),
#  ('Knock Warlock', 'Lapu-Lapu', 'Philippines', 1),
#  ('Wash Heavenly', 'Beni-Mellal', 'Morocco', 1),
#  ('Lawrence Love', 'Baha Blanca', 'Argentina', 1),
#  ('Deer Virginian', 's-Hertogenbosch', 'Netherlands', 1),
#  ('Shane Darkness', 'Shaoguan', 'China', 1),
#  ('Family Sweet', 'Brindisi', 'Italy', 1),
#  ('Alien Center', 'San Felipe de Puerto Plata', 'Dominican Republic', 1),
#  ('Chasing Fight', 'Kamjanets-Podilskyi', 'Ukraine', 1),
#  ('Young Language', 'Syktyvkar', 'Russian Federation', 1),
#  ('Casper Dragonfly', 'Parbhani', 'India', 1),
#  ('Greatest North', 'Hiroshima', 'Japan', 1),
#  ('Sleuth Orient', 'Portoviejo', 'Ecuador', 1),
#  ('Butterfly Chocolat', 'Touliu', 'Taiwan', 1),
#  ('Island Exorcist', 'Fengshan', 'Taiwan', 1),
#  ('Gunfight Moon', 'Sal', 'Morocco', 1),
#  ('Dogma Family', 'Boa Vista', 'Brazil', 1),
#  ('Rush Goodfellas', 'La Plata', 'Argentina', 1),
#  ('Muscle Bright', 'Pak Kret', 'Thailand', 1),
#  ('House Dynamite', 'Jelets', 'Russian Federation', 1),
#  ('Egg Igby', 'Santo Andr', 'Brazil', 1),
#  ('Wash Heavenly', 'Usolje-Sibirskoje', 'Russian Federation', 1),
#  ('Doors President', 'Tokat', 'Turkey', 1),
#  ('Enemy Odds', 'Fuyu', 'China', 1),
#  ('Academy Dinosaur', 'Nukualofa', 'Tonga', 1),
#  ('Nemo Campus', 'Callao', 'Peru', 1),
#  ('Turn Star', 'Caracas', 'Venezuela', 1),
#  ('Cider Desire', 'Graz', 'Austria', 1),
#  ('Records Zorro', 'Duisburg', 'Germany', 1),
#  ('Sweethearts Suspects', 'Ourense (Orense)', 'Spain', 1),
#  ('Sling Luke', 'Datong', 'China', 1),
#  ('Stagecoach Armageddon', 'Kirovo-Tepetsk', 'Russian Federation', 1),
#  ('Sagebrush Clueless', 'Pachuca de Soto', 'Mexico', 1),
#  ('Falcon Volume', 'Bern', 'Switzerland', 1),
#  ('Titans Jerk', 'Aurora', 'United States', 1),
#  ('League Hellfighters', 'Purwakarta', 'Indonesia', 1),
#  ('Song Hedwig', 'Olomouc', 'Czech Republic', 1),
#  ('Go Purple', 'Ede', 'Netherlands', 1),
#  ('Turn Star', 'Valparai', 'India', 1),
#  ('Kwai Homeward', 'Imus', 'Philippines', 1),
#  ('Lion Uncut', 'Kitwe', 'Zambia', 1),
#  ('Philadelphia Wife', 'Tonghae', 'South Korea', 1),
#  ('Hollow Jeopardy', 'Kimchon', 'South Korea', 1),
#  ('Kissing Dolls', 'Anpolis', 'Brazil', 1),
#  ('Gunfighter Mussolini', 'Tama', 'Japan', 1),
#  ('Jet Neighbors', 'Malm', 'Sweden', 1),
#  ('Moonshine Cabin', 'Santa F', 'Argentina', 1),
#  ('Pluto Oleander', 'Ciomas', 'Indonesia', 1),
#  ('Forrest Sons', 'Gijn', 'Spain', 1),
#  ('Timberland Sky', 'Santa F', 'Argentina', 1),
#  ('Blindness Gun', 'Udaipur', 'India', 1),
#  ('Fight Jawbreaker', 'Garland', 'United States', 1),
#  ('Agent Truman', 'Tafuna', 'American Samoa', 1),
#  ('Range Moonwalker', 'Lengshuijiang', 'China', 1),
#  ('Flying Hook', 'Witten', 'Germany', 1),
#  ('Talented Homicide', 'Udaipur', 'India', 1),
#  ('Harry Idaho', 'Vancouver', 'Canada', 1),
#  ('Bringing Hysterical', 'Ozamis', 'Philippines', 1),
#  ('Rocketeer Mother', 'Coquimbo', 'Chile', 1),
#  ('Patton Interview', 'Kurashiki', 'Japan', 1),
#  ('Empire Malkovich', 'Sincelejo', 'Colombia', 1),
#  ('Sleepless Monsoon', 'Kursk', 'Russian Federation', 1),
#  ('Saturday Lambs', 'Vila Velha', 'Brazil', 1),
#  ('Madison Trap', 'Hunuco', 'Peru', 1),
#  ('War Notting', 'Ljubertsy', 'Russian Federation', 1),
#  ('Badman Dawn', 'Simferopol', 'Ukraine', 1),
#  ('Heaven Freedom', 'Shenzhen', 'China', 1),
#  ('Alone Trip', 'Almirante Brown', 'Argentina', 1),
#  ('Patton Interview', 'Duisburg', 'Germany', 1),
#  ('High Encino', 'Hamilton', 'New Zealand', 1),
#  ('Runaway Tenenbaums', 'Kolpino', 'Russian Federation', 1),
#  ('Invasion Cyclone', 'Yaound', 'Cameroon', 1),
#  ('Stampede Disturbing', 'Omiya', 'Japan', 1),
#  ('Thin Sagebrush', 'Faaa', 'French Polynesia', 1),
#  ('Natural Stock', 'San Juan Bautista Tuxtepec', 'Mexico', 1),
#  ('Kick Savannah', 'Deba Habe', 'Nigeria', 1),
#  ('Enough Raging', 'Balikesir', 'Turkey', 1),
#  ('Sierra Divide', 'Araatuba', 'Brazil', 1),
#  ('Music Boondock', 'Adoni', 'India', 1),
#  ('Snowman Rollercoaster', 'Meixian', 'China', 1),
#  ('Rage Games', 'Bchar', 'Algeria', 1),
#  ('Gun Bonnie', 'Antofagasta', 'Chile', 1),
#  ('Pulp Beverly', 'Manchester', 'United States', 1),
#  ('Grapes Fury', 'Lausanne', 'Switzerland', 1),
#  ('Hobbit Alien', 'Hsichuh', 'Taiwan', 1),
#  ('Rock Instinct', 'Haldia', 'India', 1),
#  ('Diary Panic', 'Smolensk', 'Russian Federation', 1),
#  ('Taxi Kick', 'Gijn', 'Spain', 1),
#  ('Velvet Terminator', 'London', 'United Kingdom', 1),
#  ('Montezuma Command', 'Bydgoszcz', 'Poland', 1),
#  ('Vanishing Rocky', 'Barcelona', 'Venezuela', 1),
#  ('Suspects Quills', 'Satna', 'India', 1),
#  ('Conversation Downhill', 'Mannheim', 'Germany', 1),
#  ('Mourning Purple', 'Firozabad', 'India', 1),
#  ('Princess Giant', 'Bislig', 'Philippines', 1),
#  ('Arabia Dogma', 'Usak', 'Turkey', 1),
#  ('Telemark Heartbreakers', 'Moscow', 'Russian Federation', 1),
#  ('Kissing Dolls', 'Cuautla', 'Mexico', 1),
#  ('Groundhog Uncut', 'Dhaka', 'Bangladesh', 1),
#  ('Modern Dorado', 'Phnom Penh', 'Cambodia', 1),
#  ('Rocky War', 'Kuching', 'Malaysia', 1),
#  ('Jet Neighbors', 'Benin City', 'Nigeria', 1),
#  ('Human Graffiti', 'Zhezqazghan', 'Kazakstan', 1),
#  ('Ice Crossing', 'Coacalco de Berriozbal', 'Mexico', 1),
#  ('Wonka Sea', 'Huejutla de Reyes', 'Mexico', 1),
#  ('Stagecoach Armageddon', 'Batman', 'Turkey', 1),
#  ('Vision Torque', 'Cuautla', 'Mexico', 1),
#  ('Honey Ties', 'Escobar', 'Argentina', 1),
#  ('Groundhog Uncut', 'Leshan', 'China', 1),
#  ('Goldfinger Sensibility', 'Cayenne', 'French Guiana', 1),
#  ('Jerk Paycheck', 'Kabul', 'Afghanistan', 1),
#  ('Sassy Packer', 'Funafuti', 'Tuvalu', 1),
#  ('Gaslight Crusade', 'Kanazawa', 'Japan', 1),
#  ('Brotherhood Blanket', 'Uttarpara-Kotrung', 'India', 1),
#  ('Brotherhood Blanket', 'Beira', 'Mozambique', 1),
#  ('Streetcar Intentions', 'Hanoi', 'Vietnam', 1),
#  ('Edge Kissing', 'Witten', 'Germany', 1),
#  ('Opposite Necklace', 'Rio Claro', 'Brazil', 1),
#  ('Heaven Freedom', 'A Corua (La Corua)', 'Spain', 1),
#  ('Sabrina Midnight', 'Novi Sad', 'Yugoslavia', 1),
#  ('Devil Desire', 'Shahr-e Kord', 'Iran', 1),
#  ('Gone Trouble', 'Jinzhou', 'China', 1),
#  ('Disciple Mother', 'Halle/Saale', 'Germany', 1),
#  ('Beach Heartbreakers', 'Kingstown', 'Saint Vincent and the Grenadines', 1),
#  ('Kwai Homeward', 'Laohekou', 'China', 1),
#  ('Loathing Legally', 'Lincoln', 'United States', 1),
#  ('Caper Motions', 'A Corua (La Corua)', 'Spain', 1),
#  ('Freaky Pocus', 'Nantou', 'Taiwan', 1),
#  ('Rear Trading', 'Athenai', 'Greece', 1),
#  ('Fury Murder', 'Yaound', 'Cameroon', 1),
#  ('Smoochy Control', 'Satna', 'India', 1),
#  ('Spice Sorority', 'Addis Abeba', 'Ethiopia', 1),
#  ('Ice Crossing', 'Sambhal', 'India', 1),
#  ('Talented Homicide', 'Sasebo', 'Japan', 1),
#  ('Halloween Nuts', 'Vijayawada', 'India', 1),
#  ('Pirates Roxanne', 'Ahmadnagar', 'India', 1),
#  ('Timberland Sky', 'Bijapur', 'India', 1),
#  ('Army Flintstones', 'Cavite', 'Philippines', 1),
#  ('Human Graffiti', 'Mosul', 'Iraq', 1),
#  ('Thief Pelican', 'Okayama', 'Japan', 1),
#  ('Hours Rage', 'Sal', 'Morocco', 1),
#  ('Titanic Boondock', 'Juazeiro do Norte', 'Brazil', 1),
#  ('Oscar Gold', 'Ranchi', 'India', 1),
#  ('Voice Peach', 'Cheju', 'South Korea', 1),
#  ('Enemy Odds', 'Firozabad', 'India', 1),
#  ('Interview Liaisons', 'Almirante Brown', 'Argentina', 1),
#  ('Bound Cheaper', 'Fuyu', 'China', 1),
#  ('Money Harold', 'Usolje-Sibirskoje', 'Russian Federation', 1),
#  ('Ghost Groundhog', 'Kamarhati', 'India', 1),
#  ('Sense Greek', 'Ponce', 'Puerto Rico', 1),
#  ('French Holiday', 'Goinia', 'Brazil', 1),
#  ('Fool Mockingbird', 'Gijn', 'Spain', 1),
#  ('Loverboy Attacks', 'Sharja', 'United Arab Emirates', 1),
#  ('Samurai Lion', 'Kamjanets-Podilskyi', 'Ukraine', 1),
#  ('Club Graffiti', 'So Leopoldo', 'Brazil', 1),
#  ('American Circus', 'Cabuyao', 'Philippines', 1),
#  ('Sunset Racer', 'Molodetno', 'Belarus', 1),
#  ('Bikini Borrowers', 'Guaruj', 'Brazil', 1),
#  ('Effect Gladiator', 'Sivas', 'Turkey', 1),
#  ('Dinosaur Secretary', 'Kowloon and New Kowloon', 'Hong Kong', 1),
#  ('Ferris Mother', 'Tychy', 'Poland', 1),
#  ('Kiss Glory', 'Satna', 'India', 1),
#  ('Virginian Pluto', 'Mahajanga', 'Madagascar', 1),
#  ('Redemption Comforts', 'Yingkou', 'China', 1),
#  ('Frida Slipper', 'Benin City', 'Nigeria', 1),
#  ('Wife Turn', 'Karnal', 'India', 1),
#  ('Samurai Lion', 'Valle de la Pascua', 'Venezuela', 1),
#  ('Straight Hours', 'Monclova', 'Mexico', 1),
#  ('Show Lord', 'Brockton', 'United States', 1),
#  ('Platoon Instinct', 'Bern', 'Switzerland', 1),
#  ('Princess Giant', 'Cianjur', 'Indonesia', 1),
#  ('Eagles Panky', 'Yaound', 'Cameroon', 1),
#  ('Anthem Luke', 'Coacalco de Berriozbal', 'Mexico', 1),
#  ('Dragon Squad', 'Tarsus', 'Turkey', 1),
#  ('Roses Treasure', 'Emeishan', 'China', 1),
#  ('Chill Luck', 'Huaian', 'China', 2),
#  ('Arachnophobia Rollercoaster', 'Vicente Lpez', 'Argentina', 1),
#  ('Straight Hours', 'Purwakarta', 'Indonesia', 1),
#  ('Born Spinal', 'Coacalco de Berriozbal', 'Mexico', 1),
#  ('Outlaw Hanky', 'Sungai Petani', 'Malaysia', 1),
#  ('Beast Hunchback', 'Guadalajara', 'Mexico', 1),
#  ('Patient Sister', 'Uluberia', 'India', 1),
#  ('Moonshine Cabin', 'Atinsk', 'Russian Federation', 1),
#  ('Congeniality Quest', 'La Plata', 'Argentina', 1),
#  ('Boogie Amelie', 'Garland', 'United States', 1),
#  ('Conquerer Nuts', 'Rampur', 'India', 1),
#  ('Spy Mile', 'Compton', 'United States', 1),
#  ('Congeniality Quest', 'Tandil', 'Argentina', 1),
#  ('Videotape Arsenic', 'Nador', 'Morocco', 2),
#  ('Dogma Family', 'Ibirit', 'Brazil', 1),
#  ('Blackout Private', 'Smolensk', 'Russian Federation', 1),
#  ('Club Graffiti', 'Ciomas', 'Indonesia', 1),
#  ('Fight Jawbreaker', 'Ogbomosho', 'Nigeria', 1),
#  ('Steers Armageddon', 'Chandrapur', 'India', 1),
#  ('Brannigan Sunrise', 'Xiangfan', 'China', 1),
#  ('Run Pacific', 'Bchar', 'Algeria', 1),
#  ('Lawrence Love', 'Caracas', 'Venezuela', 1),
#  ('Tracy Cider', 'Valle de la Pascua', 'Venezuela', 1),
#  ('Midsummer Groundhog', 'Lima', 'Peru', 1),
#  ('Rules Human', 'Ibirit', 'Brazil', 1),
#  ('Ballroom Mockingbird', 'Tarsus', 'Turkey', 1),
#  ('Maude Mod', 'Sogamoso', 'Colombia', 1),
#  ('Dream Pickup', 'Parbhani', 'India', 1),
#  ('Gilbert Pelican', 'Addis Abeba', 'Ethiopia', 1),
#  ('Alamo Videotape', 'Baicheng', 'China', 1),
#  ('Seattle Expecations', 'Santa Brbara dOeste', 'Brazil', 1),
#  ('Wife Turn', 'Phnom Penh', 'Cambodia', 1),
#  ('Hills Neighbors', 'Pyongyang', 'North Korea', 1),
#  ('Desire Alien', 'Nabereznyje Telny', 'Russian Federation', 1),
#  ('Forrester Comancheros', 'Shaoguan', 'China', 1),
#  ('Blade Polish', 'Qalyub', 'Egypt', 1),
#  ('Drifter Commandments', 'Shikarpur', 'Pakistan', 1),
#  ('Musketeers Wait', 'Purnea (Purnia)', 'India', 1),
#  ('Madness Attacks', 'Kragujevac', 'Yugoslavia', 1),
#  ('Frontier Cabin', 'Tanauan', 'Philippines', 1),
#  ('Lady Stage', 'Olomouc', 'Czech Republic', 1),
#  ('Graduate Lord', 'Kamjanets-Podilskyi', 'Ukraine', 1),
#  ('Pond Seattle', 'Emeishan', 'China', 1),
#  ('Details Packer', 'Southampton', 'United Kingdom', 1),
#  ('Oz Liaisons', 'Garland', 'United States', 1),
#  ('Streak Ridgemont', 'Dundee', 'United Kingdom', 1),
#  ('Kiss Glory', 'Nyeri', 'Kenya', 1),
#  ('Blues Instinct', 'Cape Coral', 'United States', 1),
#  ('Greedy Roots', 'Boa Vista', 'Brazil', 1),
#  ('Duffel Apocalypse', 'Amersfoort', 'Netherlands', 1),
#  ('Jacket Frisco', 'Sunnyvale', 'United States', 1),
#  ('Excitement Eve', 'Halisahar', 'India', 1),
#  ('Telemark Heartbreakers', 'Bergamo', 'Italy', 1),
#  ('Rouge Squad', 'Hunuco', 'Peru', 1),
#  ('Maude Mod', 'Mukateve', 'Ukraine', 1),
#  ('Hills Neighbors', 'Ambattur', 'India', 1),
#  ('Pickup Driving', 'San Bernardino', 'United States', 1),
#  ('Desperate Trainspotting', 'Atinsk', 'Russian Federation', 1),
#  ('Motions Details', 'Vinh', 'Vietnam', 1),
#  ('Mockingbird Hollywood', 'Miraj', 'India', 1),
#  ('Pacific Amistad', 'Dadu', 'Pakistan', 1),
#  ('Saturday Lambs', 'Southend-on-Sea', 'United Kingdom', 1),
#  ('Jet Neighbors', 'Fontana', 'United States', 1),
#  ('Camelot Vacation', 'Poos de Caldas', 'Brazil', 1),
#  ('Amadeus Holy', 'Matamoros', 'Mexico', 1),
#  ('Gun Bonnie', 'Sambhal', 'India', 1),
#  ('Frisco Forrest', 'Onomichi', 'Japan', 1),
#  ('Newsies Story', 'Santa F', 'Argentina', 1),
#  ('Stagecoach Armageddon', 'Hsichuh', 'Taiwan', 1),
#  ('Karate Moon', 'Balurghat', 'India', 1),
#  ('Fidelity Devil', 'Yuzhou', 'China', 1),
#  ('Hustler Party', 'Clarksville', 'United States', 1),
#  ('Forward Temple', 'San Felipe del Progreso', 'Mexico', 1),
#  ('Sleuth Orient', 'Vaduz', 'Liechtenstein', 1),
#  ('Westward Seabiscuit', 'Charlotte Amalie', 'Virgin Islands, U.S.', 1),
#  ('Wyoming Storm', 'Madiun', 'Indonesia', 1),
#  ('Heaven Freedom', 'Sucre', 'Bolivia', 1),
#  ('Mars Roman', 'Addis Abeba', 'Ethiopia', 1),
#  ('Blues Instinct', 'Tieli', 'China', 1),
#  ('Affair Prejudice', 'Crdoba', 'Argentina', 1),
#  ('Odds Boogie', 'Munger (Monghyr)', 'India', 1),
#  ('Volcano Texas', 's-Hertogenbosch', 'Netherlands', 1),
#  ('Feathers Metal', 'Naju', 'South Korea', 1),
#  ('Horror Reign', 'Merlo', 'Argentina', 1),
#  ('Outfield Massacre', 'Dundee', 'United Kingdom', 1),
#  ('Modern Dorado', 'Akron', 'United States', 1),
#  ('Horror Reign', 'Cuauhtmoc', 'Mexico', 1),
#  ('Donnie Alley', 'Bhimavaram', 'India', 1),
#  ('Freedom Cleopatra', 'York', 'United Kingdom', 1),
#  ('Angels Life', 'Teboksary', 'Russian Federation', 1),
#  ('Trading Pinocchio', 'Blumenau', 'Brazil', 1),
#  ('Sagebrush Clueless', 'Molodetno', 'Belarus', 1),
#  ('Backlash Undefeated', 'Maring', 'Brazil', 1),
#  ('Super Wyoming', 'Newcastle', 'South Africa', 1),
#  ('Earth Vision', 'Balaiha', 'Russian Federation', 1),
#  ('Magnolia Forrester', 'Shimonoseki', 'Japan', 1),
#  ('Fellowship Autumn', 'Okinawa', 'Japan', 1),
#  ('Wasteland Divine', 'Callao', 'Peru', 1),
#  ('Airplane Sierra', 'Jurez', 'Mexico', 1),
#  ('Goldfinger Sensibility', 'Athenai', 'Greece', 1),
#  ('Frost Head', 'Najafabad', 'Iran', 1),
#  ('Berets Agent', 'Osmaniye', 'Turkey', 1),
#  ('Basic Easy', 'Imus', 'Philippines', 1),
#  ('Arizona Bang', 'Molodetno', 'Belarus', 1),
#  ('Kissing Dolls', 'Sharja', 'United Arab Emirates', 1),
#  ('Kwai Homeward', 'Nam Dinh', 'Vietnam', 1),
#  ('Spoilers Hellfighters', 'Pontianak', 'Indonesia', 1),
#  ('Effect Gladiator', 'Novoterkassk', 'Russian Federation', 1),
#  ('Noon Papi', 'Garden Grove', 'United States', 1),
#  ('Heartbreakers Bright', 'Stockport', 'United Kingdom', 1),
#  ('Frost Head', 'Tsaotun', 'Taiwan', 1),
#  ('Princess Giant', 'London', 'United Kingdom', 1),
#  ('Suit Walls', 'Sousse', 'Tunisia', 1),
#  ('Secret Groundhog', 'Iwatsuki', 'Japan', 1),
#  ('Rings Heartbreakers', 'Rio Claro', 'Brazil', 1),
#  ('Lolita World', 'Tartu', 'Estonia', 1),
#  ('Expecations Natural', 'Bern', 'Switzerland', 1),
#  ('Jacket Frisco', 'al-Qatif', 'Saudi Arabia', 1),
#  ('West Lion', 'Shubra al-Khayma', 'Egypt', 1),
#  ('Illusion Amelie', 'Haldia', 'India', 1),
#  ('Butterfly Chocolat', 'Molodetno', 'Belarus', 1),
#  ('Canyon Stock', 'Tanshui', 'Taiwan', 1),
#  ('Packer Madigan', 'Fuzhou', 'China', 1),
#  ('Scalawag Duck', 'Udine', 'Italy', 1),
#  ('Pond Seattle', 'Phnom Penh', 'Cambodia', 1),
#  ('Rock Instinct', 'Bucuresti', 'Romania', 2),
#  ('Scorpion Apollo', 'Siegen', 'Germany', 1),
#  ('Wonka Sea', 'Mahajanga', 'Madagascar', 1),
#  ('Lolita World', 'Ife', 'Nigeria', 1),
#  ('Craft Outfield', 'Chatsworth', 'South Africa', 1),
#  ('Treatment Jekyll', 'Hiroshima', 'Japan', 1),
#  ('Madison Trap', 'Gaziantep', 'Turkey', 1),
#  ('Driving Polish', 'Angra dos Reis', 'Brazil', 1),
#  ('Goldmine Tycoon', 'Almirante Brown', 'Argentina', 1),
#  ('Hope Tootsie', 'Hohhot', 'China', 1),
#  ('Driving Polish', 'Brescia', 'Italy', 1),
#  ('Jumping Wrath', 'Hanoi', 'Vietnam', 1),
#  ('Summer Scarface', 'Santiago de Compostela', 'Spain', 1),
#  ('Gilbert Pelican', 'Papeete', 'French Polynesia', 1),
#  ('Prejudice Oleander', 'Saint-Denis', 'Runion', 1),
#  ('Insider Arizona', 'Erlangen', 'Germany', 1),
#  ('Outfield Massacre', 'Ljubertsy', 'Russian Federation', 1),
#  ('Pulp Beverly', 'Bchar', 'Algeria', 1),
#  ('Butterfly Chocolat', 'Dos Quebradas', 'Colombia', 1),
#  ('Goldmine Tycoon', 'Rustenburg', 'South Africa', 1),
#  ('Smoking Barbarella', 'Ilorin', 'Nigeria', 1),
#  ('Durham Panky', 'Atlixco', 'Mexico', 1),
#  ('Grit Clockwork', 'Southport', 'United Kingdom', 1),
#  ('Bingo Talented', 'Tambaram', 'India', 1),
#  ('Calendar Gunfight', 'Southend-on-Sea', 'United Kingdom', 1),
#  ('Pelican Comforts', 'Tete', 'Mozambique', 1),
#  ('Chasing Fight', 'Iwakuni', 'Japan', 1),
#  ('Sweethearts Suspects', 'Vilnius', 'Lithuania', 2),
#  ('Chamber Italian', 'Zaoyang', 'China', 1),
#  ('Greatest North', 'San Lorenzo', 'Paraguay', 1),
#  ('Bonnie Holocaust', 'Daugavpils', 'Latvia', 1),
#  ('Witches Panic', 'La Paz', 'Mexico', 1),
#  ('Sunset Racer', 'Chisinau', 'Moldova', 1),
#  ('Hobbit Alien', 'Kingstown', 'Saint Vincent and the Grenadines', 1),
#  ('Fugitive Maguire', 'Ede', 'Netherlands', 1),
#  ('Heavenly Gun', 'Sivas', 'Turkey', 1),
#  ('Bingo Talented', 'Ashqelon', 'Israel', 1),
#  ('Montezuma Command', 'Pontianak', 'Indonesia', 1),
#  ('Monster Spartacus', 'Kanazawa', 'Japan', 1),
#  ('Forward Temple', 'Asuncin', 'Paraguay', 1),
#  ('Darling Breaking', 'Haldia', 'India', 1),
#  ('Badman Dawn', 'Ozamis', 'Philippines', 1),
#  ('Manchurian Curtain', 'Cheju', 'South Korea', 1),
#  ('Sweet Brotherhood', 'Klerksdorp', 'South Africa', 1),
#  ('Sleepy Japanese', 'Cam Ranh', 'Vietnam', 1),
#  ('Run Pacific', 'Iwatsuki', 'Japan', 1),
#  ('Disturbing Scarface', 'Simferopol', 'Ukraine', 1),
#  ('English Bulworth', 'Simferopol', 'Ukraine', 1),
#  ('Tourist Pelican', 'Braslia', 'Brazil', 1),
#  ('Lord Arizona', 'Nyeri', 'Kenya', 1),
#  ('Hardly Robbers', 'Dundee', 'United Kingdom', 1),
#  ('Princess Giant', 'Kursk', 'Russian Federation', 1),
#  ('Music Boondock', 'Idfu', 'Egypt', 1),
#  ('Galaxy Sweethearts', 'Patiala', 'India', 1),
#  ('Tourist Pelican', 'Cuman', 'Venezuela', 1),
#  ('Right Cranes', 'Jedda', 'Saudi Arabia', 1),
#  ('Secret Groundhog', 'Bhavnagar', 'India', 1),
#  ('Color Philadelphia', 'Luzinia', 'Brazil', 1),
#  ('Deep Crusade', 'Johannesburg', 'South Africa', 1),
#  ('None Spiking', 'Gingoog', 'Philippines', 1),
#  ('Gun Bonnie', 'Saint Louis', 'United States', 1),
#  ('Midsummer Groundhog', 'Ife', 'Nigeria', 1),
#  ('Dances None', 'Kakamigahara', 'Japan', 1),
#  ('Wait Cider', 'Baiyin', 'China', 1),
#  ('Amistad Midsummer', 'Jastrzebie-Zdrj', 'Poland', 1),
#  ('Scorpion Apollo', 'Nagareyama', 'Japan', 1),
#  ('Midsummer Groundhog', 'Nantou', 'Taiwan', 1),
#  ('Married Go', 'Kakamigahara', 'Japan', 1),
#  ('Ties Hunger', 'Ibirit', 'Brazil', 1),
#  ('Stallion Sundance', 'Amroha', 'India', 1),
#  ('Wife Turn', 'Kaliningrad', 'Russian Federation', 1),
#  ('Bucket Brotherhood', 'Southport', 'United Kingdom', 1),
#  ('Roses Treasure', 'Pudukkottai', 'India', 1),
#  ('Blade Polish', 'Florencia', 'Colombia', 1),
#  ('Brotherhood Blanket', 'Bhavnagar', 'India', 1),
#  ('Truman Crazy', 'Angra dos Reis', 'Brazil', 1),
#  ('Coneheads Smoochy', 'Ahmadnagar', 'India', 1),
#  ('Polish Brooklyn', 'Ibirit', 'Brazil', 1),
#  ('Crossroads Casualties', 'Battambang', 'Cambodia', 1),
#  ('Taxi Kick', 'Madiun', 'Indonesia', 1),
#  ('Bowfinger Gables', 'Bhusawal', 'India', 1),
#  ('Magnolia Forrester', 'So Leopoldo', 'Brazil', 1),
#  ('Mission Zoolander', 'Osmaniye', 'Turkey', 1),
#  ('Innocent Usual', 'Dhule (Dhulia)', 'India', 1),
#  ('Slums Duck', 'Naju', 'South Korea', 1),
#  ('Factory Dragon', 'Stara Zagora', 'Bulgaria', 1),
#  ('Roman Punk', 'Rockford', 'United States', 1),
#  ('Identity Lover', 'Fuyu', 'China', 1),
#  ('Show Lord', 'Graz', 'Austria', 1),
#  ('Necklace Outbreak', 'Santo Andr', 'Brazil', 1),
#  ('Scarface Bang', 'Antofagasta', 'Chile', 1),
#  ('Roman Punk', 'Coquimbo', 'Chile', 1),
#  ('Chocolat Harry', 'Tabuk', 'Saudi Arabia', 1),
#  ('Seattle Expecations', 'Laredo', 'United States', 1),
#  ('Ice Crossing', 'El Fuerte', 'Mexico', 1),
#  ('Armageddon Lost', 'Rio Claro', 'Brazil', 1),
#  ('Valentine Vanishing', 'Yingkou', 'China', 1),
#  ('Caddyshack Jedi', 'Sorocaba', 'Brazil', 3),
#  ('Rocketeer Mother', 'Citrus Heights', 'United States', 1),
#  ('Factory Dragon', 'Shahr-e Kord', 'Iran', 1),
#  ('Troopers Metal', 'Qinhuangdao', 'China', 1),
#  ('Goodfellas Salute', 'Tangail', 'Bangladesh', 1),
#  ('Sun Confessions', 'Callao', 'Peru', 1),
#  ('Steel Santa', 'Coatzacoalcos', 'Mexico', 1),
#  ('Neighbors Charade', 'Nuuk', 'Greenland', 1),
#  ('Lose Inch', 'Citt del Vaticano', 'Holy See (Vatican City State)', 1),
#  ('Mystic Truman', 'Zhoushan', 'China', 1),
#  ('Greek Everyone', 'Karnal', 'India', 1),
#  ('Moonwalker Fool', 'Halle/Saale', 'Germany', 1),
#  ('Vacation Boondock', 'Smolensk', 'Russian Federation', 1),
#  ('Pirates Roxanne', 'Sanaa', 'Yemen', 1),
#  ('Hyde Doctor', 'Kaduna', 'Nigeria', 1),
#  ('Star Operation', 'Jamalpur', 'Bangladesh', 1),
#  ('Pirates Roxanne', 'Higashiosaka', 'Japan', 1),
#  ('Roman Punk', 'Nuuk', 'Greenland', 1),
#  ('Vacation Boondock', 'Newcastle', 'South Africa', 1),
#  ('American Circus', 'Callao', 'Peru', 1),
#  ('Sleeping Suspects', 'Kamyin', 'Russian Federation', 1),
#  ('Sorority Queen', 'Madiun', 'Indonesia', 1),
#  ('Attacks Hate', 'Aden', 'Yemen', 1),
#  ('Blanket Beverly', 'Antofagasta', 'Chile', 1),
#  ('Wind Phantom', 'San Felipe del Progreso', 'Mexico', 1),
#  ('Room Roman', 'Hagonoy', 'Philippines', 1),
#  ('Mourning Purple', 'Tanshui', 'Taiwan', 1),
#  ('Bringing Hysterical', 'Mit Ghamr', 'Egypt', 1),
#  ('Carrie Bunch', 'Carmen', 'Mexico', 1),
#  ('Worst Banger', 'Okara', 'Pakistan', 1),
#  ('Seven Swarm', 'Tonghae', 'South Korea', 1),
#  ('Annie Identity', 'Pangkal Pinang', 'Indonesia', 1),
#  ('Driving Polish', 'Lhokseumawe', 'Indonesia', 1),
#  ('Barbarella Streetcar', 'Qomsheh', 'Iran', 1),
#  ('Party Knock', 'Purwakarta', 'Indonesia', 1),
#  ('Saturday Lambs', 'Wroclaw', 'Poland', 1),
#  ('Dawn Pond', 'Uruapan', 'Mexico', 1),
#  ('Virginian Pluto', 'Iligan', 'Philippines', 1),
#  ('Enemy Odds', 'Salinas', 'United States', 1),
#  ...]

# %% [markdown]
# # 10
#
# ### List the film title, number of times it has been rented, and the most recent rental date, in order of least recently rented, then most rentals.

# %%
# %%sql
# EXPLAIN
# SELECT title, Count(*), MAX(rental_date)
# FROM film JOIN inventory
# ON film.film_id = inventory.film_id
# JOIN rental
# ON inventory.inventory_id = rental.inventory_id
# GROUP BY title
# ORDER BY MAX(rental_date) asc ;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 13 rows affected.
# [('Sort  (cost=779.62..782.12 rows=1000 width=31)',),
#  ('  Sort Key: (max(rental.rental_date))',),
#  ('  ->  HashAggregate  (cost=719.80..729.80 rows=1000 width=31)',),
#  ('        Group Key: film.title',),
#  ('        ->  Hash Join  (cost=204.57..599.47 rows=16044 width=23)',),
#  ('              Hash Cond: (inventory.film_id = film.film_id)',),
#  ('              ->  Hash Join  (cost=128.07..480.67 rows=16044 width=10)',),
#  ('                    Hash Cond: (rental.inventory_id = inventory.inventory_id)',),
#  ('                    ->  Seq Scan on rental  (cost=0.00..310.44 rows=16044 width=12)',),
#  ('                    ->  Hash  (cost=70.81..70.81 rows=4581 width=6)',),
#  ('                          ->  Seq Scan on inventory  (cost=0.00..70.81 rows=4581 width=6)',),
#  ('              ->  Hash  (cost=64.00..64.00 rows=1000 width=19)',),
#  ('                    ->  Seq Scan on film  (cost=0.00..64.00 rows=1000 width=19)',)]

# %%
# %%sql
# SELECT title, Count(*), MAX(rental_date)
# FROM film JOIN inventory
# ON film.film_id = inventory.film_id
# JOIN rental
# ON inventory.inventory_id = rental.inventory_id
# GROUP BY title
# ORDER BY MAX(rental_date) asc   ;
# Out:
#  * postgres://dsa_ro_user:***@pgsql.dsa.lan/dvdrental
# 958 rows affected.
# [('Graceland Dynamite', 6, datetime.datetime(2005, 8, 17, 7, 46, 54)),
#  ('Papi Necklace', 8, datetime.datetime(2005, 8, 17, 17, 16, 42)),
#  ('Hoosiers Birdcage', 8, datetime.datetime(2005, 8, 18, 0, 14, 3)),
#  ('Towers Hurricane', 11, datetime.datetime(2005, 8, 18, 2, 37, 7)),
#  ('Impact Aladdin', 9, datetime.datetime(2005, 8, 18, 3, 37, 31)),
#  ('Leathernecks Dwarfs', 7, datetime.datetime(2005, 8, 18, 7, 16, 58)),
#  ('Dares Pluto', 9, datetime.datetime(2005, 8, 18, 8, 7, 45)),
#  ('Conspiracy Spirit', 5, datetime.datetime(2005, 8, 18, 12, 58, 40)),
#  ('Lights Deer', 8, datetime.datetime(2005, 8, 18, 13, 42, 14)),
#  ('Miracle Virtual', 9, datetime.datetime(2005, 8, 18, 15, 15, 44)),
#  ('Fever Empire', 5, datetime.datetime(2005, 8, 18, 15, 32, 57)),
#  ('Youth Kick', 6, datetime.datetime(2005, 8, 18, 17, 31, 36)),
#  ('Bed Highball', 6, datetime.datetime(2005, 8, 18, 17, 34, 11)),
#  ('Superfly Trip', 10, datetime.datetime(2005, 8, 18, 18, 58, 35)),
#  ('Eve Resurrection', 7, datetime.datetime(2005, 8, 18, 19, 36, 5)),
#  ('Sling Luke', 6, datetime.datetime(2005, 8, 18, 20, 20, 59)),
#  ('Clue Grail', 7, datetime.datetime(2005, 8, 18, 22, 11, 37)),
#  ('Jersey Sassy', 6, datetime.datetime(2005, 8, 18, 23, 21, 50)),
#  ('Intolerable Intentions', 9, datetime.datetime(2005, 8, 19, 3, 38, 32)),
#  ('Jungle Closer', 9, datetime.datetime(2005, 8, 19, 4, 27, 5)),
#  ('Phantom Glory', 6, datetime.datetime(2005, 8, 19, 5, 11, 47)),
#  ('Atlantis Cause', 24, datetime.datetime(2005, 8, 19, 6, 38, 59)),
#  ('Language Cowboy', 11, datetime.datetime(2005, 8, 19, 7, 36, 42)),
#  ('Valentine Vanishing', 12, datetime.datetime(2005, 8, 19, 7, 47, 43)),
#  ('Panky Submarine', 15, datetime.datetime(2005, 8, 19, 9, 34, 2)),
#  ('Heavenly Gun', 7, datetime.datetime(2005, 8, 19, 9, 48, 52)),
#  ('Breaking Home', 13, datetime.datetime(2005, 8, 19, 10, 15, 19)),
#  ('Monsoon Cause', 9, datetime.datetime(2005, 8, 19, 10, 33, 52)),
#  ('Bowfinger Gables', 11, datetime.datetime(2005, 8, 19, 10, 49, 3)),
#  ('Runner Madigan', 8, datetime.datetime(2005, 8, 19, 11, 33, 20)),
#  ('Maude Mod', 8, datetime.datetime(2005, 8, 19, 12, 4, 3)),
#  ('Luck Opus', 10, datetime.datetime(2005, 8, 19, 13, 9, 54)),
#  ('Warlock Werewolf', 6, datetime.datetime(2005, 8, 19, 13, 12, 28)),
#  ('Jumanji Blade', 8, datetime.datetime(2005, 8, 19, 13, 56, 54)),
#  ('Frogmen Breaking', 10, datetime.datetime(2005, 8, 19, 15, 25, 48)),
#  ('Comforts Rush', 17, datetime.datetime(2005, 8, 19, 16, 50, 50)),
#  ('Smile Earring', 10, datetime.datetime(2005, 8, 19, 19, 11, 41)),
#  ('Magnificent Chitty', 8, datetime.datetime(2005, 8, 19, 19, 35, 13)),
#  ('Mussolini Spoilers', 5, datetime.datetime(2005, 8, 19, 20, 53, 43)),
#  ('Factory Dragon', 17, datetime.datetime(2005, 8, 19, 20, 55, 23)),
#  ('Killer Innocent', 6, datetime.datetime(2005, 8, 19, 23, 37, 52)),
#  ('Greek Everyone', 17, datetime.datetime(2005, 8, 19, 23, 38, 2)),
#  ('Private Drop', 5, datetime.datetime(2005, 8, 19, 23, 48, 23)),
#  ('Anonymous Human', 13, datetime.datetime(2005, 8, 20, 0, 18, 15)),
#  ('License Weekend', 7, datetime.datetime(2005, 8, 20, 5, 10, 39)),
#  ('Pilot Hoosiers', 16, datetime.datetime(2005, 8, 20, 5, 50, 5)),
#  ('Slipper Fidelity', 16, datetime.datetime(2005, 8, 20, 5, 59, 5)),
#  ('Arabia Dogma', 13, datetime.datetime(2005, 8, 20, 7, 47, 5)),
#  ('Holy Tadpole', 9, datetime.datetime(2005, 8, 20, 8, 27, 1)),
#  ('Idaho Love', 17, datetime.datetime(2005, 8, 20, 8, 27, 27)),
#  ('Birdcage Casper', 9, datetime.datetime(2005, 8, 20, 8, 27, 30)),
#  ('Chisum Behavior', 13, datetime.datetime(2005, 8, 20, 8, 57, 28)),
#  ('Chocolat Harry', 20, datetime.datetime(2005, 8, 20, 9, 7, 39)),
#  ('Beneath Rush', 10, datetime.datetime(2005, 8, 20, 9, 21, 8)),
#  ('Hamlet Wisdom', 14, datetime.datetime(2005, 8, 20, 10, 31, 1)),
#  ('Translation Summer', 15, datetime.datetime(2005, 8, 20, 11, 37, 56)),
#  ('Pickup Driving', 16, datetime.datetime(2005, 8, 20, 12, 11, 28)),
#  ('Noon Papi', 17, datetime.datetime(2005, 8, 20, 12, 33, 36)),
#  ('Jeopardy Encino', 10, datetime.datetime(2005, 8, 20, 12, 59, 38)),
#  ('Prix Undefeated', 11, datetime.datetime(2005, 8, 20, 13, 26, 37)),
#  ('Soldiers Evolution', 8, datetime.datetime(2005, 8, 20, 14, 6, 33)),
#  ('Divide Monster', 21, datetime.datetime(2005, 8, 20, 14, 23, 16)),
#  ('Speed Suit', 9, datetime.datetime(2005, 8, 20, 14, 42, 34)),
#  ('Stranger Strangers', 11, datetime.datetime(2005, 8, 20, 15, 18, 20)),
#  ('Chaplin License', 8, datetime.datetime(2005, 8, 20, 16, 2, 28)),
#  ('Braveheart Human', 5, datetime.datetime(2005, 8, 20, 16, 5, 11)),
#  ('Confused Candles', 17, datetime.datetime(2005, 8, 20, 16, 17, 27)),
#  ('Untouchables Sunrise', 8, datetime.datetime(2005, 8, 20, 16, 37, 35)),
#  ('Punk Divorce', 8, datetime.datetime(2005, 8, 20, 16, 51, 18)),
#  ('Something Duck', 19, datetime.datetime(2005, 8, 20, 17, 24, 45)),
#  ('Super Wyoming', 13, datetime.datetime(2005, 8, 20, 17, 58)),
#  ('Hanover Galaxy', 17, datetime.datetime(2005, 8, 20, 18, 42, 40)),
#  ('Empire Malkovich', 21, datetime.datetime(2005, 8, 20, 19, 3, 25)),
#  ('Doctor Grail', 7, datetime.datetime(2005, 8, 20, 19, 4, 40)),
#  ('Fire Wolves', 7, datetime.datetime(2005, 8, 20, 19, 19, 30)),
#  ('Evolution Alter', 12, datetime.datetime(2005, 8, 20, 20, 7, 15)),
#  ('Park Citizen', 8, datetime.datetime(2005, 8, 20, 20, 26, 53)),
#  ('Hawk Chill', 7, datetime.datetime(2005, 8, 20, 20, 42, 12)),
#  ('Anaconda Confessions', 21, datetime.datetime(2005, 8, 20, 21, 21, 8)),
#  ('Beethoven Exorcist', 11, datetime.datetime(2005, 8, 20, 21, 21, 34)),
#  ('Diary Panic', 9, datetime.datetime(2005, 8, 20, 21, 23, 54)),
#  ('Searchers Wait', 14, datetime.datetime(2005, 8, 20, 21, 26, 55)),
#  ('Past Suicides', 13, datetime.datetime(2005, 8, 20, 21, 50, 11)),
#  ('Soup Wisdom', 8, datetime.datetime(2005, 8, 20, 22, 40, 47)),
#  ('Lies Treatment', 27, datetime.datetime(2005, 8, 20, 23, 7, 10)),
#  ('Spirit Flintstones', 15, datetime.datetime(2005, 8, 20, 23, 18, 54)),
#  ('Hanging Deep', 19, datetime.datetime(2005, 8, 20, 23, 42, 31)),
#  ('Random Go', 9, datetime.datetime(2005, 8, 20, 23, 47, 54)),
#  ('Duffel Apocalypse', 7, datetime.datetime(2005, 8, 21, 0, 21, 29)),
#  ('Doubtfire Labyrinth', 10, datetime.datetime(2005, 8, 21, 0, 44, 34)),
#  ('Hollywood Anonymous', 13, datetime.datetime(2005, 8, 21, 1, 10, 29)),
#  ('Antitrust Tomatoes', 10, datetime.datetime(2005, 8, 21, 1, 31, 25)),
#  ('Loverboy Attacks', 12, datetime.datetime(2005, 8, 21, 1, 44, 14)),
#  ('Kane Exorcist', 14, datetime.datetime(2005, 8, 21, 2, 4, 33)),
#  ('Flight Lies', 12, datetime.datetime(2005, 8, 21, 2, 14, 3)),
#  ('Musketeers Wait', 17, datetime.datetime(2005, 8, 21, 2, 23, 25)),
#  ('Destiny Saturday', 16, datetime.datetime(2005, 8, 21, 2, 56, 52)),
#  ('Teen Apollo', 17, datetime.datetime(2005, 8, 21, 3, 32, 3)),
#  ('Wisdom Worker', 9, datetime.datetime(2005, 8, 21, 3, 40, 40)),
#  ('Treatment Jekyll', 7, datetime.datetime(2005, 8, 21, 4, 9, 18)),
#  ('Betrayed Rear', 15, datetime.datetime(2005, 8, 21, 4, 29, 11)),
#  ('Boiled Dares', 15, datetime.datetime(2005, 8, 21, 4, 30, 47)),
#  ('Stage World', 10, datetime.datetime(2005, 8, 21, 4, 49, 41)),
#  ('Clerks Angels', 7, datetime.datetime(2005, 8, 21, 4, 49, 48)),
#  ('Frontier Cabin', 6, datetime.datetime(2005, 8, 21, 5, 51, 28)),
#  ('Runaway Tenenbaums', 8, datetime.datetime(2005, 8, 21, 6, 18, 22)),
#  ('Pizza Jumanji', 7, datetime.datetime(2005, 8, 21, 6, 20, 14)),
#  ('Lost Bird', 12, datetime.datetime(2005, 8, 21, 6, 21, 24)),
#  ('Right Cranes', 10, datetime.datetime(2005, 8, 21, 6, 39, 8)),
#  ('Jacket Frisco', 18, datetime.datetime(2005, 8, 21, 7, 9, 27)),
#  ('Hysterical Grail', 15, datetime.datetime(2005, 8, 21, 7, 29, 5)),
#  ('Drumline Cyclone', 11, datetime.datetime(2005, 8, 21, 7, 56, 39)),
#  ('Bonnie Holocaust', 16, datetime.datetime(2005, 8, 21, 7, 59, 47)),
#  ('Elf Murder', 7, datetime.datetime(2005, 8, 21, 8, 8, 43)),
#  ('President Bang', 7, datetime.datetime(2005, 8, 21, 8, 33, 42)),
#  ('Spartacus Cheaper', 9, datetime.datetime(2005, 8, 21, 8, 40, 21)),
#  ('Primary Glass', 27, datetime.datetime(2005, 8, 21, 8, 58, 38)),
#  ('Hurricane Affair', 24, datetime.datetime(2005, 8, 21, 9, 4, 20)),
#  ('Easy Gladiator', 23, datetime.datetime(2005, 8, 21, 9, 6, 29)),
#  ('Mod Secretary', 11, datetime.datetime(2005, 8, 21, 9, 16, 40)),
#  ('Matrix Snowman', 9, datetime.datetime(2005, 8, 21, 9, 20, 3)),
#  ('School Jacket', 6, datetime.datetime(2005, 8, 21, 9, 25, 11)),
#  ('Home Pity', 14, datetime.datetime(2005, 8, 21, 9, 39, 50)),
#  ('Exorcist Sting', 13, datetime.datetime(2005, 8, 21, 9, 49, 28)),
#  ('Enemy Odds', 29, datetime.datetime(2005, 8, 21, 10, 10, 1)),
#  ('Platoon Instinct', 9, datetime.datetime(2005, 8, 21, 10, 16, 27)),
#  ('Craft Outfield', 16, datetime.datetime(2005, 8, 21, 10, 19, 25)),
#  ('Submarine Bed', 15, datetime.datetime(2005, 8, 21, 10, 22, 51)),
#  ('Wasteland Divine', 15, datetime.datetime(2005, 8, 21, 11, 20, 21)),
#  ('King Evolution', 9, datetime.datetime(2005, 8, 21, 11, 36, 15)),
#  ('Jaws Harry', 14, datetime.datetime(2005, 8, 21, 12, 7, 25)),
#  ('Wagon Jaws', 10, datetime.datetime(2005, 8, 21, 12, 10, 41)),
#  ('Vanilla Day', 9, datetime.datetime(2005, 8, 21, 12, 47, 38)),
#  ('Groove Fiction', 18, datetime.datetime(2005, 8, 21, 12, 47, 53)),
#  ('Freedom Cleopatra', 5, datetime.datetime(2005, 8, 21, 12, 48, 8)),
#  ('Tourist Pelican', 22, datetime.datetime(2005, 8, 21, 12, 48, 48)),
#  ('Homeward Cider', 16, datetime.datetime(2005, 8, 21, 13, 7, 24)),
#  ('Mile Mulan', 13, datetime.datetime(2005, 8, 21, 13, 22, 48)),
#  ('Full Flatliners', 5, datetime.datetime(2005, 8, 21, 13, 32, 38)),
#  ('Pluto Oleander', 16, datetime.datetime(2005, 8, 21, 13, 52, 54)),
#  ('Massage Image', 12, datetime.datetime(2005, 8, 21, 13, 53, 33)),
#  ('Grosse Wonderful', 8, datetime.datetime(2005, 8, 21, 13, 54, 15)),
#  ('Identity Lover', 13, datetime.datetime(2005, 8, 21, 13, 55, 39)),
#  ('Tomatoes Hellfighters', 14, datetime.datetime(2005, 8, 21, 14, 11, 19)),
#  ('Casualties Encino', 9, datetime.datetime(2005, 8, 21, 14, 47, 9)),
#  ('Uptown Young', 12, datetime.datetime(2005, 8, 21, 14, 51, 35)),
#  ('Elizabeth Shane', 10, datetime.datetime(2005, 8, 21, 14, 51, 52)),
#  ('Jedi Beneath', 19, datetime.datetime(2005, 8, 21, 14, 52, 14)),
#  ('Sensibility Rear', 10, datetime.datetime(2005, 8, 21, 14, 57, 3)),
#  ('Sorority Queen', 12, datetime.datetime(2005, 8, 21, 15, 24, 24)),
#  ('Lover Truman', 10, datetime.datetime(2005, 8, 21, 15, 44, 23)),
#  ('Cabin Flash', 15, datetime.datetime(2005, 8, 21, 15, 57, 25)),
#  ('Prejudice Oleander', 20, datetime.datetime(2005, 8, 21, 15, 59, 40)),
#  ('Agent Truman', 21, datetime.datetime(2005, 8, 21, 16, 3, 1)),
#  ('Bugsy Song', 11, datetime.datetime(2005, 8, 21, 16, 3, 27)),
#  ('Bunch Minds', 5, datetime.datetime(2005, 8, 21, 16, 5, 11)),
#  ('Traffic Hobbit', 5, datetime.datetime(2005, 8, 21, 16, 24, 45)),
#  ('Date Speed', 13, datetime.datetime(2005, 8, 21, 16, 32, 32)),
#  ('Lonely Elephant', 15, datetime.datetime(2005, 8, 21, 16, 44, 32)),
#  ('Dying Maker', 17, datetime.datetime(2005, 8, 21, 16, 52, 3)),
#  ('Finding Anaconda', 12, datetime.datetime(2005, 8, 21, 16, 56, 39)),
#  ('Destination Jerk', 8, datetime.datetime(2005, 8, 21, 17, 8, 33)),
#  ('Model Fish', 15, datetime.datetime(2005, 8, 21, 17, 30, 17)),
#  ('Feathers Metal', 11, datetime.datetime(2005, 8, 21, 17, 33, 18)),
#  ('Speakeasy Date', 12, datetime.datetime(2005, 8, 21, 17, 48, 49)),
#  ('Early Home', 7, datetime.datetime(2005, 8, 21, 17, 57, 26)),
#  ('Mixed Doors', 4, datetime.datetime(2005, 8, 21, 18, 34, 21)),
#  ('Dirty Ace', 15, datetime.datetime(2005, 8, 21, 18, 35, 44)),
#  ('Luke Mummy', 7, datetime.datetime(2005, 8, 21, 18, 35, 54)),
#  ('Shanghai Tycoon', 14, datetime.datetime(2005, 8, 21, 19, 1, 36)),
#  ('Jawbreaker Brooklyn', 10, datetime.datetime(2005, 8, 21, 19, 5, 23)),
#  ('Ending Crowds', 11, datetime.datetime(2005, 8, 21, 19, 9, 40)),
#  ('Strangelove Desire', 24, datetime.datetime(2005, 8, 21, 19, 12, 12)),
#  ('Legend Jedi', 9, datetime.datetime(2005, 8, 21, 19, 12, 47)),
#  ('Darling Breaking', 9, datetime.datetime(2005, 8, 21, 19, 14, 48)),
#  ('Thin Sagebrush', 11, datetime.datetime(2005, 8, 21, 19, 19, 21)),
#  ('Vietnam Smoochy', 15, datetime.datetime(2005, 8, 21, 19, 54, 11)),
#  ('Midsummer Groundhog', 22, datetime.datetime(2005, 8, 21, 19, 59, 30)),
#  ('Casper Dragonfly', 8, datetime.datetime(2005, 8, 21, 20, 1, 34)),
#  ('Waterfront Deliverance', 17, datetime.datetime(2005, 8, 21, 20, 12, 30)),
#  ('Aladdin Calendar', 23, datetime.datetime(2005, 8, 21, 20, 49, 21)),
#  ('Sabrina Midnight', 21, datetime.datetime(2005, 8, 21, 20, 53, 40)),
#  ('Texas Watch', 6, datetime.datetime(2005, 8, 21, 21, 2, 22)),
#  ('Wolves Desire', 21, datetime.datetime(2005, 8, 21, 21, 4, 42)),
#  ('Robbery Bright', 13, datetime.datetime(2005, 8, 21, 21, 27, 24)),
#  ('United Pilot', 17, datetime.datetime(2005, 8, 21, 21, 50, 51)),
#  ('Chicago North', 16, datetime.datetime(2005, 8, 21, 22, 12, 45)),
#  ('Eyes Driving', 19, datetime.datetime(2005, 8, 21, 22, 21, 49)),
#  ('Autumn Crow', 11, datetime.datetime(2005, 8, 21, 22, 25, 53)),
#  ('Harold French', 8, datetime.datetime(2005, 8, 21, 22, 27, 11)),
#  ('Wash Heavenly', 23, datetime.datetime(2005, 8, 21, 22, 53, 1)),
#  ('Attraction Newton', 24, datetime.datetime(2005, 8, 21, 23, 0, 2)),
#  ('Contact Anonymous', 26, datetime.datetime(2005, 8, 21, 23, 8, 33)),
#  ('Dalmations Sweden', 20, datetime.datetime(2005, 8, 21, 23, 9, 32)),
#  ('League Hellfighters', 17, datetime.datetime(2005, 8, 21, 23, 17, 26)),
#  ('Unforgiven Zoolander', 18, datetime.datetime(2005, 8, 21, 23, 33, 57)),
#  ('Neighbors Charade', 19, datetime.datetime(2005, 8, 21, 23, 40, 28)),
#  ('Pajama Jawbreaker', 14, datetime.datetime(2005, 8, 21, 23, 47, 16)),
#  ('Desperate Trainspotting', 6, datetime.datetime(2005, 8, 22, 0, 34, 17)),
#  ('Darkness War', 13, datetime.datetime(2005, 8, 22, 0, 40, 49)),
#  ('Goldfinger Sensibility', 24, datetime.datetime(2005, 8, 22, 0, 46, 54)),
#  ('Blood Argonauts', 10, datetime.datetime(2005, 8, 22, 0, 51, 25)),
#  ('Dolls Rage', 9, datetime.datetime(2005, 8, 22, 1, 0, 42)),
#  ('Gathering Calendar', 11, datetime.datetime(2005, 8, 22, 1, 9, 4)),
#  ('Valley Packer', 15, datetime.datetime(2005, 8, 22, 1, 10, 32)),
#  ('Durham Panky', 26, datetime.datetime(2005, 8, 22, 1, 12, 44)),
#  ('Daddy Pittsburgh', 13, datetime.datetime(2005, 8, 22, 1, 17, 16)),
#  ('Gentlemen Stage', 23, datetime.datetime(2005, 8, 22, 1, 17, 18)),
#  ('Potter Connecticut', 17, datetime.datetime(2005, 8, 22, 1, 20, 19)),
#  ('Tarzan Videotape', 8, datetime.datetime(2005, 8, 22, 1, 32, 14)),
#  ('Ship Wonderland', 15, datetime.datetime(2005, 8, 22, 1, 35, 37)),
#  ('Vampire Whale', 12, datetime.datetime(2005, 8, 22, 1, 52, 26)),
#  ('Rushmore Mermaid', 6, datetime.datetime(2005, 8, 22, 1, 58, 15)),
#  ('Majestic Floats', 17, datetime.datetime(2005, 8, 22, 2, 4, 38)),
#  ('Anything Savannah', 9, datetime.datetime(2005, 8, 22, 2, 9, 12)),
#  ('Paradise Sabrina', 18, datetime.datetime(2005, 8, 22, 2, 13, 51)),
#  ('Dream Pickup', 22, datetime.datetime(2005, 8, 22, 2, 20, 44)),
#  ('Shakespeare Saddle', 22, datetime.datetime(2005, 8, 22, 2, 26, 33)),
#  ('Command Darling', 16, datetime.datetime(2005, 8, 22, 2, 57, 4)),
#  ('Brooklyn Desert', 21, datetime.datetime(2005, 8, 22, 3, 20, 26)),
#  ('Interview Liaisons', 20, datetime.datetime(2005, 8, 22, 3, 42, 12)),
#  ('Baby Hall', 8, datetime.datetime(2005, 8, 22, 3, 47, 39)),
#  ('Alamo Videotape', 24, datetime.datetime(2005, 8, 22, 4, 4, 31)),
#  ('Robbers Joon', 31, datetime.datetime(2005, 8, 22, 4, 9, 18)),
#  ('Ladybugs Armageddon', 6, datetime.datetime(2005, 8, 22, 4, 15, 48)),
#  ('Guys Falcon', 9, datetime.datetime(2005, 8, 22, 4, 31, 50)),
#  ('Mission Zoolander', 18, datetime.datetime(2005, 8, 22, 4, 51, 42)),
#  ('Gandhi Kwai', 17, datetime.datetime(2005, 8, 22, 5, 7, 17)),
#  ('Bright Encounters', 13, datetime.datetime(2005, 8, 22, 5, 16, 16)),
#  ('Notting Speakeasy', 10, datetime.datetime(2005, 8, 22, 5, 38, 32)),
#  ('Clones Pinocchio', 19, datetime.datetime(2005, 8, 22, 5, 53, 52)),
#  ('Scissorhands Slums', 15, datetime.datetime(2005, 8, 22, 5, 59, 59)),
#  ('Fury Murder', 19, datetime.datetime(2005, 8, 22, 6, 5, 38)),
#  ('Savannah Town', 12, datetime.datetime(2005, 8, 22, 6, 7, 52)),
#  ('Opus Ice', 11, datetime.datetime(2005, 8, 22, 6, 10, 53)),
#  ('Chariots Conspiracy', 21, datetime.datetime(2005, 8, 22, 6, 17, 12)),
#  ('Nash Chocolat', 15, datetime.datetime(2005, 8, 22, 6, 19, 37)),
#  ('Connecticut Tramp', 13, datetime.datetime(2005, 8, 22, 6, 23, 54)),
#  ('Fargo Gandhi', 24, datetime.datetime(2005, 8, 22, 6, 29, 34)),
#  ('Graduate Lord', 16, datetime.datetime(2005, 8, 22, 6, 30, 10)),
#  ('Pittsburgh Hunchback', 12, datetime.datetime(2005, 8, 22, 6, 37, 43)),
#  ('Kiss Glory', 22, datetime.datetime(2005, 8, 22, 6, 39, 24)),
#  ('Behavior Runaway', 13, datetime.datetime(2005, 8, 22, 6, 46, 3)),
#  ('Resurrection Silverado', 21, datetime.datetime(2005, 8, 22, 6, 46, 59)),
#  ('Terminator Club', 6, datetime.datetime(2005, 8, 22, 6, 49, 15)),
#  ('Candles Grapes', 23, datetime.datetime(2005, 8, 22, 6, 49, 29)),
#  ('Rules Human', 16, datetime.datetime(2005, 8, 22, 6, 53, 21)),
#  ('Mermaid Insects', 16, datetime.datetime(2005, 8, 22, 7, 4, 25)),
#  ('Alley Evolution', 14, datetime.datetime(2005, 8, 22, 7, 10, 26)),
#  ('Monterey Labyrinth', 13, datetime.datetime(2005, 8, 22, 7, 16, 45)),
#  ('Egg Igby', 21, datetime.datetime(2005, 8, 22, 7, 19, 5)),
#  ('Shane Darkness', 14, datetime.datetime(2005, 8, 22, 7, 32, 23)),
#  ('Gosford Donnie', 8, datetime.datetime(2005, 8, 22, 7, 35, 31)),
#  ('Fool Mockingbird', 23, datetime.datetime(2005, 8, 22, 7, 37, 24)),
#  ('Tequila Past', 6, datetime.datetime(2005, 8, 22, 7, 48, 1)),
#  ('West Lion', 16, datetime.datetime(2005, 8, 22, 7, 51, 47)),
#  ('Sleuth Orient', 21, datetime.datetime(2005, 8, 22, 8, 21, 21)),
#  ('Taxi Kick', 17, datetime.datetime(2005, 8, 22, 8, 27, 27)),
#  ('Pet Haunting', 8, datetime.datetime(2005, 8, 22, 8, 43, 50)),
#  ('Run Pacific', 10, datetime.datetime(2005, 8, 22, 8, 52, 53)),
#  ('Unfaithful Kill', 8, datetime.datetime(2005, 8, 22, 9, 3, 44)),
#  ('Lose Inch', 27, datetime.datetime(2005, 8, 22, 9, 25, 24)),
#  ('Expecations Natural', 18, datetime.datetime(2005, 8, 22, 9, 33, 8)),
#  ('Cupboard Sinners', 23, datetime.datetime(2005, 8, 22, 9, 37, 54)),
#  ('Splash Gump', 14, datetime.datetime(2005, 8, 22, 9, 49, 32)),
#  ('French Holiday', 17, datetime.datetime(2005, 8, 22, 9, 54, 54)),
#  ('Oleander Clue', 10, datetime.datetime(2005, 8, 22, 10, 0, 4)),
#  ('Sun Confessions', 25, datetime.datetime(2005, 8, 22, 10, 7, 52)),
#  ('Divorce Shining', 7, datetime.datetime(2005, 8, 22, 10, 13, 9)),
#  ('Knock Warlock', 24, datetime.datetime(2005, 8, 22, 10, 14, 33)),
#  ('Moulin Wake', 16, datetime.datetime(2005, 8, 22, 10, 24, 32)),
#  ('Rush Goodfellas', 31, datetime.datetime(2005, 8, 22, 10, 29, 44)),
#  ('Wars Pluto', 10, datetime.datetime(2005, 8, 22, 10, 34, 39)),
#  ('Drop Waterfront', 9, datetime.datetime(2005, 8, 22, 10, 39, 51)),
#  ('Moon Bunch', 29, datetime.datetime(2005, 8, 22, 10, 49, 6)),
#  ('Money Harold', 20, datetime.datetime(2005, 8, 22, 10, 55, 45)),
#  ('Notorious Reunion', 14, datetime.datetime(2005, 8, 22, 10, 58, 45)),
#  ('Sunrise League', 24, datetime.datetime(2005, 8, 22, 11, 1, 15)),
#  ('Tramp Others', 20, datetime.datetime(2005, 8, 22, 11, 5, 34)),
#  ('Pond Seattle', 19, datetime.datetime(2005, 8, 22, 11, 9, 18)),
#  ('Dancing Fever', 27, datetime.datetime(2005, 8, 22, 11, 11, 51)),
#  ('Magnolia Forrester', 11, datetime.datetime(2005, 8, 22, 11, 14, 31)),
#  ('Godfather Diary', 8, datetime.datetime(2005, 8, 22, 11, 19, 22)),
#  ('Lola Agent', 24, datetime.datetime(2005, 8, 22, 11, 36, 16)),
#  ('Hope Tootsie', 18, datetime.datetime(2005, 8, 22, 11, 43, 4)),
#  ('Newton Labyrinth', 17, datetime.datetime(2005, 8, 22, 11, 43, 42)),
#  ('Watership Frontier', 6, datetime.datetime(2005, 8, 22, 11, 48, 19)),
#  ('Hollow Jeopardy', 10, datetime.datetime(2005, 8, 22, 11, 49, 16)),
#  ('Christmas Moonshine', 21, datetime.datetime(2005, 8, 22, 11, 56, 2)),
#  ('Kramer Chocolate', 9, datetime.datetime(2005, 8, 22, 11, 58, 58)),
#  ('Cranes Reservoir', 11, datetime.datetime(2005, 8, 22, 12, 1, 6)),
#  ('Fantasy Troopers', 26, datetime.datetime(2005, 8, 22, 12, 16, 46)),
#  ('Madison Trap', 15, datetime.datetime(2005, 8, 22, 12, 24, 55)),
#  ('Maguire Apache', 9, datetime.datetime(2005, 8, 22, 12, 38, 20)),
#  ('Goldmine Tycoon', 27, datetime.datetime(2005, 8, 22, 12, 47, 45)),
#  ('Spiking Element', 13, datetime.datetime(2005, 8, 22, 13, 3, 52)),
#  ('Liaisons Sweet', 22, datetime.datetime(2005, 8, 22, 13, 4, 32)),
#  ('Hobbit Alien', 31, datetime.datetime(2005, 8, 22, 13, 6, 26)),
#  ('Metropolis Coma', 26, datetime.datetime(2005, 8, 22, 13, 19, 25)),
#  ('Crazy Home', 9, datetime.datetime(2005, 8, 22, 13, 20, 28)),
#  ('Fellowship Autumn', 26, datetime.datetime(2005, 8, 22, 13, 39, 20)),
#  ('Slums Duck', 24, datetime.datetime(2005, 8, 22, 13, 59, 19)),
#  ('Thief Pelican', 19, datetime.datetime(2005, 8, 22, 14, 23, 11)),
#  ('Disturbing Scarface', 26, datetime.datetime(2005, 8, 22, 14, 26, 1)),
#  ('Minds Truman', 20, datetime.datetime(2005, 8, 22, 14, 27, 46)),
#  ('Grinch Massage', 14, datetime.datetime(2005, 8, 22, 14, 41, 5)),
#  ('Sinners Atlantis', 22, datetime.datetime(2005, 8, 22, 14, 59, 30)),
#  ('Confessions Maguire', 14, datetime.datetime(2005, 8, 22, 15, 21, 56)),
#  ('Innocent Usual', 26, datetime.datetime(2005, 8, 22, 15, 22, 15)),
#  ('Legally Secretary', 9, datetime.datetime(2005, 8, 22, 15, 25, 33)),
#  ('Videotape Arsenic', 29, datetime.datetime(2005, 8, 22, 15, 29, 15)),
#  ('Personal Ladybugs', 14, datetime.datetime(2005, 8, 22, 15, 30, 25)),
#  ('Ballroom Mockingbird', 8, datetime.datetime(2005, 8, 22, 15, 42, 57)),
#  ('Excitement Eve', 21, datetime.datetime(2005, 8, 22, 15, 52, 57)),
#  ('Lambs Cincinatti', 10, datetime.datetime(2005, 8, 22, 15, 53, 32)),
#  ('Mask Peach', 17, datetime.datetime(2005, 8, 22, 15, 56, 42)),
#  ('Impossible Prejudice', 14, datetime.datetime(2005, 8, 22, 15, 57, 38)),
#  ('Turn Star', 14, datetime.datetime(2005, 8, 22, 16, 6, 23)),
#  ('Donnie Alley', 14, datetime.datetime(2005, 8, 22, 16, 8, 23)),
#  ('Feud Frogmen', 25, datetime.datetime(2005, 8, 22, 16, 11, 32)),
#  ('Elephant Trojan', 14, datetime.datetime(2005, 8, 22, 16, 15, 33)),
#  ('Desire Alien', 8, datetime.datetime(2005, 8, 22, 16, 22, 53)),
#  ('Informer Double', 5, datetime.datetime(2005, 8, 22, 16, 26, 53)),
#  ('Flatliners Killer', 22, datetime.datetime(2005, 8, 22, 16, 30, 43)),
#  ('Reef Salute', 11, datetime.datetime(2005, 8, 22, 16, 32, 23)),
#  ('Straight Hours', 20, datetime.datetime(2005, 8, 22, 16, 33, 39)),
#  ('Vision Torque', 7, datetime.datetime(2005, 8, 22, 16, 35, 47)),
#  ('Spy Mile', 27, datetime.datetime(2005, 8, 22, 16, 37, 36)),
#  ('Patriot Roman', 16, datetime.datetime(2005, 8, 22, 16, 40, 21)),
#  ('Hours Rage', 19, datetime.datetime(2005, 8, 22, 16, 49, 2)),
#  ('High Encino', 22, datetime.datetime(2005, 8, 22, 16, 55, 26)),
#  ('Giant Troopers', 28, datetime.datetime(2005, 8, 22, 16, 57, 2)),
#  ('Rider Caddyshack', 11, datetime.datetime(2005, 8, 22, 17, 0, 31)),
#  ('Airplane Sierra', 15, datetime.datetime(2005, 8, 22, 17, 18, 5)),
#  ('Gilmore Boiled', 28, datetime.datetime(2005, 8, 22, 17, 18, 32)),
#  ('Panther Reds', 15, datetime.datetime(2005, 8, 22, 17, 22, 41)),
#  ('Madness Attacks', 25, datetime.datetime(2005, 8, 22, 17, 27, 23)),
#  ('Panic Club', 7, datetime.datetime(2005, 8, 22, 17, 32, 57)),
#  ('Human Graffiti', 15, datetime.datetime(2005, 8, 22, 17, 46, 41)),
#  ('Control Anthem', 7, datetime.datetime(2005, 8, 22, 17, 47, 40)),
#  ('Independence Hotel', 19, datetime.datetime(2005, 8, 22, 17, 48, 10)),
#  ('Watch Tracy', 16, datetime.datetime(2005, 8, 22, 17, 48, 28)),
#  ('Mannequin Worst', 5, datetime.datetime(2005, 8, 22, 17, 49, 35)),
#  ('Deceiver Betrayed', 21, datetime.datetime(2005, 8, 22, 17, 53, 6)),
#  ('Analyze Hoosiers', 14, datetime.datetime(2005, 8, 22, 17, 58, 27)),
#  ('Ishtar Rocketeer', 7, datetime.datetime(2005, 8, 22, 18, 3, 11)),
#  ('Handicap Boondock', 28, datetime.datetime(2005, 8, 22, 18, 4, 22)),
#  ('Town Ark', 14, datetime.datetime(2005, 8, 22, 18, 5, 21)),
#  ('Daisy Menagerie', 16, datetime.datetime(2005, 8, 22, 18, 21, 4)),
#  ('Army Flintstones', 16, datetime.datetime(2005, 8, 22, 18, 27, 33)),
#  ('Egypt Tenenbaums', 17, datetime.datetime(2005, 8, 22, 18, 39, 11)),
#  ('Tootsie Pilot', 15, datetime.datetime(2005, 8, 22, 18, 48, 42)),
#  ('Unbreakable Karate', 21, datetime.datetime(2005, 8, 22, 18, 48, 48)),
#  ('Mars Roman', 19, datetime.datetime(2005, 8, 22, 18, 53, 28)),
#  ('Freaky Pocus', 17, datetime.datetime(2005, 8, 22, 18, 57, 39)),
#  ('Words Hunter', 16, datetime.datetime(2005, 8, 22, 18, 59, 1)),
#  ('Gun Bonnie', 25, datetime.datetime(2005, 8, 22, 19, 2, 48)),
#  ('Doom Dancing', 21, datetime.datetime(2005, 8, 22, 19, 8, 49)),
#  ('Salute Apollo', 23, datetime.datetime(2005, 8, 22, 19, 9, 52)),
#  ('Gone Trouble', 10, datetime.datetime(2005, 8, 22, 19, 16, 4)),
#  ('Bulworth Commandments', 7, datetime.datetime(2005, 8, 22, 19, 17, 24)),
#  ('Hotel Happiness', 9, datetime.datetime(2005, 8, 22, 19, 23, 58)),
#  ('Beast Hunchback', 11, datetime.datetime(2005, 8, 22, 19, 28, 2)),
#  ('Flamingos Connecticut', 23, datetime.datetime(2005, 8, 22, 19, 28, 4)),
#  ('Moonshine Cabin', 21, datetime.datetime(2005, 8, 22, 19, 37, 20)),
#  ('Fireball Philadelphia', 21, datetime.datetime(2005, 8, 22, 19, 41, 37)),
#  ('Kwai Homeward', 23, datetime.datetime(2005, 8, 22, 19, 44)),
#  ('Artist Coldblooded', 16, datetime.datetime(2005, 8, 22, 19, 44, 53)),
#  ('Gold River', 14, datetime.datetime(2005, 8, 22, 19, 44, 59)),
#  ('Virgin Daisy', 17, datetime.datetime(2005, 8, 22, 19, 45, 57)),
#  ('Campus Remember', 19, datetime.datetime(2005, 8, 22, 19, 46, 36)),
#  ('Worker Tarzan', 15, datetime.datetime(2005, 8, 22, 19, 54, 26)),
#  ('Mourning Purple', 21, datetime.datetime(2005, 8, 22, 19, 54, 52)),
#  ('Married Go', 30, datetime.datetime(2005, 8, 22, 19, 56, 41)),
#  ('Bikini Borrowers', 17, datetime.datetime(2005, 8, 22, 20, 3, 46)),
#  ('Cheaper Clyde', 20, datetime.datetime(2005, 8, 22, 20, 17, 49)),
#  ('Driving Polish', 21, datetime.datetime(2005, 8, 22, 20, 22, 40)),
#  ('Secret Groundhog', 21, datetime.datetime(2005, 8, 22, 20, 27, 38)),
#  ('Wrath Mile', 14, datetime.datetime(2005, 8, 22, 20, 31, 38)),
#  ('Rocky War', 16, datetime.datetime(2005, 8, 22, 20, 41, 53)),
#  ('Hardly Robbers', 4, datetime.datetime(2005, 8, 22, 20, 44, 6)),
#  ('Storm Happiness', 29, datetime.datetime(2005, 8, 22, 20, 44, 35)),
#  ('Butterfly Chocolat', 30, datetime.datetime(2005, 8, 22, 20, 47, 48)),
#  ('Silence Kane', 16, datetime.datetime(2005, 8, 22, 20, 55, 56)),
#  ('Memento Zoolander', 13, datetime.datetime(2005, 8, 22, 21, 1, 25)),
#  ('Secrets Paradise', 20, datetime.datetime(2005, 8, 22, 21, 1, 48)),
#  ('Satisfaction Confidential', 17, datetime.datetime(2005, 8, 22, 21, 5, 50)),
#  ('Tenenbaums Command', 13, datetime.datetime(2005, 8, 22, 21, 13, 51)),
#  ('Rear Trading', 17, datetime.datetime(2005, 8, 22, 21, 15, 46)),
#  ('Truman Crazy', 23, datetime.datetime(2005, 8, 22, 21, 18, 59)),
#  ('Sassy Packer', 13, datetime.datetime(2005, 8, 22, 21, 19, 24)),
#  ('Wonderful Drop', 9, datetime.datetime(2005, 8, 22, 21, 24, 19)),
#  ('Closer Bang', 28, datetime.datetime(2005, 8, 22, 21, 28, 59)),
#  ('Conquerer Nuts', 16, datetime.datetime(2005, 8, 22, 21, 29, 14)),
#  ('Holocaust Highball', 17, datetime.datetime(2005, 8, 22, 21, 36, 51)),
#  ('Ferris Mother', 17, datetime.datetime(2005, 8, 22, 21, 39, 45)),
#  ('Labyrinth League', 15, datetime.datetime(2005, 8, 22, 21, 41, 40)),
#  ('Room Roman', 20, datetime.datetime(2005, 8, 22, 21, 42, 17)),
#  ('Stepmom Dream', 20, datetime.datetime(2005, 8, 22, 22, 12, 2)),
#  ('Cowboy Doom', 7, datetime.datetime(2005, 8, 22, 22, 28, 36)),
#  ('Bingo Talented', 29, datetime.datetime(2005, 8, 22, 22, 30, 50)),
#  ('Anthem Luke', 15, datetime.datetime(2005, 8, 22, 22, 37, 34)),
#  ('Stone Fire', 11, datetime.datetime(2005, 8, 22, 22, 49, 13)),
#  ('Brotherhood Blanket', 26, datetime.datetime(2005, 8, 22, 22, 57, 25)),
#  ('Novocaine Flight', 19, datetime.datetime(2005, 8, 22, 23, 6, 25)),
#  ('Flintstones Happiness', 17, datetime.datetime(2005, 8, 22, 23, 8, 46)),
#  ('Steers Armageddon', 15, datetime.datetime(2005, 8, 22, 23, 11, 59)),
#  ('Galaxy Sweethearts', 18, datetime.datetime(2005, 8, 22, 23, 17, 41)),
#  ('Victory Academy', 9, datetime.datetime(2005, 8, 22, 23, 18, 10)),
#  ('Secretary Rouge', 18, datetime.datetime(2005, 8, 22, 23, 19, 44)),
#  ('Arachnophobia Rollercoaster', 24, datetime.datetime(2005, 8, 22, 23, 26, 32)),
#  ('Weekend Personal', 18, datetime.datetime(2005, 8, 22, 23, 35, 41)),
#  ('Magic Mallrats', 7, datetime.datetime(2005, 8, 22, 23, 38, 1)),
#  ('Trap Guys', 16, datetime.datetime(2005, 8, 22, 23, 48, 56)),
#  ('Drums Dynamite', 13, datetime.datetime(2005, 8, 22, 23, 51, 23)),
#  ('Congeniality Quest', 22, datetime.datetime(2005, 8, 22, 23, 54, 14)),
#  ('Dozen Lion', 7, datetime.datetime(2005, 8, 22, 23, 54, 36)),
#  ('Fatal Haunted', 28, datetime.datetime(2005, 8, 22, 23, 55, 51)),
#  ('Metal Armageddon', 25, datetime.datetime(2005, 8, 22, 23, 58, 9)),
#  ('Caribbean Liberty', 9, datetime.datetime(2005, 8, 23, 0, 5, 57)),
#  ('Muscle Bright', 30, datetime.datetime(2005, 8, 23, 0, 7, 53)),
#  ('War Notting', 12, datetime.datetime(2005, 8, 23, 0, 11, 52)),
#  ('Freddy Storm', 23, datetime.datetime(2005, 8, 23, 0, 30, 26)),
#  ('Jingle Sagebrush', 13, datetime.datetime(2005, 8, 23, 0, 37, 21)),
#  ('Daughter Madigan', 9, datetime.datetime(2005, 8, 23, 0, 46, 52)),
#  ('Calendar Gunfight', 21, datetime.datetime(2005, 8, 23, 0, 49, 24)),
#  ('Timberland Sky', 31, datetime.datetime(2005, 8, 23, 0, 53, 57)),
#  ('Double Wrath', 25, datetime.datetime(2005, 8, 23, 0, 56, 1)),
#  ('Balloon Homeward', 23, datetime.datetime(2005, 8, 23, 0, 56, 27)),
#  ('Academy Dinosaur', 23, datetime.datetime(2005, 8, 23, 1, 1, 1)),
#  ('Worst Banger', 16, datetime.datetime(2005, 8, 23, 1, 13, 52)),
#  ('Redemption Comforts', 20, datetime.datetime(2005, 8, 23, 1, 14, 1)),
#  ('Creepers Kane', 14, datetime.datetime(2005, 8, 23, 1, 15, 7)),
#  ('Casablanca Super', 16, datetime.datetime(2005, 8, 23, 1, 16, 55)),
#  ('Simon North', 6, datetime.datetime(2005, 8, 23, 1, 22, 12)),
#  ('Loser Hustler', 15, datetime.datetime(2005, 8, 23, 1, 25, 30)),
#  ('Holiday Games', 15, datetime.datetime(2005, 8, 23, 1, 29, 59)),
#  ('Menagerie Rushmore', 7, datetime.datetime(2005, 8, 23, 1, 38, 48)),
#  ('Blackout Private', 27, datetime.datetime(2005, 8, 23, 1, 39, 10)),
#  ('Won Dares', 9, datetime.datetime(2005, 8, 23, 1, 44, 43)),
#  ('Madigan Dorado', 10, datetime.datetime(2005, 8, 23, 1, 45, 7)),
#  ('Young Language', 7, datetime.datetime(2005, 8, 23, 1, 50, 31)),
#  ('Reservoir Adaptation', 10, datetime.datetime(2005, 8, 23, 1, 57, 20)),
#  ('Rebel Airport', 8, datetime.datetime(2005, 8, 23, 1, 59, 14)),
#  ('Packer Madigan', 22, datetime.datetime(2005, 8, 23, 2, 2, 53)),
#  ('Million Ace', 20, datetime.datetime(2005, 8, 23, 2, 5, 51)),
#  ('Working Microcosmos', 25, datetime.datetime(2005, 8, 23, 2, 6, 1)),
#  ('Coma Head', 26, datetime.datetime(2005, 8, 23, 2, 6, 41)),
#  ('Streetcar Intentions', 25, datetime.datetime(2005, 8, 23, 2, 8, 18)),
#  ('Ice Crossing', 24, datetime.datetime(2005, 8, 23, 2, 8, 40)),
#  ('Pacific Amistad', 24, datetime.datetime(2005, 8, 23, 2, 25, 9)),
#  ('Games Bowfinger', 14, datetime.datetime(2005, 8, 23, 2, 33, 27)),
#  ('Cruelty Unforgiven', 7, datetime.datetime(2005, 8, 23, 2, 39, 37)),
#  ('Wind Phantom', 23, datetime.datetime(2005, 8, 23, 2, 39, 56)),
#  ('Honey Ties', 19, datetime.datetime(2005, 8, 23, 2, 45, 21)),
#  ('Highball Potter', 21, datetime.datetime(2005, 8, 23, 2, 48, 24)),
#  ('Raging Airplane', 13, datetime.datetime(2005, 8, 23, 2, 51, 27)),
#  ('Rings Heartbreakers', 15, datetime.datetime(2005, 8, 23, 2, 55, 42)),
#  ('Spice Sorority', 20, datetime.datetime(2005, 8, 23, 3, 1, 56)),
#  ('Nemo Campus', 14, datetime.datetime(2005, 8, 23, 3, 3, 40)),
#  ('Sugar Wonka', 17, datetime.datetime(2005, 8, 23, 3, 3, 53)),
#  ('Jeepers Wedding', 16, datetime.datetime(2005, 8, 23, 3, 13, 1)),
#  ('Gunfighter Mussolini', 12, datetime.datetime(2005, 8, 23, 3, 30, 45)),
#  ('Annie Identity', 22, datetime.datetime(2005, 8, 23, 3, 30, 51)),
#  ('Lion Uncut', 18, datetime.datetime(2005, 8, 23, 3, 32, 31)),
#  ('Oklahoma Jumanji', 6, datetime.datetime(2005, 8, 23, 3, 44, 30)),
#  ('Alter Victory', 22, datetime.datetime(2005, 8, 23, 3, 44, 51)),
#  ('Talented Homicide', 29, datetime.datetime(2005, 8, 23, 3, 46, 47)),
#  ('Apocalypse Flamingos', 6, datetime.datetime(2005, 8, 23, 3, 50, 48)),
#  ('Lock Rear', 16, datetime.datetime(2005, 8, 23, 3, 52, 36)),
#  ('Heavyweights Beast', 23, datetime.datetime(2005, 8, 23, 3, 54, 39)),
#  ('Lesson Cleopatra', 7, datetime.datetime(2005, 8, 23, 3, 58, 2)),
#  ('Oz Liaisons', 24, datetime.datetime(2005, 8, 23, 4, 0, 30)),
#  ('Hills Neighbors', 25, datetime.datetime(2005, 8, 23, 4, 17, 56)),
#  ('Core Suit', 18, datetime.datetime(2005, 8, 23, 4, 20, 16)),
#  ('Seven Swarm', 5, datetime.datetime(2005, 8, 23, 4, 28, 25)),
#  ('Voice Peach', 19, datetime.datetime(2005, 8, 23, 4, 33, 23)),
#  ('Glory Tracy', 5, datetime.datetime(2005, 8, 23, 4, 33, 39)),
#  ('Attacks Hate', 16, datetime.datetime(2005, 8, 23, 4, 48, 12)),
#  ('Head Stranger', 22, datetime.datetime(2005, 8, 23, 4, 51, 52)),
#  ('Shootist Superfly', 24, datetime.datetime(2005, 8, 23, 5, 1, 13)),
#  ('Uncut Suicides', 14, datetime.datetime(2005, 8, 23, 5, 4, 33)),
#  ('Arizona Bang', 21, datetime.datetime(2005, 8, 23, 5, 8, 58)),
#  ('Dogma Family', 30, datetime.datetime(2005, 8, 23, 5, 24, 29)),
#  ('Clockwork Paradise', 10, datetime.datetime(2005, 8, 23, 5, 26, 30)),
#  ('Reap Unfaithful', 16, datetime.datetime(2005, 8, 23, 5, 32, 3)),
#  ('Coldblooded Darling', 16, datetime.datetime(2005, 8, 23, 5, 39, 6)),
#  ('Sea Virgin', 22, datetime.datetime(2005, 8, 23, 5, 49, 21)),
#  ('Dumbo Lust', 6, datetime.datetime(2005, 8, 23, 5, 55, 22)),
#  ('Maiden Home', 24, datetime.datetime(2005, 8, 23, 6, 0, 28)),
#  ('Liberty Magnificent', 12, datetime.datetime(2005, 8, 23, 6, 3, 31)),
#  ('Temple Attraction', 12, datetime.datetime(2005, 8, 23, 6, 9, 44)),
#  ('Alaska Phantom', 26, datetime.datetime(2005, 8, 23, 6, 11, 52)),
#  ('Tycoon Gathering', 12, datetime.datetime(2005, 8, 23, 6, 18, 43)),
#  ('Telemark Heartbreakers', 25, datetime.datetime(2005, 8, 23, 6, 19, 12)),
#  ('Stampede Disturbing', 14, datetime.datetime(2005, 8, 23, 6, 19, 51)),
#  ('Spirited Casualties', 11, datetime.datetime(2005, 8, 23, 6, 21, 20)),
#  ('Siege Madre', 15, datetime.datetime(2005, 8, 23, 6, 33, 26)),
#  ('Fidelity Devil', 21, datetime.datetime(2005, 8, 23, 6, 41, 7)),
#  ('Potluck Mixed', 11, datetime.datetime(2005, 8, 23, 6, 48, 47)),
#  ('Halloween Nuts', 10, datetime.datetime(2005, 8, 23, 6, 50, 27)),
#  ('Tights Dawn', 26, datetime.datetime(2005, 8, 23, 7, 7, 22)),
#  ('Lucky Flying', 13, datetime.datetime(2005, 8, 23, 7, 10, 14)),
#  ('Dude Blindness', 16, datetime.datetime(2005, 8, 23, 7, 10, 22)),
#  ('Stallion Sundance', 7, datetime.datetime(2005, 8, 23, 7, 13, 43)),
#  ('Paris Weekend', 14, datetime.datetime(2005, 8, 23, 7, 23, 29)),
#  ('Troopers Metal', 14, datetime.datetime(2005, 8, 23, 7, 25, 29)),
#  ('Extraordinary Conquerer', 6, datetime.datetime(2005, 8, 23, 7, 28, 4)),
#  ('Crow Grease', 12, datetime.datetime(2005, 8, 23, 7, 31, 10)),
#  ('Reunion Witches', 20, datetime.datetime(2005, 8, 23, 7, 43)),
#  ('Duck Racer', 6, datetime.datetime(2005, 8, 23, 7, 50, 46)),
#  ('Bringing Hysterical', 20, datetime.datetime(2005, 8, 23, 7, 53, 38)),
#  ('Rock Instinct', 17, datetime.datetime(2005, 8, 23, 7, 54, 54)),
#  ('Mighty Luck', 12, datetime.datetime(2005, 8, 23, 8, 9, 11)),
#  ('Quest Mussolini', 20, datetime.datetime(2005, 8, 23, 8, 19, 55)),
#  ('Telegraph Voyage', 27, datetime.datetime(2005, 8, 23, 8, 27, 57)),
#  ('Louisiana Harry', 17, datetime.datetime(2005, 8, 23, 8, 29, 53)),
#  ('Westward Seabiscuit', 26, datetime.datetime(2005, 8, 23, 8, 34, 10)),
#  ('Hedwig Alter', 12, datetime.datetime(2005, 8, 23, 8, 42, 40)),
#  ('Zoolander Fiction', 17, datetime.datetime(2005, 8, 23, 8, 48, 43)),
#  ('Quills Bull', 16, datetime.datetime(2005, 8, 23, 8, 51, 21)),
#  ('Patton Interview', 23, datetime.datetime(2005, 8, 23, 8, 52, 50)),
#  ('Remember Diary', 18, datetime.datetime(2005, 8, 23, 8, 54, 26)),
#  ('Samurai Lion', 25, datetime.datetime(2005, 8, 23, 8, 59, 12)),
#  ('Roxanne Rebel', 19, datetime.datetime(2005, 8, 23, 9, 1, 10)),
#  ('Entrapment Satisfaction', 15, datetime.datetime(2005, 8, 23, 9, 2, 3)),
#  ('Homicide Peach', 22, datetime.datetime(2005, 8, 23, 9, 2, 4)),
#  ('Network Peak', 31, datetime.datetime(2005, 8, 23, 9, 7, 11)),
#  ('Citizen Shrek', 13, datetime.datetime(2005, 8, 23, 9, 9, 18)),
#  ('Witches Panic', 30, datetime.datetime(2005, 8, 23, 9, 16, 39)),
#  ('Stock Glass', 14, datetime.datetime(2005, 8, 23, 9, 23, 8)),
#  ('Necklace Outbreak', 15, datetime.datetime(2005, 8, 23, 9, 35, 34)),
#  ('Requiem Tycoon', 19, datetime.datetime(2005, 8, 23, 9, 37, 34)),
#  ('Spinal Rocky', 13, datetime.datetime(2005, 8, 23, 9, 38, 17)),
#  ('Sunset Racer', 8, datetime.datetime(2005, 8, 23, 9, 40, 4)),
#  ('Blindness Gun', 14, datetime.datetime(2005, 8, 23, 9, 41, 28)),
#  ('Hustler Party', 22, datetime.datetime(2005, 8, 23, 9, 42, 21)),
#  ('Inch Jet', 18, datetime.datetime(2005, 8, 23, 9, 53, 30)),
#  ('Coast Rainbow', 21, datetime.datetime(2005, 8, 23, 10, 0, 24)),
#  ('Newsies Story', 7, datetime.datetime(2005, 8, 23, 10, 4, 17)),
#  ('Horn Working', 24, datetime.datetime(2005, 8, 23, 10, 4, 36)),
#  ('Willow Tracy', 16, datetime.datetime(2005, 8, 23, 10, 11, 40)),
#  ('Outbreak Divine', 23, datetime.datetime(2005, 8, 23, 10, 22, 21)),
#  ('Garden Island', 20, datetime.datetime(2005, 8, 23, 10, 23, 28)),
#  ('Clueless Bucket', 25, datetime.datetime(2005, 8, 23, 10, 25, 45)),
#  ('Wizard Coldblooded', 16, datetime.datetime(2005, 8, 23, 10, 32, 52)),
#  ('Dangerous Uptown', 12, datetime.datetime(2005, 8, 23, 10, 32, 52)),
#  ('Sierra Divide', 15, datetime.datetime(2005, 8, 23, 10, 35, 45)),
#  ('Hook Chariots', 13, datetime.datetime(2005, 8, 23, 10, 35, 51)),
#  ('Birds Perdition', 18, datetime.datetime(2005, 8, 23, 10, 36)),
#  ('Birch Antitrust', 11, datetime.datetime(2005, 8, 23, 10, 56, 15)),
#  ('Spoilers Hellfighters', 10, datetime.datetime(2005, 8, 23, 10, 57, 40)),
#  ('Natural Stock', 13, datetime.datetime(2005, 8, 23, 11, 2)),
#  ('Madre Gables', 14, datetime.datetime(2005, 8, 23, 11, 15, 20)),
#  ('Cider Desire', 19, datetime.datetime(2005, 8, 23, 11, 16, 16)),
#  ('National Story', 19, datetime.datetime(2005, 8, 23, 11, 16, 29)),
#  ('Strangers Graffiti', 17, datetime.datetime(2005, 8, 23, 11, 17, 26)),
#  ('Blues Instinct', 21, datetime.datetime(2005, 8, 23, 11, 25)),
#  ('Island Exorcist', 26, datetime.datetime(2005, 8, 23, 11, 28, 49)),
#  ('Masked Bubble', 20, datetime.datetime(2005, 8, 23, 11, 30, 32)),
#  ('Darko Dorado', 11, datetime.datetime(2005, 8, 23, 11, 32, 35)),
#  ('Rouge Squad', 18, datetime.datetime(2005, 8, 23, 11, 33, 25)),
#  ('Range Moonwalker', 27, datetime.datetime(2005, 8, 23, 11, 35, 12)),
#  ('Trip Newton', 28, datetime.datetime(2005, 8, 23, 11, 37, 32)),
#  ('Vacation Boondock', 21, datetime.datetime(2005, 8, 23, 11, 40, 30)),
#  ('Carol Texas', 18, datetime.datetime(2005, 8, 23, 11, 55, 50)),
#  ('Bear Graceland', 22, datetime.datetime(2005, 8, 23, 11, 56, 22)),
#  ('Amelie Hellfighters', 10, datetime.datetime(2005, 8, 23, 12, 7, 51)),
#  ('Lebowski Soldiers', 21, datetime.datetime(2005, 8, 23, 12, 15, 51)),
#  ('Jerk Paycheck', 20, datetime.datetime(2005, 8, 23, 12, 26, 19)),
#  ('Forward Temple', 32, datetime.datetime(2005, 8, 23, 12, 29, 24)),
#  ('Twisted Pirates', 11, datetime.datetime(2005, 8, 23, 12, 33, 41)),
#  ('Circus Youth', 15, datetime.datetime(2005, 8, 23, 12, 41, 7)),
#  ('Sagebrush Clueless', 16, datetime.datetime(2005, 8, 23, 12, 43, 30)),
#  ('California Birds', 12, datetime.datetime(2005, 8, 23, 12, 46, 38)),
#  ('Crossroads Casualties', 21, datetime.datetime(2005, 8, 23, 12, 47, 5)),
#  ('Escape Metropolis', 25, datetime.datetime(2005, 8, 23, 12, 47, 16)),
#  ('Expendable Stallion', 28, datetime.datetime(2005, 8, 23, 12, 47, 37)),
#  ('Crusade Honey', 8, datetime.datetime(2005, 8, 23, 13, 1, 43)),
#  ('Others Soup', 23, datetime.datetime(2005, 8, 23, 13, 5, 10)),
#  ('Element Freddy', 10, datetime.datetime(2005, 8, 23, 13, 6, 19)),
#  ('Horror Reign', 27, datetime.datetime(2005, 8, 23, 13, 10, 16)),
#  ('Life Twisted', 10, datetime.datetime(2005, 8, 23, 13, 16, 15)),
#  ('Fiction Christmas', 19, datetime.datetime(2005, 8, 23, 13, 18, 16)),
#  ('Slacker Liaisons', 17, datetime.datetime(2005, 8, 23, 13, 18, 46)),
#  ('Virtual Spoilers', 14, datetime.datetime(2005, 8, 23, 13, 22, 56)),
#  ('Ghostbusters Elf', 9, datetime.datetime(2005, 8, 23, 13, 24, 57)),
#  ('Encounters Curtain', 19, datetime.datetime(2005, 8, 23, 13, 25, 8)),
#  ('Undefeated Dalmations', 21, datetime.datetime(2005, 8, 23, 13, 29, 8)),
#  ('Fugitive Maguire', 11, datetime.datetime(2005, 8, 23, 13, 33, 46)),
#  ('Whisperer Giant', 22, datetime.datetime(2005, 8, 23, 13, 41, 5)),
#  ('Reign Gentlemen', 20, datetime.datetime(2005, 8, 23, 13, 43, 26)),
#  ('Born Spinal', 12, datetime.datetime(2005, 8, 23, 13, 45, 44)),
#  ('Angels Life', 22, datetime.datetime(2005, 8, 23, 13, 46)),
#  ('Grit Clockwork', 32, datetime.datetime(2005, 8, 23, 13, 46, 27)),
#  ('Polish Brooklyn', 18, datetime.datetime(2005, 8, 23, 13, 48, 34)),
#  ('Adaptation Holes', 12, datetime.datetime(2005, 8, 23, 13, 54, 39)),
#  ('Earring Instinct', 19, datetime.datetime(2005, 8, 23, 13, 56, 40)),
#  ('Odds Boogie', 15, datetime.datetime(2005, 8, 23, 14, 1, 7)),
#  ('Tracy Cider', 26, datetime.datetime(2005, 8, 23, 14, 2, 13)),
#  ('Iron Moon', 11, datetime.datetime(2005, 8, 23, 14, 5, 37)),
#  ('North Tequila', 11, datetime.datetime(2005, 8, 23, 14, 6, 19)),
#  ('Wait Cider', 21, datetime.datetime(2005, 8, 23, 14, 7, 56)),
#  ('Fiddler Lost', 10, datetime.datetime(2005, 8, 23, 14, 12, 22)),
#  ('Splendor Patton', 21, datetime.datetime(2005, 8, 23, 14, 23, 3)),
#  ('Malkovich Pet', 26, datetime.datetime(2005, 8, 23, 14, 23, 23)),
#  ('Dawn Pond', 18, datetime.datetime(2005, 8, 23, 14, 23, 44)),
#  ('Alabama Devil', 12, datetime.datetime(2005, 8, 23, 14, 26, 51)),
#  ('Caddyshack Jedi', 16, datetime.datetime(2005, 8, 23, 14, 27, 7)),
#  ('Road Roxanne', 19, datetime.datetime(2005, 8, 23, 14, 29, 16)),
#  ('Modern Dorado', 15, datetime.datetime(2005, 8, 23, 14, 31, 50)),
#  ('Montezuma Command', 9, datetime.datetime(2005, 8, 23, 14, 35, 10)),
#  ('Go Purple', 20, datetime.datetime(2005, 8, 23, 14, 38, 37)),
#  ('Heaven Freedom', 18, datetime.datetime(2005, 8, 23, 14, 42, 7)),
#  ('Japanese Run', 6, datetime.datetime(2005, 8, 23, 14, 43, 15)),
#  ('Wife Turn', 31, datetime.datetime(2005, 8, 23, 14, 47, 26)),
#  ('Bilko Anonymous', 13, datetime.datetime(2005, 8, 23, 14, 55, 47)),
#  ('Celebrity Horn', 24, datetime.datetime(2005, 8, 23, 14, 59, 51)),
#  ('Side Ark', 12, datetime.datetime(2005, 8, 23, 15, 1, 54)),
#  ('Graffiti Love', 30, datetime.datetime(2005, 8, 23, 15, 3, 58)),
#  ('Shining Roses', 8, datetime.datetime(2005, 8, 23, 15, 5, 59)),
#  ('Peak Forever', 20, datetime.datetime(2005, 8, 23, 15, 8)),
#  ('Oscar Gold', 25, datetime.datetime(2005, 8, 23, 15, 9, 17)),
#  ('Apache Divine', 31, datetime.datetime(2005, 8, 23, 15, 10, 42)),
#  ('Backlash Undefeated', 19, datetime.datetime(2005, 8, 23, 15, 15, 2)),
#  ('Grease Youth', 21, datetime.datetime(2005, 8, 23, 15, 15, 19)),
#  ('Beverly Outlaw', 21, datetime.datetime(2005, 8, 23, 15, 19, 15)),
#  ('Pocus Pulp', 26, datetime.datetime(2005, 8, 23, 15, 21, 19)),
#  ('Flash Wars', 13, datetime.datetime(2005, 8, 23, 15, 21, 35)),
#  ('Confidential Interview', 29, datetime.datetime(2005, 8, 23, 15, 22, 15)),
#  ('Badman Dawn', 21, datetime.datetime(2005, 8, 23, 15, 23, 50)),
#  ('Beach Heartbreakers', 17, datetime.datetime(2005, 8, 23, 15, 29, 17)),
#  ('Wardrobe Phantom', 27, datetime.datetime(2005, 8, 23, 15, 29, 41)),
#  ('Jade Bunch', 18, datetime.datetime(2005, 8, 23, 15, 30, 48)),
#  ('Snatch Slipper', 22, datetime.datetime(2005, 8, 23, 15, 34, 46)),
#  ('Hellfighters Sierra', 20, datetime.datetime(2005, 8, 23, 15, 34, 49)),
#  ('Chainsaw Uptown', 21, datetime.datetime(2005, 8, 23, 15, 37, 31)),
#  ('Vertigo Northwest', 8, datetime.datetime(2005, 8, 23, 15, 38, 34)),
#  ('Instinct Airport', 18, datetime.datetime(2005, 8, 23, 15, 41, 12)),
#  ('Ties Hunger', 11, datetime.datetime(2005, 8, 23, 15, 41, 20)),
#  ('Karate Moon', 23, datetime.datetime(2005, 8, 23, 15, 46, 33)),
#  ('Forrest Sons', 18, datetime.datetime(2005, 8, 23, 15, 47, 2)),
#  ('Glass Dying', 14, datetime.datetime(2005, 8, 23, 15, 58, 5)),
#  ('Roman Punk', 24, datetime.datetime(2005, 8, 23, 15, 59, 12)),
#  ('Mother Oleander', 14, datetime.datetime(2005, 8, 23, 15, 59, 51)),
#  ('Wonka Sea', 18, datetime.datetime(2005, 8, 23, 16, 7, 15)),
#  ('Usual Untouchables', 13, datetime.datetime(2005, 8, 23, 16, 8, 15)),
#  ('Haunting Pianist', 22, datetime.datetime(2005, 8, 23, 16, 15, 45)),
#  ('Music Boondock', 19, datetime.datetime(2005, 8, 23, 16, 17, 9)),
#  ('Paths Control', 10, datetime.datetime(2005, 8, 23, 16, 18, 12)),
#  ('Hunting Musketeers', 15, datetime.datetime(2005, 8, 23, 16, 18, 25)),
#  ('Stagecoach Armageddon', 26, datetime.datetime(2005, 8, 23, 16, 19, 2)),
#  ('Italian African', 6, datetime.datetime(2005, 8, 23, 16, 19, 14)),
#  ('Express Lonely', 13, datetime.datetime(2005, 8, 23, 16, 22, 20)),
#  ('Cause Date', 21, datetime.datetime(2005, 8, 23, 16, 23, 8)),
#  ('Brannigan Sunrise', 12, datetime.datetime(2005, 8, 23, 16, 24, 24)),
#  ('Roots Remember', 17, datetime.datetime(2005, 8, 23, 16, 27, 24)),
#  ('Chance Resurrection', 27, datetime.datetime(2005, 8, 23, 16, 30, 55)),
#  ('Greatest North', 29, datetime.datetime(2005, 8, 23, 16, 32, 10)),
#  ('Kissing Dolls', 20, datetime.datetime(2005, 8, 23, 16, 33, 33)),
#  ('Gangs Pride', 27, datetime.datetime(2005, 8, 23, 16, 34, 31)),
#  ('Maltese Hope', 22, datetime.datetime(2005, 8, 23, 16, 43, 54)),
#  ('Champion Flatliners', 13, datetime.datetime(2005, 8, 23, 16, 44, 25)),
#  ('Hunter Alter', 5, datetime.datetime(2005, 8, 23, 16, 44, 31)),
#  ('Mystic Truman', 10, datetime.datetime(2005, 8, 23, 16, 44, 56)),
#  ('Joon Northwest', 17, datetime.datetime(2005, 8, 23, 16, 45, 28)),
#  ('Indian Love', 16, datetime.datetime(2005, 8, 23, 16, 50, 43)),
#  ('Paycheck Wait', 16, datetime.datetime(2005, 8, 23, 16, 50, 53)),
#  ('Uprising Uptown', 16, datetime.datetime(2005, 8, 23, 16, 54, 9)),
#  ('Coneheads Smoochy', 25, datetime.datetime(2005, 8, 23, 16, 57, 43)),
#  ('Show Lord', 25, datetime.datetime(2005, 8, 23, 16, 58, 12)),
#  ('Invasion Cyclone', 27, datetime.datetime(2005, 8, 23, 17, 0, 12)),
#  ('Massacre Usual', 30, datetime.datetime(2005, 8, 23, 17, 2)),
#  ('Jumping Wrath', 24, datetime.datetime(2005, 8, 23, 17, 9, 31)),
#  ('Scalawag Duck', 32, datetime.datetime(2005, 8, 23, 17, 13, 1)),
#  ('Steel Santa', 23, datetime.datetime(2005, 8, 23, 17, 16, 28)),
#  ('Racer Egg', 18, datetime.datetime(2005, 8, 23, 17, 36)),
#  ('Open African', 21, datetime.datetime(2005, 8, 23, 17, 39, 35)),
#  ('Borrowers Bedazzled', 22, datetime.datetime(2005, 8, 23, 17, 42, 42)),
#  ('Party Knock', 13, datetime.datetime(2005, 8, 23, 17, 44, 53)),
#  ('Story Side', 28, datetime.datetime(2005, 8, 23, 17, 48, 30)),
#  ('Clyde Theory', 8, datetime.datetime(2005, 8, 23, 17, 49, 26)),
#  ('Sense Greek', 7, datetime.datetime(2005, 8, 23, 17, 52, 1)),
#  ('Zorro Ark', 31, datetime.datetime(2005, 8, 23, 17, 56, 1)),
#  ('Image Princess', 14, datetime.datetime(2005, 8, 23, 17, 57, 28)),
#  ('Fish Opus', 25, datetime.datetime(2005, 8, 23, 17, 57, 35)),
#  ('Greedy Roots', 14, datetime.datetime(2005, 8, 23, 18, 1, 31)),
#  ('Goodfellas Salute', 31, datetime.datetime(2005, 8, 23, 18, 8, 19)),
#  ('Downhill Enough', 25, datetime.datetime(2005, 8, 23, 18, 8, 59)),
#  ('Roses Treasure', 28, datetime.datetime(2005, 8, 23, 18, 15, 6)),
#  ('Jericho Mulan', 17, datetime.datetime(2005, 8, 23, 18, 20, 56)),
#  ('Love Suicides', 20, datetime.datetime(2005, 8, 23, 18, 23, 11)),
#  ('Hanky October', 26, datetime.datetime(2005, 8, 23, 18, 23, 30)),
#  ('Dragon Squad', 11, datetime.datetime(2005, 8, 23, 18, 28, 9)),
#  ('Wyoming Storm', 13, datetime.datetime(2005, 8, 23, 18, 31, 40)),
#  ('Saturn Name', 13, datetime.datetime(2005, 8, 23, 18, 36, 44)),
#  ('Desert Poseidon', 19, datetime.datetime(2005, 8, 23, 18, 40, 41)),
#  ('English Bulworth', 30, datetime.datetime(2005, 8, 23, 18, 43, 11)),
#  ('Nuts Ties', 9, datetime.datetime(2005, 8, 23, 18, 43, 22)),
#  ('October Submarine', 11, datetime.datetime(2005, 8, 23, 18, 43, 31)),
#  ('Purple Movie', 13, datetime.datetime(2005, 8, 23, 18, 44, 21)),
#  ('Gaslight Crusade', 16, datetime.datetime(2005, 8, 23, 18, 45, 6)),
# ...
#  ('Hall Cassidy', 16, datetime.datetime(2005, 8, 23, 19, 51, 30)),
#  ('Wonderland Christmas', 22, datetime.datetime(2005, 8, 23, 19, 54, 24)),
#  ('Saints Bride', 8, datetime.datetime(2005, 8, 23, 19, 59, 33)),
#  ('Werewolf Lola', 14, datetime.datetime(2005, 8, 23, 20, 0, 30)),
#  ('Dinosaur Secretary', 20, datetime.datetime(2005, 8, 23, 20, 7, 10)),
#  ('Whale Bikini', 18, datetime.datetime(2005, 8, 23, 20, 8, 18)),
#  ('Snowman Rollercoaster', 23, datetime.datetime(2005, 8, 23, 20, 8, 26)),
#  ('Rocketeer Mother', 33, datetime.datetime(2005, 8, 23, 20, 10, 13)),
#  ('Northwest Polish', 20, datetime.datetime(2005, 8, 23, 20, 12, 17)),
#  ('Orange Grapes', 24, datetime.datetime(2005, 8, 23, 20, 13, 31)),
#  ('House Dynamite', 23, datetime.datetime(2005, 8, 23, 20, 16, 27)),
#  ('Mine Titans', 19, datetime.datetime(2005, 8, 23, 20, 20, 23)),
#  ('Santa Paris', 11, datetime.datetime(2005, 8, 23, 20, 20, 37)),
#  ('Poseidon Forever', 17, datetime.datetime(2005, 8, 23, 20, 22, 17)),
#  ('Strictly Scarface', 23, datetime.datetime(2005, 8, 23, 20, 23, 8)),
#  ('Airport Pollock', 18, datetime.datetime(2005, 8, 23, 20, 24, 36)),
#  ('Idols Snatchers', 30, datetime.datetime(2005, 8, 23, 20, 27, 34)),
#  ('Gilbert Pelican', 9, datetime.datetime(2005, 8, 23, 20, 28, 44)),
#  ('Bride Intrigue', 19, datetime.datetime(2005, 8, 23, 20, 29, 10)),
#  ('Dracula Crystal', 21, datetime.datetime(2005, 8, 23, 20, 29, 56)),
#  ('Nightmare Chill', 25, datetime.datetime(2005, 8, 23, 20, 40, 31)),
#  ('Edge Kissing', 15, datetime.datetime(2005, 8, 23, 20, 41, 9)),
#  ('Meet Chocolate', 12, datetime.datetime(2005, 8, 23, 20, 44, 10)),
#  ('Bedazzled Married', 13, datetime.datetime(2005, 8, 23, 20, 44, 36)),
#  ('Barbarella Streetcar', 25, datetime.datetime(2005, 8, 23, 20, 45, 53)),
#  ('Murder Antitrust', 23, datetime.datetime(2005, 8, 23, 20, 47, 12)),
#  ('Rugrats Shakespeare', 30, datetime.datetime(2005, 8, 23, 20, 47, 28)),
#  ('Jekyll Frogmen', 17, datetime.datetime(2005, 8, 23, 20, 53, 20)),
#  ('Records Zorro', 8, datetime.datetime(2005, 8, 23, 21, 0, 22)),
#  ('Banger Pinocchio', 22, datetime.datetime(2005, 8, 23, 21, 1, 9)),
#  ('Rage Games', 19, datetime.datetime(2005, 8, 23, 21, 2, 43)),
#  ('Reds Pocus', 9, datetime.datetime(2005, 8, 23, 21, 4, 51)),
#  ('Pelican Comforts', 26, datetime.datetime(2005, 8, 23, 21, 7, 59)),
#  ('Manchurian Curtain', 15, datetime.datetime(2005, 8, 23, 21, 10, 24)),
#  ('Lolita World', 10, datetime.datetime(2005, 8, 23, 21, 13, 39)),
#  ('Carrie Bunch', 23, datetime.datetime(2005, 8, 23, 21, 17, 17)),
#  ('Pity Bound', 26, datetime.datetime(2005, 8, 23, 21, 25, 3)),
#  ('Rollercoaster Bringing', 10, datetime.datetime(2005, 8, 23, 21, 26, 35)),
#  ('Chill Luck', 22, datetime.datetime(2005, 8, 23, 21, 27, 11)),
#  ('Pinocchio Simon', 20, datetime.datetime(2005, 8, 23, 21, 30, 45)),
#  ('Beauty Grease', 22, datetime.datetime(2005, 8, 23, 21, 34, 33)),
#  ('Perfect Groove', 17, datetime.datetime(2005, 8, 23, 21, 37, 59)),
#  ('Orient Closer', 17, datetime.datetime(2005, 8, 23, 21, 44, 27)),
#  ('Lawrence Love', 13, datetime.datetime(2005, 8, 23, 21, 45, 2)),
#  ('Bucket Brotherhood', 34, datetime.datetime(2005, 8, 23, 21, 49, 22)),
#  ('Maker Gables', 10, datetime.datetime(2005, 8, 23, 21, 52, 56)),
#  ('Darn Forrester', 18, datetime.datetime(2005, 8, 23, 21, 54, 2)),
#  ('Train Bunch', 4, datetime.datetime(2005, 8, 23, 21, 56, 4)),
#  ('Harper Dying', 20, datetime.datetime(2005, 8, 23, 21, 59, 26)),
#  ('Mallrats United', 25, datetime.datetime(2005, 8, 23, 21, 59, 57)),
#  ('Color Philadelphia', 24, datetime.datetime(2005, 8, 23, 22, 6, 15)),
#  ('Chicken Hellfighters', 22, datetime.datetime(2005, 8, 23, 22, 6, 34)),
#  ('Fantasia Park', 19, datetime.datetime(2005, 8, 23, 22, 12, 44)),
#  ('Bird Independence', 11, datetime.datetime(2005, 8, 23, 22, 13, 4)),
#  ('Microcosmos Paradise', 13, datetime.datetime(2005, 8, 23, 22, 14, 31)),
#  ('Caper Motions', 24, datetime.datetime(2005, 8, 23, 22, 18, 51)),
#  ('Scorpion Apollo', 23, datetime.datetime(2005, 8, 23, 22, 19, 33)),
#  ('Tomorrow Hustler', 25, datetime.datetime(2005, 8, 23, 22, 20, 26)),
#  ('Charade Duffel', 15, datetime.datetime(2005, 8, 23, 22, 20, 40)),
#  ('Sting Personal', 21, datetime.datetime(2005, 8, 23, 22, 21, 3)),
#  ('Everyone Craft', 13, datetime.datetime(2005, 8, 23, 22, 24, 39)),
#  ('Comancheros Enemy', 6, datetime.datetime(2005, 8, 23, 22, 25, 26)),
#  ('Voyage Legally', 28, datetime.datetime(2005, 8, 23, 22, 26, 47)),
#  ('Illusion Amelie', 15, datetime.datetime(2005, 8, 23, 22, 42, 48)),
#  ('Mob Duffel', 12, datetime.datetime(2005, 8, 23, 22, 50, 12)),
#  ('Juggler Hardly', 32, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Camelot Vacation', 27, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Ace Goldfinger', 7, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Shock Cabin', 30, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('South Wait', 22, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Gunfight Moon', 24, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Club Graffiti', 19, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Bull Shawshank', 16, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Amistad Midsummer', 21, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Insider Arizona', 20, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Intrigue Worst', 20, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Seattle Expecations', 24, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Berets Agent', 21, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Sleepy Japanese', 21, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Blanket Beverly', 12, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Ali Forever', 9, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Pulp Beverly', 30, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Dragonfly Strangers', 18, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Lady Stage', 17, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Name Detective', 23, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Gorgeous Bingo', 19, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Outfield Massacre', 20, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Driver Annie', 18, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Smoking Barbarella', 18, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Gleaming Jawbreaker', 29, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Zhivago Core', 9, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Chitty Lock', 8, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Trojan Tomorrow', 19, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Ghost Groundhog', 21, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Bubble Grosse', 6, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Affair Prejudice', 23, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Lovely Jingle', 14, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Deep Crusade', 14, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Suspects Quills', 30, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Mulan Moon', 13, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Deer Virginian', 29, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Mosquito Armageddon', 15, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Boulevard Mob', 18, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Cat Coneheads', 30, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Falcon Volume', 22, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Blade Polish', 22, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Varsity Trip', 16, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Harry Idaho', 30, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Basic Easy', 21, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Drifter Commandments', 24, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Swarm Gold', 27, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Torque Bound', 27, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Pirates Roxanne', 21, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Outlaw Hanky', 14, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Mummy Creatures', 16, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Moonwalker Fool', 13, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Trading Pinocchio', 25, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Forrester Comancheros', 27, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Lust Lock', 15, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Trouble Date', 23, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Divine Resurrection', 15, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Flying Hook', 20, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Amadeus Holy', 21, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Titans Jerk', 29, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Fight Jawbreaker', 22, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Sweden Shining', 18, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Candidate Perdition', 18, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Happiness United', 6, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Chasing Fight', 20, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Cincinatti Whisperer', 13, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Theory Mermaid', 11, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Conversation Downhill', 17, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Volcano Texas', 22, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Frost Head', 30, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Alone Trip', 18, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Grapes Fury', 22, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Frisco Forrest', 9, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Frida Slipper', 11, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Peach Innocent', 14, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Doors President', 19, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Shrek License', 15, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Tuxedo Mile', 13, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Pure Runner', 16, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Seabiscuit Punk', 26, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Lord Arizona', 11, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Princess Giant', 27, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Intentions Empire', 17, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Day Unfaithful', 14, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Window Side', 12, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Chamber Italian', 13, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Gables Metropolis', 19, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Movie Shakespeare', 27, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Silverado Goldfinger', 12, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Philadelphia Wife', 23, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Hyde Doctor', 26, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Holes Brannigan', 15, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Curtain Videotape', 27, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Canyon Stock', 19, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Groundhog Uncut', 18, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Monster Spartacus', 15, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Connection Microcosmos', 7, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Streak Ridgemont', 16, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Shawshank Bubble', 19, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('State Wasteland', 13, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Lawless Vision', 17, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Star Operation', 21, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Motions Details', 16, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Sweethearts Suspects', 29, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Operation Operation', 27, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Sundance Invasion', 19, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Crooked Frogmen', 23, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Encino Elf', 19, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Boogie Amelie', 29, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('None Spiking', 27, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Details Packer', 19, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Pianist Outfield', 21, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Queen Luke', 22, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Mulholland Beast', 7, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Cyclone Family', 15, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('African Egg', 12, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Family Sweet', 29, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Insects Stone', 18, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Vanished Garden', 7, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Bound Cheaper', 24, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Midnight Westward', 17, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Bang Kwai', 7, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Sleeping Suspects', 24, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Igby Maker', 19, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('World Leathernecks', 8, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Dwarfs Alter', 9, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Hunchback Impossible', 20, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Virginian Pluto', 29, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Wanda Chamber', 16, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Earth Vision', 23, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Haunted Antitrust', 6, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Devil Desire', 15, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Loathing Legally', 27, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Suit Walls', 21, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Pollock Deliverance', 18, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Sleepless Monsoon', 20, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Eagles Panky', 22, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Enough Raging', 18, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Song Hedwig', 11, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Baked Cleopatra', 16, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('American Circus', 22, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('River Outlaw', 20, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Effect Gladiator', 25, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Detective Vision', 27, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Armageddon Lost', 21, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Grail Frankenstein', 10, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Mockingbird Hollywood', 24, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Hunger Roof', 13, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Minority Kiss', 12, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Kick Savannah', 20, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Jason Trap', 24, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Half Outfield', 26, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Ridgemont Submarine', 32, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Pride Alamo', 16, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Cleopatra Devil', 18, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Dances None', 14, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Scarface Bang', 18, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Titanic Boondock', 23, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Center Dinosaur', 24, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Smoochy Control', 12, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Sons Interview', 15, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Wedding Apollo', 24, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Summer Scarface', 16, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Disciple Mother', 19, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Wild Apollo', 6, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Vanishing Rocky', 18, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Women Dorado', 23, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Opposite Necklace', 13, datetime.datetime(2006, 2, 14, 15, 16, 3)),
#  ('Creatures Shakespeare', 16, datetime.datetime(2006, 2, 14, 15, 16, 3))]

# %% [markdown]
# # Save your Notebook, then `File > Close and Halt`

# %% [markdown]
# ---
