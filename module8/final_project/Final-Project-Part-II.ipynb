# %% [markdown]
# ## Final Project Part - II
#
# ### In this part, we will be creating tables and loading data into the tables using the ERD in Part - I.
#
# In this project, we will explore Chicago Crime Dataset and implement a relational database for storing the data. During the final week, you will complete Tasks 3-5:
#
# 1. Identify the features (attributes) in Chicago Crime dataset and design an entity-relationship model
# 2. Refine the model and convert each relation to BCNF (if required)
# 3. Using DDL implement the relations in a Postgres server
# 4. Load the given data to the relations
# 5. Execute some interesting queries on the relations

# %%
import pandas as pd

# %%
chi = pd.read_csv('Chicago-Crime-Sample-2012.csv')
list(chi.columns)
# Out:
# ['Unnamed: 0',
#  'ID',
#  'Case Number',
#  'Date',
#  'Block',
#  'IUCR',
#  'Primary Type',
#  'Description',
#  'Location Description',
#  'Arrest',
#  'Domestic',
#  'Beat',
#  'District',
#  'Ward',
#  'Community Area',
#  'FBI Code',
#  'X Coordinate',
#  'Y Coordinate',
#  'Year',
#  'Updated On',
#  'Latitude',
#  'Longitude',
#  'Location']

# %%
chi = chi.rename(columns={'Location Description' : 'location_description', 'Primary Type' : 'primary_type', 'Case Number' : 'case_number', 'X Coordinate': 'x_coordinate', 'Y Coordinate' : 'y_coordinate', 'Updated On':'updated_on', 'FBI Code':'fbi_code','Community Area' : 'community_area'})

# %%
chi.columns = map(str.lower, chi.columns)

# %%
list(chi.columns)
# Out:
# ['unnamed: 0',
#  'id',
#  'case_number',
#  'date',
#  'block',
#  'iucr',
#  'primary_type',
#  'description',
#  'location_description',
#  'arrest',
#  'domestic',
#  'beat',
#  'district',
#  'ward',
#  'community_area',
#  'fbi_code',
#  'x_coordinate',
#  'y_coordinate',
#  'year',
#  'updated_on',
#  'latitude',
#  'longitude',
#  'location']

# %%
chi = chi.rename(columns={'unnamed: 0' : 'unnamed_id'})
chi.head()
# Out:
#    unnamed_id        id case_number           date                  block  \
# 0       47398  10433096    HZ170962  1/1/2012 0:00  026XX N MC VICKER AVE
# 1       47420  10433124    HZ170983  1/1/2012 0:00  026XX N MC VICKER AVE
# 2      802910  10532867    HZ276514  1/1/2012 0:00     036XX S RHODES AVE
# 3      803605  10536876    HZ280873  1/1/2012 0:00    062XX S ROCKWELL ST
# 4      831733   9581929    HX232501  1/1/2012 0:00        006XX W 66TH ST
#
#    iucr        primary_type                          description  \
# 0  1562         SEX OFFENSE            AGG CRIMINAL SEXUAL ABUSE
# 1  1544         SEX OFFENSE       SEXUAL EXPLOITATION OF A CHILD
# 2  1563         SEX OFFENSE                CRIMINAL SEXUAL ABUSE
# 3  1153  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 4  1563         SEX OFFENSE                CRIMINAL SEXUAL ABUSE
#
#   location_description  arrest  ...  ward  community_area  fbi_code  \
# 0            RESIDENCE    True  ...  29.0            19.0        17
# 1            RESIDENCE    True  ...  29.0            19.0        17
# 2            APARTMENT   False  ...   4.0            35.0        17
# 3            RESIDENCE   False  ...  15.0            66.0        11
# 4            RESIDENCE   False  ...   6.0            68.0        17
#
#    x_coordinate  y_coordinate  year       updated_on  latitude  longitude  \
# 0           NaN           NaN  2012  5/11/2016 15:48       NaN        NaN
# 1           NaN           NaN  2012  5/11/2016 15:48       NaN        NaN
# 2           NaN           NaN  2012  5/26/2016 15:51       NaN        NaN
# 3           NaN           NaN  2012  5/27/2016 15:48       NaN        NaN
# 4           NaN           NaN  2012  8/17/2015 15:03       NaN        NaN
#
#   location
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#
# [5 rows x 23 columns]

# %%
chi['lb_id']  = pd.factorize(chi['block'])[0]
chi['ld_id'] = pd.factorize(chi['location_description'])[0]

# %%
chi['ld_id'] = pd.factorize(chi['location_description'])[0]

# %%
chi = chi.drop(['la_id'], axis = 1 )

# %%
def make_identifier(df):
    str_id = df.apply(lambda x: '_'.join(map(str, x)), axis=1)
    return pd.factorize(str_id)[0]

# %%
chi['la_id'] = make_identifier(chi[['beat','district','ward','community_area']])

# %%
chi['lc_id'] = make_identifier(chi[['x_coordinate','y_coordinate','latitude','longitude','location']])

# %%
chi['cl_id'] = make_identifier(chi[['la_id','lb_id','lc_id','ld_id']])

# %%
location_block = chi[['lb_id','block']]
location_block = location_block.drop_duplicates()

# %%
location_description = chi[['ld_id', 'location_description']]
location_description = location_description.drop_duplicates()
location_description
location_description.location_description.unique()
# Out:
# array(['RESIDENCE', 'APARTMENT', 'OTHER', 'CURRENCY EXCHANGE',
#        'RESIDENCE PORCH/HALLWAY', 'SIDEWALK', 'BAR OR TAVERN',
#        'VEHICLE NON-COMMERCIAL', 'STREET', 'HOTEL/MOTEL',
#        'COMMERCIAL / BUSINESS OFFICE', 'RESIDENCE-GARAGE',
#        'TAVERN/LIQUOR STORE', 'BANK', 'RESIDENTIAL YARD (FRONT/BACK)',
#        'ATM (AUTOMATIC TELLER MACHINE)', 'PARKING LOT/GARAGE(NON.RESID.)',
#        'GAS STATION', 'SMALL RETAIL STORE', 'DEPARTMENT STORE',
#        'PARK PROPERTY', 'POLICE FACILITY/VEH PARKING LOT',
#        'MEDICAL/DENTAL OFFICE', 'ABANDONED BUILDING', 'DAY CARE CENTER',
#        'CTA TRAIN', 'VEHICLE-COMMERCIAL', 'CTA PLATFORM', 'ALLEY',
#        'CHA APARTMENT', 'GROCERY FOOD STORE', 'RESTAURANT', 'CEMETARY',
#        'CONVENIENCE STORE', 'CHURCH/SYNAGOGUE/PLACE OF WORSHIP',
#        'POOL ROOM', 'SCHOOL, PRIVATE, GROUNDS', 'CTA BUS',
#        'DRIVEWAY - RESIDENTIAL', 'CTA GARAGE / OTHER PROPERTY', 'TAXICAB',
#        'CAR WASH', 'SPORTS ARENA/STADIUM', 'VACANT LOT/LAND',
#        'ANIMAL HOSPITAL', 'OTHER RAILROAD PROP / TRAIN DEPOT',
#        'FACTORY/MANUFACTURING BUILDING', 'DRUG STORE',
#        'CHA HALLWAY/STAIRWELL/ELEVATOR', 'SCHOOL, PUBLIC, BUILDING',
#        'SCHOOL, PRIVATE, BUILDING', 'JAIL / LOCK-UP FACILITY',
#        'CONSTRUCTION SITE', 'SCHOOL, PUBLIC, GROUNDS',
#        'NURSING HOME/RETIREMENT HOME', 'CTA BUS STOP',
#        'HOSPITAL BUILDING/GROUNDS',
#        'AIRPORT TERMINAL UPPER LEVEL - SECURE AREA',
#        'CHA PARKING LOT/GROUNDS', 'GOVERNMENT BUILDING/PROPERTY',
#        'AIRPORT TRANSPORTATION SYSTEM (ATS)',
#        'AIRPORT EXTERIOR - NON-SECURE AREA',
#        'AIRPORT TERMINAL UPPER LEVEL - NON-SECURE AREA', 'BARBERSHOP',
#        'BRIDGE', 'ATHLETIC CLUB',
#        'AIRPORT TERMINAL LOWER LEVEL - SECURE AREA',
#        'AIRPORT BUILDING NON-TERMINAL - NON-SECURE AREA', 'WAREHOUSE',
#        'AIRPORT/AIRCRAFT', 'CLEANING STORE', nan, 'HIGHWAY/EXPRESSWAY',
#        'APPLIANCE STORE', 'COLLEGE/UNIVERSITY GROUNDS',
#        'OTHER COMMERCIAL TRANSPORTATION',
#        'COLLEGE/UNIVERSITY RESIDENCE HALL',
#        'AIRPORT TERMINAL LOWER LEVEL - NON-SECURE AREA',
#        'AIRPORT PARKING LOT', 'LIBRARY', 'COIN OPERATED MACHINE',
#        'LAKEFRONT/WATERFRONT/RIVERBANK', 'BOWLING ALLEY',
#        'AIRPORT EXTERIOR - SECURE AREA', 'AIRPORT VENDING ESTABLISHMENT',
#        'MOVIE HOUSE/THEATER', 'SAVINGS AND LOAN', 'FIRE STATION',
#        'AIRPORT BUILDING NON-TERMINAL - SECURE AREA', 'DELIVERY TRUCK',
#        'FEDERAL BUILDING', 'AIRCRAFT', 'PAWN SHOP', 'FOREST PRESERVE',
#        'AIRPORT TERMINAL MEZZANINE - NON-SECURE AREA', 'CREDIT UNION',
#        'BOAT/WATERCRAFT', 'NEWSSTAND'], dtype=object)

# %%
location_coordinate = chi[['lc_id','x_coordinate','y_coordinate','latitude','longitude','location']]
location_coordinate = location_coordinate.drop_duplicates()
location_coordinate.dtypes
location_coordinate.head()
# Out:
#     lc_id  x_coordinate  y_coordinate   latitude  longitude  \
# 0       0           NaN           NaN        NaN        NaN
# 16      1     1150568.0     1905409.0  41.896342 -87.722441
# 17      2     1145387.0     1901385.0  41.885399 -87.741572
# 18      3     1170335.0     1922325.0  41.942351 -87.649345
# 19      4     1158836.0     1861215.0  41.774903 -87.693283
#
#                          location
# 0                             NaN
# 16  (41.896341861, -87.722440573)
# 17    (41.8853992, -87.741571528)
# 18  (41.942351064, -87.649344776)
# 19  (41.774902869, -87.693283132)

# %%
crime_record = chi[['id','iucr','fbi_code','cl_id','unnamed_id','case_number','arrest','domestic','date','year','updated_on']]
crime_record = crime_record.drop_duplicates()
crime_record.head()
# Out:
#          id  iucr fbi_code  cl_id  unnamed_id case_number  arrest  domestic  \
# 0  10433096  1562       17      0       47398    HZ170962    True     False
# 1  10433124  1544       17      0       47420    HZ170983    True     False
# 2  10532867  1563       17      1      802910    HZ276514   False     False
# 3  10536876  1153       11      2      803605    HZ280873   False     False
# 4   9581929  1563       17      3      831733    HX232501   False      True
#
#             date  year       updated_on
# 0  1/1/2012 0:00  2012  5/11/2016 15:48
# 1  1/1/2012 0:00  2012  5/11/2016 15:48
# 2  1/1/2012 0:00  2012  5/26/2016 15:51
# 3  1/1/2012 0:00  2012  5/27/2016 15:48
# 4  1/1/2012 0:00  2012  8/17/2015 15:03

# %%
crime_code = chi[['iucr','fbi_code','description','primary_type']]
crime_code =crime_code.drop_duplicates()
crime_code.fbi_code.unique()
crime_code[crime_code['description'].str.contains('CANNABIS')]
# Out:
#         iucr fbi_code                     description primary_type
# 272     1812       18  POSS: CANNABIS MORE THAN 30GMS    NARCOTICS
# 320     1811       18    POSS: CANNABIS 30GMS OR LESS    NARCOTICS
# 2431    1821       18  MANU/DEL:CANNABIS 10GM OR LESS    NARCOTICS
# 2861    1822       18   MANU/DEL:CANNABIS OVER 10 GMS    NARCOTICS
# 16923   1850       18                  CANNABIS PLANT    NARCOTICS
# 32323   2094       18     ATTEMPT POSSESSION CANNABIS    NARCOTICS
# 205967  1840       18  DELIVER CANNABIS TO PERSON <18    NARCOTICS

# %%
crime_code17investigation = crime_code[crime_code['fbi_code'] == '17']
crime_code17investigation
# Out:
#         iucr fbi_code                     description  \
# 0       1562       17       AGG CRIMINAL SEXUAL ABUSE
# 1       1544       17  SEXUAL EXPLOITATION OF A CHILD
# 2       1563       17           CRIMINAL SEXUAL ABUSE
# 160     1565       17     INDECENT SOLICITATION/CHILD
# 249     1582       17               CHILD PORNOGRAPHY
# 955     1564       17    CRIMINAL TRANSMISSION OF HIV
# 1380    2830       17         OBSCENE TELEPHONE CALLS
# 3765    1576       17                          BIGAMY
# 4077    1570       17                PUBLIC INDECENCY
# 5501    1541       17  SALE/DIST OBSCENE MAT TO MINOR
# 6273    1536       17                LICENSED PREMISE
# 10127   1540       17                  OBSCENE MATTER
# 22559   1585       17                           OTHER
# 29581   5004       17           ATT CRIM SEXUAL ABUSE
# 30266   1590       17   ATT AGG CRIMINAL SEXUAL ABUSE
# 54185   1535       17                       OBSCENITY
# 111789  1566       17     INDECENT SOLICITATION/ADULT
# 123082  1580       17          SEX RELATION IN FAMILY
#
#                       primary_type
# 0                      SEX OFFENSE
# 1                      SEX OFFENSE
# 2                      SEX OFFENSE
# 160                    SEX OFFENSE
# 249     OFFENSE INVOLVING CHILDREN
# 955                    SEX OFFENSE
# 1380                 OTHER OFFENSE
# 3765                   SEX OFFENSE
# 4077                   SEX OFFENSE
# 5501                     OBSCENITY
# 6273              PUBLIC INDECENCY
# 10127                    OBSCENITY
# 22559                  SEX OFFENSE
# 29581                  SEX OFFENSE
# 30266                  SEX OFFENSE
# 54185                    OBSCENITY
# 111789                 SEX OFFENSE
# 123082                 SEX OFFENSE

# %%
location_area = chi[['la_id','beat','district','ward','community_area']]
location_area =location_area.drop_duplicates()
location_area.head()
# Out:
#     la_id  beat  district  ward  community_area
# 23     22   713         7  16.0            67.0

# %%
crime_location = chi[['cl_id','la_id','lb_id','lc_id','ld_id']]
crime_location = crime_location.drop_duplicates()

# %% [markdown]
# ## 2.1 Using DDL, create each of the relations in the postgres server.
#
# * Use the ERD from Module 7 to create tables (DDL).
# * Add additional cells if required.
# * Make sure you have good documentation for each table to explain what attributes are and anything that are worth noting.

# %%
import getpass
# This collects a masked password from the user
mypasswd = getpass.getpass()
# Out:
# ········

# %%
del(mypasswd)

# %%
import psycopg2
from psycopg2.extensions import adapt, register_adapter, AsIs
connection = psycopg2.connect(database = 'dsa_student', 
                              user = 'may96c', 
                              host = 'pgsql.dsa.lan',
                              password = mypasswd)

cursor = connection.cursor()

# %%
import numpy as np

# %%
sqlCreateTable = """ CREATE TABLE may96c.location_block (
    lb_id INT PRIMARY KEY,
    block VARCHAR);"""
cursor.execute(sqlCreateTable)

connection.commit()

# %%
sqlCreateTable = """ CREATE TABLE may96c.location_description ( 
    ld_id INT PRIMARY KEY,
    location_description VARCHAR);"""
cursor.execute(sqlCreateTable)

connection.commit()

# %%
sqlCreateTable = """ CREATE TABLE may96c.location_coordinate ( 
    lc_id INT PRIMARY KEY,
    x_coordinate NUMERIC,
    y_coordinate NUMERIC,
    latitude NUMERIC,
    longitude NUMERIC,
    location VARCHAR);"""
cursor.execute(sqlCreateTable)

connection.commit()

# %%
sqlCreateTable = """ CREATE TABLE IF NOT EXISTS may96c.crime_code ( 
    iucr VARCHAR ,
    fbi_code VARCHAR,
    description VARCHAR,
    primary_type VARCHAR,
    PRIMARY KEY(fbi_code,iucr));"""
cursor.execute(sqlCreateTable)

connection.commit()

# %%
sqlCreateTable = """ CREATE TABLE may96c.location_area ( 
    la_id INT PRIMARY KEY, 
    beat INT,
    district INT,
    ward INT,
    community_area INT );"""
    
cursor.execute(sqlCreateTable)

connection.commit()

# %%
sqlCreateTable = """ CREATE TABLE may96c.crime_location (
    cl_id INT PRIMARY KEY,
    la_id INT,
    lb_id INT,
    lc_id INT,
    ld_id INT,
    CONSTRAINT fk_cl_a 
        FOREIGN KEY (la_id)
        REFERENCES may96c.location_area(la_id),
    CONSTRAINT fk_cl_b
        FOREIGN KEY(lb_id)
        REFERENCES may96c.location_block(lb_id),
    CONSTRAINT fk_cl_c
        FOREIGN KEY (lc_id)
        REFERENCES may96c.location_coordinate(lc_id),
    CONSTRAINT fk_cl_d
        FOREIGN KEY (ld_id)
        REFERENCES may96c.location_description(ld_id));"""
cursor.execute(sqlCreateTable)

connection.commit()

# %%
sqlCreateTable = """ CREATE TABLE may96c.crime_record (
    id INT PRIMARY KEY,
    iucr VARCHAR,
    fbi_code VARCHAR,
    cl_id INT, 
    unnamed_id INT,
    case_number VARCHAR,
    arrest VARCHAR,
    domestic VARCHAR,
    date TIMESTAMP,
    year INT,
    updated_on TIMESTAMP,
    CONSTRAINT cr_fk_a
        FOREIGN KEY(iucr,fbi_code)
        REFERENCES may96c.crime_code(iucr,fbi_code),
    CONSTRAINT cr_fk_c
        FOREIGN KEY (cl_id)
        REFERENCES may96c.crime_location(cl_id));"""
cursor.execute(sqlCreateTable)

connection.commit()

# %% [markdown]
# ## 2.2 Show the table's definition for each table using psql or querying the information_schema.colums catalog
#
# * Add additional cells if required

# %%
SSO = 'may96c'
hostname ='pgsql.dsa.lan'
database ='dsa_student'

# %% [markdown]
# dsa_student=> \d may96c.location_block ;
#                 Table "may96c.location_block"
#  Column |       Type        | Collation | Nullable | Default
# --------+-------------------+-----------+----------+---------
#  lb_id  | integer           |           | not null |
#  block  | character varying |           |          |
# Indexes:
#     "location_block_pkey" PRIMARY KEY, btree (lb_id)
# Referenced by:
#     TABLE "crime_location" CONSTRAINT "fk_cl_b" FOREIGN KEY (lb_id) REFERENCES location_block(lb_id)

# %% [markdown]
# dsa_student=> \d may96c.location_description ;
#                     Table "may96c.location_description"
#         Column        |       Type        | Collation | Nullable | Default
# ----------------------+-------------------+-----------+----------+---------
#  ld_id                | integer           |           | not null |
#  location_description | character varying |           |          |
# Indexes:
#     "location_description_pkey" PRIMARY KEY, btree (ld_id)
# Referenced by:
#     TABLE "crime_location" CONSTRAINT "fk_cl_d" FOREIGN KEY (ld_id) REFERENCES location_description(ld_id)

# %% [markdown]
# dsa_student=> \d may96c.location_coordinate ;
#                 Table "may96c.location_coordinate"
#     Column    |       Type        | Collation | Nullable | Default
# --------------+-------------------+-----------+----------+---------
#  lc_id        | integer           |           | not null |
#  x_coordinate | numeric           |           |          |
#  y_coordinate | numeric           |           |          |
#  latitude     | numeric           |           |          |
#  longitude    | numeric           |           |          |
#  location     | character varying |           |          |
# Indexes:
#     "location_coordinate_pkey" PRIMARY KEY, btree (lc_id)
# Referenced by:
#     TABLE "crime_location" CONSTRAINT "fk_cl_c" FOREIGN KEY (lc_id) REFERENCES location_coordinate(lc_id)

# %% [markdown]
# dsa_student=> \d may96c.crime_code
#                      Table "may96c.crime_code"
#     Column    |       Type        | Collation | Nullable | Default
# --------------+-------------------+-----------+----------+---------
#  iucr         | character varying |           | not null |
#  fbi_code     | character varying |           | not null |
#  description  | character varying |           |          |
#  primary_type | character varying |           |          |
# Indexes:
#     "crime_code_pkey" PRIMARY KEY, btree (fbi_code, iucr)

# %% [markdown]
# dsa_student=> \d may96c.location_area ;
#                Table "may96c.location_area"
#      Column     |  Type   | Collation | Nullable | Default
# ----------------+---------+-----------+----------+---------
#  la_id          | integer |           | not null |
#  beat           | integer |           |          |
#  district       | integer |           |          |
#  ward           | integer |           |          |
#  community_area | integer |           |          |
# Indexes:
#     "location_area_pkey" PRIMARY KEY, btree (la_id)
# Referenced by:
#     TABLE "crime_location" CONSTRAINT "fk_cl_a" FOREIGN KEY (la_id) REFERENCES location_area(la_id)

# %% [markdown]
# dsa_student=> \d may96c.crime_location;
#            Table "may96c.crime_location"
#  Column |  Type   | Collation | Nullable | Default
# --------+---------+-----------+----------+---------
#  cl_id  | integer |           | not null |
#  la_id  | integer |           |          |
#  lb_id  | integer |           |          |
#  lc_id  | integer |           |          |
#  ld_id  | integer |           |          |
# Indexes:
#     "crime_location_pkey" PRIMARY KEY, btree (cl_id)
# Foreign-key constraints:
#     "fk_cl_a" FOREIGN KEY (la_id) REFERENCES location_area(la_id)
#     "fk_cl_b" FOREIGN KEY (lb_id) REFERENCES location_block(lb_id)
#     "fk_cl_c" FOREIGN KEY (lc_id) REFERENCES location_coordinate(lc_id)
#     "fk_cl_d" FOREIGN KEY (ld_id) REFERENCES location_description(ld_id)
# Referenced by:
#     TABLE "crime_record" CONSTRAINT "cr_fk_c" FOREIGN KEY (cl_id) REFERENCES crime_location(cl_id)

# %% [markdown]
# dsa_student=> \d may96c.crime_record
#                         Table "may96c.crime_record"
#    Column    |            Type             | Collation | Nullable | Default
# -------------+-----------------------------+-----------+----------+---------
#  id          | integer                     |           | not null |
#  iucr        | character varying           |           |          |
#  fbi_code    | character varying           |           |          |
#  cl_id       | integer                     |           |          |
#  unnamed_id  | integer                     |           |          |
#  case_number | character varying           |           |          |
#  arrest      | character varying           |           |          |
#  domestic    | character varying           |           |          |
#  date        | timestamp without time zone |           |          |
#  year        | integer                     |           |          |
#  updated_on  | timestamp without time zone |           |          |
# Indexes:
#     "crime_record_pkey" PRIMARY KEY, btree (id)
# Foreign-key constraints:
#     "cr_fk_a" FOREIGN KEY (iucr, fbi_code) REFERENCES crime_code(iucr, fbi_code)
#     "cr_fk_c" FOREIGN KEY (cl_id) REFERENCES crime_location(cl_id)

# %% [markdown]
# ## 2.3 Load the data from the given csv file in Part 1 to the relations
#
# * Assuming there will be multiple relations, you need to extract a subsets of data from the original csv data. As Python may not be your first choice, you can use any languages to create subsets of data. Then store these data into the Module 8 exercises folder.
# * After curating the data use the load loading skillset gained from Module 6
#   * Copy and paste your command/query in the following cell or comment on what you have done to populate the data.
#
# * Add additional cells if required

# %%
print(list(location_block))
s = ''
for i in list(location_block):
    s += '%s,'
print(s)
# Out:
# ['lb_id', 'block']
# %s,%s,

# %%
register_adapter(np.int64,AsIs)
register_adapter(np.float64,AsIs)
location_block = location_block.where(pd.notnull(location_block), None)
INSERT_SQL = 'INSERT INTO may96c.location_block '
INSERT_SQL += ' (lb_id,block) VALUES '
INSERT_SQL += '(%s,%s)'

with connection, connection.cursor() as cursor:
    
    for row in location_block.itertuples(index=False, name=None):  
        
        cursor.execute(INSERT_SQL,row)

# %%
print(list(location_description))
s = ''
for i in list(location_description):
    s += '%s,'
print(s)
# Out:
# ['ld_id', 'location_description']
# %s,%s,

# %%
register_adapter(np.int64,AsIs)
register_adapter(np.float64,AsIs)
location_description = location_description.where(pd.notnull(location_description), None)
INSERT_SQL = 'INSERT INTO may96c.location_description '
INSERT_SQL += ' (ld_id,location_description) VALUES '
INSERT_SQL += '(%s,%s)'

with connection, connection.cursor() as cursor:
    
    for row in location_description.itertuples(index=False, name=None):  
        
        cursor.execute(INSERT_SQL,row)

# %%
print(list(location_coordinate))
s = ''
for i in list(location_coordinate):
    s += '%s,'
print(s)
# Out:
# ['lc_id', 'x_coordinate', 'y_coordinate', 'latitude', 'longitude', 'location']
# %s,%s,%s,%s,%s,%s,

# %%
register_adapter(np.int64,AsIs)
register_adapter(np.float64,AsIs)
location_coordinate= location_coordinate.where(pd.notnull(location_coordinate), None)
INSERT_SQL = 'INSERT INTO may96c.location_coordinate '
INSERT_SQL += ' (lc_id,x_coordinate,y_coordinate,latitude,longitude,location) VALUES '
INSERT_SQL += '(%s,%s,%s,%s,%s,%s)'

with connection, connection.cursor() as cursor:
    
    for row in location_coordinate.itertuples(index=False, name=None):  
        
        cursor.execute(INSERT_SQL,row)

# %%
print(list(crime_code))
s = ''
for i in list(crime_code):
    s += '%s,'
print(s)
# Out:
# ['iucr', 'fbi_code', 'description', 'primary_type']
# %s,%s,%s,%s,

# %%
register_adapter(np.int64,AsIs)
register_adapter(np.float64,AsIs)
crime_code= crime_code.where(pd.notnull(crime_code), None)
INSERT_SQL = 'INSERT INTO may96c.crime_code '
INSERT_SQL += ' (iucr,fbi_code, description, primary_type) VALUES '
INSERT_SQL += '(%s,%s,%s,%s)'

with connection, connection.cursor() as cursor:
    
    for row in crime_code.itertuples(index=False, name=None):  
        
        cursor.execute(INSERT_SQL,row)

# %%
print(list(location_area))
s = ''
for i in list(location_area):
    s += '%s,'
print(s)
# Out:
# ['la_id', 'beat', 'district', 'ward', 'community_area']
# %s,%s,%s,%s,%s,

# %%
register_adapter(np.int64,AsIs)
register_adapter(np.float64,AsIs)
location_area= location_area.where(pd.notnull(location_area), None)
INSERT_SQL = 'INSERT INTO may96c.location_area '
INSERT_SQL += ' (la_id,beat,district,ward,community_area) VALUES '
INSERT_SQL += '(%s,%s,%s,%s,%s)'

with connection, connection.cursor() as cursor:
    
    for row in location_area.itertuples(index=False, name=None):  
        
        cursor.execute(INSERT_SQL,row)

# %%
print(list(crime_location))
s = ''
for i in list(crime_location):
    s += '%s,'
print(s)
# Out:
# ['cl_id', 'la_id', 'lb_id', 'lc_id', 'ld_id']
# %s,%s,%s,%s,%s,

# %%
register_adapter(np.int64,AsIs)
register_adapter(np.float64,AsIs)
crime_location= crime_location.where(pd.notnull(crime_location), None)
INSERT_SQL = 'INSERT INTO may96c.crime_location '
INSERT_SQL += ' (cl_id,la_id,lb_id,lc_id,ld_id) VALUES '
INSERT_SQL += '(%s,%s,%s,%s,%s)'

with connection, connection.cursor() as cursor:
    
    for row in crime_location.itertuples(index=False, name=None):  
        
        cursor.execute(INSERT_SQL,row)

# %%
print(list(crime_record))
s = ''
for i in list(crime_record):
    s += '%s,'
print(s)
# Out:
# ['id', 'iucr', 'fbi_code', 'cl_id', 'unnamed_id', 'case_number', 'arrest', 'domestic', 'date', 'year', 'updated_on']
# %s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,

# %%
register_adapter(np.int64,AsIs)
register_adapter(np.float64,AsIs)
crime_record= crime_record.where(pd.notnull(crime_record), None)
INSERT_SQL = 'INSERT INTO may96c.crime_record'
INSERT_SQL += ' (id,iucr,fbi_code,cl_id,unnamed_id,case_number,arrest,domestic,date,year,updated_on) VALUES '
INSERT_SQL += '(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'

with connection, connection.cursor() as cursor:
    
    for row in crime_record.itertuples(index=False, name=None):  
        
        cursor.execute(INSERT_SQL,row)

# %% [markdown]
# ## 2.4 For each table, show the table name and number of rows using a sql query
#
# * Add additional cells if required

# %%
SSO = 'may96c'
hostname = 'pgsql.dsa.lan'
database = 'dsa_student'

# %%
# %load_ext sql
connection_str = "postgres://{username}:{password}@{hostname}/{database}".format(
    username=SSO, password=mypasswd, hostname=hostname, database=database
)
# %sql $connection_str
# Out:
# 'Connected: may96c@dsa_student'

# %%
# %%sql
# select table_schema,
#        table_name,
#        (xpath('/row/cnt/text()', xml_count))[1]::text::int as row_count
# from (
#   select table_name, table_schema,
#          query_to_xml(format('select count(*) as cnt from %I.%I', table_schema, table_name), false, true, '') as xml_count
#   from information_schema.tables
#   where table_schema = 'may96c' AND table_name = 'location_block' OR table_name = 'crime_record' OR table_name = 'crime_code' OR table_name = 'location_area' OR table_name = 'location_description' OR table_name = 'location_coordinate' OR table_name = 'crime_location'
# ) t order by 3 DESC
# Out:
#  * postgres://may96c:***@pgsql.dsa.lan/dsa_student
# 7 rows affected.
# [('may96c', 'crime_record', 334715),
#  ('may96c', 'crime_location', 243427),
#  ('may96c', 'location_coordinate', 162286),
#  ('may96c', 'location_block', 28340),
#  ('may96c', 'location_area', 1023),
#  ('may96c', 'crime_code', 319),
#  ('may96c', 'location_description', 98)]

# %% [markdown]
# ## 2.5 Develop five distinct and useful queries that could be potentially used for policing planning, policy making, citizen awareness, etc.
#
# * Queries should provide some analytic values and use your SQL skillset beyond simple SELECT-FROM-WHERE using multiple tables. I expect to see GROUP BY/HAVING, Nested Queries, Aggregation Operators, etc.
# * Each query should have documentation to explain what this query is looking for and why it is meaningful for what purposes.
#
# ### Best final projects will be given to three students (two online and one on campus) who will join me for beers at Flat Branch (local brewery in Columbia, Missouri) during the Executive Week in March 2022 (if pandemic situation is OK) or 2023 (I seriously think it should be OK by then).
#
# * five pairs of cells are expected. Your output presentations have to be self explainable. (hint: use AS)

# %% [markdown]
# # What is the query trying to achieve - use natural language
# This query returns the average, minimum, and maximum arrests made on cannabis related charges per district in the year of 2012. This data could be taken into consideration when considering cannabis decriminalization in chicago.

# %%
# %%sql
#
# SELECT AVG(amount_of_cannabis_related_arrests) as avg_cannabis_arrests_per_district_2012, MIN(amount_of_cannabis_related_arrests) as min_cannabis_arrests_per_district_2012, MAX(amount_of_cannabis_related_arrests) as max_cannabis_arrests_per_district_2012
#     FROM (
#         SELECT COUNT(*) as amount_of_cannabis_related_arrests, district
#         FROM crime_record cr JOIN crime_location cl ON cr.cl_id = cl.cl_id JOIN location_area la ON cl.la_id = la.la_id JOIN crime_code cc ON cc.fbi_code = cr.fbi_code AND cc.iucr = cr.iucr
#         WHERE description LIKE '%CANNABIS%' AND arrest = 'true'
#         GROUP BY district, year
#         HAVING year = 2012) as cannabis_district_info
# Out:
#  * postgres://may96c:***@pgsql.dsa.lan/dsa_student
# 1 rows affected.
# [(Decimal('902.5000000000000000'), 334, 1580)]

# %% [markdown]
# # What is the query trying to achieve - use natural language
# This query finds the most prominent crime type in chicago, based on primary_type description, and then determines how many instances of this type of crime(theft) has occured at each location description. With this information, to minimize the number one type of crime chicago experiences, cops could make an effor to be present at location types that are higher on the list (implying more theft occurs at these types of spots)

# %%
# %%sql
# SELECT location_description as location_type, count(*) amount_of_most_prominent_crime_type_that_occurs_at_this_location, primary_type as most_prominent_crime
# FROM crime_code cc JOIN crime_record cr ON cc.fbi_code = cr.fbi_code AND cc.iucr = cr.iucr JOIN crime_location cl ON cr.cl_id = cl.cl_id JOIN location_description ld ON cl.ld_id = ld.ld_id
# WHERE primary_type IN ( SELECT primary_type FROM (
# SELECT count(*), primary_type
# FROM crime_code cc JOIN crime_record cr ON cc.fbi_code = cr.fbi_code AND cc.iucr = cr.iucr
# GROUP BY primary_type
# ORDER BY count(*) desc
# LIMIT 1  ) as cool )
# group by location_description, primary_type
# ORDER BY COUNT(*) DESC
# Out:
#  * postgres://may96c:***@pgsql.dsa.lan/dsa_student
# 97 rows affected.
# [('STREET', 16449, 'THEFT'),
#  ('RESIDENCE', 11287, 'THEFT'),
#  ('SIDEWALK', 7510, 'THEFT'),
#  ('APARTMENT', 7401, 'THEFT'),
#  ('OTHER', 3150, 'THEFT'),
#  ('DEPARTMENT STORE', 2755, 'THEFT'),
#  ('PARKING LOT/GARAGE(NON.RESID.)', 2458, 'THEFT'),
#  ('SMALL RETAIL STORE', 2079, 'THEFT'),
#  ('RESIDENTIAL YARD (FRONT/BACK)', 1987, 'THEFT'),
#  ('GROCERY FOOD STORE', 1900, 'THEFT'),
#  ('ALLEY', 1683, 'THEFT'),
#  ('VEHICLE NON-COMMERCIAL', 1401, 'THEFT'),
#  ('RESIDENCE-GARAGE', 1384, 'THEFT'),
#  ('SCHOOL, PUBLIC, BUILDING', 1320, 'THEFT'),
#  ('RESIDENCE PORCH/HALLWAY', 1310, 'THEFT'),
#  ('RESTAURANT', 1238, 'THEFT'),
#  ('BAR OR TAVERN', 615, 'THEFT'),
#  ('CTA TRAIN', 608, 'THEFT'),
#  ('GAS STATION', 564, 'THEFT'),
#  ('PARK PROPERTY', 516, 'THEFT'),
#  ('COMMERCIAL / BUSINESS OFFICE', 506, 'THEFT'),
#  ('DRUG STORE', 459, 'THEFT'),
#  ('ATHLETIC CLUB', 416, 'THEFT'),
#  ('CTA BUS', 405, 'THEFT'),
#  ('VACANT LOT/LAND', 392, 'THEFT'),
#  ('HOTEL/MOTEL', 364, 'THEFT'),
#  ('CTA PLATFORM', 311, 'THEFT'),
#  ('CONVENIENCE STORE', 273, 'THEFT'),
#  ('BANK', 257, 'THEFT'),
#  ('SCHOOL, PUBLIC, GROUNDS', 254, 'THEFT'),
#  ('ABANDONED BUILDING', 233, 'THEFT'),
#  ('HOSPITAL BUILDING/GROUNDS', 227, 'THEFT'),
#  ('CHURCH/SYNAGOGUE/PLACE OF WORSHIP', 200, 'THEFT'),
#  ('CTA BUS STOP', 192, 'THEFT'),
#  ('CHA APARTMENT', 188, 'THEFT'),
#  ('DRIVEWAY - RESIDENTIAL', 187, 'THEFT'),
#  ('CHA PARKING LOT/GROUNDS', 183, 'THEFT'),
#  ('TAVERN/LIQUOR STORE', 167, 'THEFT'),
#  ('SCHOOL, PRIVATE, BUILDING', 162, 'THEFT'),
#  ('CTA GARAGE / OTHER PROPERTY', 155, 'THEFT'),
#  ('ATM (AUTOMATIC TELLER MACHINE)', 126, 'THEFT'),
#  ('GOVERNMENT BUILDING/PROPERTY', 124, 'THEFT'),
#  ('CONSTRUCTION SITE', 106, 'THEFT'),
#  ('WAREHOUSE', 104, 'THEFT'),
#  ('TAXICAB', 103, 'THEFT'),
#  (None, 102, 'THEFT'),
#  ('MEDICAL/DENTAL OFFICE', 100, 'THEFT'),
#  ('VEHICLE-COMMERCIAL', 93, 'THEFT'),
#  ('NURSING HOME/RETIREMENT HOME', 90, 'THEFT'),
#  ('COLLEGE/UNIVERSITY GROUNDS', 86, 'THEFT'),
#  ('AIRPORT TERMINAL UPPER LEVEL - SECURE AREA', 78, 'THEFT'),
#  ('CURRENCY EXCHANGE', 77, 'THEFT'),
#  ('SPORTS ARENA/STADIUM', 76, 'THEFT'),
#  ('BARBERSHOP', 70, 'THEFT'),
#  ('LIBRARY', 70, 'THEFT'),
#  ('SCHOOL, PRIVATE, GROUNDS', 64, 'THEFT'),
#  ('OTHER RAILROAD PROP / TRAIN DEPOT', 63, 'THEFT'),
#  ('FACTORY/MANUFACTURING BUILDING', 56, 'THEFT'),
#  ('POLICE FACILITY/VEH PARKING LOT', 43, 'THEFT'),
#  ('AIRPORT TERMINAL LOWER LEVEL - NON-SECURE AREA', 42, 'THEFT'),
#  ('AIRPORT BUILDING NON-TERMINAL - NON-SECURE AREA', 36, 'THEFT'),
#  ('AIRPORT EXTERIOR - NON-SECURE AREA', 35, 'THEFT'),
#  ('CHA HALLWAY/STAIRWELL/ELEVATOR', 34, 'THEFT'),
#  ('AIRPORT TERMINAL LOWER LEVEL - SECURE AREA', 34, 'THEFT'),
#  ('CAR WASH', 31, 'THEFT'),
#  ('AIRPORT BUILDING NON-TERMINAL - SECURE AREA', 31, 'THEFT'),
#  ('MOVIE HOUSE/THEATER', 27, 'THEFT'),
#  ('DAY CARE CENTER', 26, 'THEFT'),
#  ('POOL ROOM', 26, 'THEFT'),
#  ('AIRPORT TERMINAL UPPER LEVEL - NON-SECURE AREA', 25, 'THEFT'),
#  ('APPLIANCE STORE', 24, 'THEFT'),
#  ('OTHER COMMERCIAL TRANSPORTATION', 24, 'THEFT'),
#  ('COLLEGE/UNIVERSITY RESIDENCE HALL', 23, 'THEFT'),
#  ('CLEANING STORE', 21, 'THEFT'),
#  ('AIRCRAFT', 20, 'THEFT'),
#  ('FIRE STATION', 20, 'THEFT'),
#  ('HIGHWAY/EXPRESSWAY', 18, 'THEFT'),
#  ('AIRPORT/AIRCRAFT', 18, 'THEFT'),
#  ('LAKEFRONT/WATERFRONT/RIVERBANK', 16, 'THEFT'),
#  ('ANIMAL HOSPITAL', 14, 'THEFT'),
#  ('AIRPORT PARKING LOT', 13, 'THEFT'),
#  ('JAIL / LOCK-UP FACILITY', 11, 'THEFT'),
#  ('BOWLING ALLEY', 10, 'THEFT'),
#  ('AIRPORT VENDING ESTABLISHMENT', 10, 'THEFT'),
#  ('CREDIT UNION', 9, 'THEFT'),
#  ('COIN OPERATED MACHINE', 7, 'THEFT'),
#  ('BOAT/WATERCRAFT', 7, 'THEFT'),
#  ('PAWN SHOP', 7, 'THEFT'),
#  ('DELIVERY TRUCK', 7, 'THEFT'),
#  ('FOREST PRESERVE', 7, 'THEFT'),
#  ('FEDERAL BUILDING', 6, 'THEFT'),
#  ('AIRPORT EXTERIOR - SECURE AREA', 5, 'THEFT'),
#  ('CEMETARY', 5, 'THEFT'),
#  ('BRIDGE', 5, 'THEFT'),
#  ('AIRPORT TRANSPORTATION SYSTEM (ATS)', 3, 'THEFT'),
#  ('AIRPORT TERMINAL MEZZANINE - NON-SECURE AREA', 3, 'THEFT'),
#  ('SAVINGS AND LOAN', 1, 'THEFT')]

# %% [markdown]
# # What is the query trying to achieve - use natural language
# In the two cells below, I identified quartiles based on the amount of narcotic crimes according to location area, I used this so I could pull location areas that have an amount of narcotic crimes that is above the median per location_area. Essentially, I identified trouble areas in terms of narcotics. I then identified the count of manufacturing and delivering crimes based on blocks within these troubled location areas. This is so the police force can see trends in these trobuled areas and potentially work to hault the delivery/manufacturing of harmful substances

# %%
# %%sql
# SELECT percentile_cont(.25) WITHIN GROUP (ORDER BY narcotic_count),
#         percentile_cont(.5) WITHIN GROUP (ORDER BY narcotic_count),
#         percentile_cont(.75) WITHIN GROUP (ORDER BY narcotic_count),
#         percentile_cont(1) WITHIN GROUP (ORDER BY narcotic_count)
#         FROM ( SELECT count(*) as narcotic_count, cl.la_id
#                 FROM crime_code cc JOIN crime_record cr ON cc.fbi_code = cr.fbi_code AND cc.iucr = cr.iucr JOIN crime_location cl ON cr.cl_id = cl.cl_id JOIN location_block lb ON cl.lb_id = lb.lb_id
#                 WHERE primary_type = 'NARCOTICS'
#                   GROUP BY cl.la_id ) narc_count ;
# Out:
#  * postgres://may96c:***@pgsql.dsa.lan/dsa_student
# 1 rows affected.
# [(6.0, 24.0, 57.0, 427.0)]

# %%
# %%sql
# SELECT COUNT(*) as number_of_manufacturing_or_delivering_crimes, lb.lb_id as block_id, block, la_id as location_area_with_above_median_narcotic_crimes
# FROM crime_code cc JOIN crime_record cr ON cc.fbi_code = cr.fbi_code AND cc.iucr = cr.iucr JOIN crime_location cl ON cr.cl_id = cl.cl_id JOIN location_block lb ON cl.lb_id = lb.lb_id
# WHERE description LIKE '%MANU/DELIVER%' AND la_id IN (
#     SELECT la_id
#     FROM
#        (SELECT count(*) as narcotic_count, la_id
#         FROM crime_code cc JOIN crime_record cr ON cc.fbi_code = cr.fbi_code AND cc.iucr = cr.iucr JOIN crime_location cl ON cr.cl_id = cl.cl_id JOIN location_block lb ON cl.lb_id = lb.lb_id
#         WHERE primary_type = 'NARCOTICS'
#         GROUP BY la_id
#         HAVING count(*) > 24 ) as narc_count_filter )
# GROUP BY lb.lb_id, block, la_id
# ORDER BY count(*) DESC
# Out:
#  * postgres://may96c:***@pgsql.dsa.lan/dsa_student
# 1591 rows affected.
# [(9, 2734, '009XX N ST LOUIS AVE', 114),
#  (8, 3770, '013XX S CHRISTIANA AVE', 10),
#  (8, 2072, '039XX W ROOSEVELT RD', 156),
#  (7, 9872, '041XX W WEST END AVE', 85),
#  (7, 1487, '048XX W SUPERIOR ST', 405),
#  (6, 2412, '010XX N SPRINGFIELD AVE', 15),
#  (5, 11859, '028XX N LAKE SHORE DR', 188),
#  (5, 5883, '048XX W GLADYS AVE', 227),
#  (5, 2316, '034XX W OHIO ST', 114),
#  (5, 7509, '037XX W GRENSHAW ST', 408),
#  (5, 3404, '057XX S CARPENTER ST', 124),
#  (4, 9757, '020XX W NORTH AVE', 266),
#  (4, 389, '055XX W CORCORAN PL', 249),
#  (4, 1186, '039XX W JACKSON BLVD', 424),
#  (4, 192, '054XX W CHICAGO AVE', 111),
#  (4, 5944, '049XX W WALTON ST', 207),
#  (2, 27638, '032XX S SEELEY AVE', 39),
#  (2, 715, '064XX S DAMEN AVE', 244),
#  (2, 6438, '060XX S CHAMPLAIN AVE', 217),
#  (2, 5011, '034XX W BELMONT AVE', 529),
#  (2, 9044, '004XX N STATE ST', 11),
#  (2, 5771, '075XX S LANGLEY AVE', 196),
#  (2, 5546, '009XX W 71ST ST', 71),
#  (2, 420, '038XX S PARNELL AVE', 215),
#  (2, 1792, '009XX N CENTRAL PARK AVE', 15),
#  (2, 3007, '034XX W FLOURNOY ST', 74),
#  (2, 2779, '009XX N LAVERGNE AVE', 207),
#  (2, 2055, '080XX S MARSHFIELD AVE', 449),
#  (2, 12904, '053XX S MARSHFIELD AVE', 105),
#  (2, 5738, '005XX N SAWYER AVE', 114),
#  (2, 5509, '064XX S PEORIA ST', 520),
#  (2, 10661, '007XX N DRAKE AVE', 114),
#  (2, 4250, '068XX S WESTERN AVE', 478),
#  (2, 3610, '040XX W WEST END AVE', 85),
#  (2, 984, '004XX S PULASKI RD', 262),
#  (2, 2666, '060XX S COTTAGE GROVE AVE', 217),
#  (2, 4429, '123XX S HALSTED ST', 106),
#  (1, 9474, '066XX N DAMEN AVE', 32),
#  (1, 5275, '054XX S MARSHFIELD AVE', 105),
#  (1, 4129, '016XX N ORCHARD ST', 303),
#  (1, 7559, '028XX W MADISON ST', 482),
#  (1, 24541, '097XX S NORMAL AVE', 152),
#  (1, 13063, '062XX N KENMORE AVE', 260),
#  (1, 2483, '005XX W LOCUST ST', 273),
#  (1, 15988, '048XX W PATTERSON AVE', 233),
#  (1, 20695, '044XX W SCHOOL ST', 455),
#  (1, 4091, '088XX S COMMERCIAL AVE', 23),
#  (1, 20239, '024XX S SACRAMENTO AVE', 437),
#  (1, 696, '075XX N PAULINA ST', 271),
#  (1, 25073, '017XX W POLK ST', 137),
#  (1, 1776, '052XX W LAKE ST', 249),
#  (1, 11446, '028XX E 80TH ST', 102),
#  (1, 8233, '026XX W WARREN BLVD', 482),
#  (1, 8042, '103XX S EBERHART AVE', 293),
#  (1, 8718, '001XX N KEDZIE AVE', 466),
#  (1, 13023, '060XX W BELMONT AVE', 403),
#  (1, 7428, '021XX W DEVON AVE', 313),
#  (1, 4495, '015XX E 67TH PL', 199),
#  (1, 3930, '059XX S CARPENTER ST', 124),
#  (1, 1151, '013XX N HUDSON AVE', 491),
#  (1, 4355, '020XX N WESTERN AVE', 432),
#  (1, 7145, '026XX W 63RD ST', 2),
#  (1, 5940, '0000X S HAMLIN BLVD', 538),
#  (1, 12195, '034XX W CERMAK RD', 256),
#  (1, 8586, '058XX S WESTERN AVE', 76),
#  (1, 12410, '035XX N HARLEM AVE', 566),
#  (1, 17033, '009XX E 50TH ST', 535),
#  (1, 2729, '118XX S MICHIGAN AVE', 363),
#  (1, 22086, '022XX W WASHBURNE AVE', 137),
#  (1, 12099, '0000X N KARLOV AVE', 324),
#  (1, 18077, '013XX W CULLERTON ST', 304),
#  (1, 2401, '048XX W WASHINGTON BLVD', 175),
#  (1, 15362, '032XX N RACINE AVE', 109),
#  (1, 4657, '015XX S RIDGEWAY AVE', 81),
#  (1, 22908, '051XX W CULLOM AVE', 228),
#  (1, 4516, '008XX E 44TH ST', 846),
#  (1, 2875, '042XX S MICHIGAN AVE', 366),
#  (1, 4335, '031XX S PULASKI RD', 67),
#  (1, 622, '011XX N LAWNDALE AVE', 15),
#  (1, 16502, '003XX W 102ND PL', 139),
#  (1, 26579, '013XX S MUSEUM CAMPUS DR', 210),
#  (1, 23397, '088XX S HALSTED ST', 357),
#  (1, 1228, '023XX E 79TH ST', 667),
#  (1, 7020, '080XX S RACINE AVE', 198),
#  (1, 9275, '0000X E 69TH ST', 502),
#  (1, 4240, '060XX N RIDGE AVE', 598),
#  (1, 2010, '044XX S DREXEL BLVD', 846),
#  (1, 14326, '016XX W WALTON ST', 445),
#  (1, 3659, '007XX N DEARBORN ST', 251),
#  (1, 3386, '004XX N AVERS AVE', 53),
#  (1, 2524, '013XX N HOMAN AVE', 307),
#  (1, 17139, '021XX W CULLERTON ST', 141),
#  (1, 17295, '030XX W FULLERTON AVE', 4),
#  (1, 982, '051XX W MADISON ST', 453),
#  (1, 1013, '084XX S MORGAN ST', 28),
#  (1, 4756, '114XX S CHURCH ST', 108),
#  (1, 9757, '020XX W NORTH AVE', 193),
#  (1, 15969, '076XX S MARYLAND AVE', 196),
#  (1, 13942, '075XX S RIDGELAND AVE', 8),
#  (1, 8787, '044XX W ADAMS ST', 20),
#  (1, 1022, '033XX N PULASKI RD', 194),
#  (1, 7175, '030XX W 26TH ST', 437),
#  (1, 7906, '062XX S WOLCOTT AVE', 416),
#  (1, 12061, '095XX S HARVARD AVE', 600),
#  (1, 18393, '014XX S LAFLIN ST', 51),
#  (1, 18184, '006XX E 62ND ST', 217),
#  (1, 10952, '005XX W 43RD ST', 676),
#  (1, 2879, '079XX S PRINCETON AVE', 121),
#  (1, 8035, '053XX N SHERIDAN RD', 84),
#  (1, 11948, '075XX S PARNELL AVE', 518),
#  (1, 9633, '002XX S LAVERGNE AVE', 453),
#  (1, 3054, '070XX N MC ALPIN AVE', 496),
#  (1, 7553, '033XX W OGDEN AVE', 256),
#  (1, 22384, '053XX S CHRISTIANA AVE', 54),
#  (1, 9921, '074XX S JEFFERY BLVD', 234),
#  (1, 10411, '068XX S ADA ST', 314),
#  (1, 14957, '022XX S ALBANY AVE', 650),
#  (1, 11650, '068XX S MAY ST', 13),
#  (1, 8546, '067XX S MERRILL AVE', 396),
#  (1, 7369, '006XX N RIDGEWAY AVE', 53),
#  (1, 11508, '032XX W WASHINGTON BLVD', 243),
#  (1, 9284, '081XX S LA SALLE ST', 129),
#  (1, 5706, '001XX W 109TH ST', 61),
#  (1, 843, '036XX W DOUGLAS BLVD', 98),
#  (1, 3697, '004XX S CLINTON ST', 147),
#  (1, 7531, '042XX W GLADYS AVE', 424),
#  (1, 9684, '032XX N KEATING AVE', 282),
#  (1, 16403, '043XX W 26TH ST', 67),
#  (1, 4093, '033XX W WARREN BLVD', 243),
#  (1, 11543, '007XX N LEAMINGTON AVE', 405),
#  (1, 5722, '068XX S ROCKWELL ST', 18),
#  (1, 8594, '049XX N WHIPPLE ST', 379),
#  (1, 6280, '033XX N TROY ST', 80),
#  (1, 6379, '038XX S ELLIS AVE', 739),
#  (1, 16541, '064XX S LOOMIS BLVD', 314),
#  (1, 20643, '002XX N KOSTNER AVE', 85),
#  (1, 17580, '013XX E 90TH ST', 554),
#  (1, 15173, '028XX E 84TH ST', 48),
#  (1, 25437, '022XX E 78TH ST', 667),
#  (1, 20174, '034XX N HOYNE AVE', 558),
#  (1, 3543, '056XX S MORGAN ST', 124),
#  (1, 168, '030XX S LOOMIS ST', 145),
#  (1, 10626, '057XX W FULLERTON AVE', 265),
#  (1, 633, '069XX S ASHLAND AVE', 421),
#  (1, 17447, '100XX S LA SALLE ST', 139),
#  (1, 3340, '063XX S MOZART ST', 36),
#  (1, 20743, '016XX W WASHINGTON BLVD', 158),
#  (1, 4300, '068XX S CARPENTER ST', 13),
#  (1, 10632, '015XX W HOLLYWOOD AVE', 528),
#  (1, 4855, '040XX W MAYPOLE AVE', 85),
#  (1, 4012, '063XX S TROY ST', 36),
#  (1, 27745, '031XX W 52ND ST', 386),
#  (1, 937, '005XX N MICHIGAN AVE', 11),
#  (1, 1056, '048XX N SHERIDAN RD', 666),
#  (1, 9590, '052XX S CHRISTIANA AVE', 54),
#  (1, 26743, '050XX N NEW ENGLAND AVE', 146),
#  (1, 12417, '029XX N AVERS AVE', 333),
#  (1, 3537, '012XX S SPAULDING AVE', 126),
#  (1, 9844, '061XX S VERNON AVE', 217),
#  (1, 8319, '021XX W CERMAK RD', 141),
#  (1, 3276, '0000X N LA SALLE ST', 325),
#  (1, 7528, '036XX W 61ST ST', 515),
#  (1, 5089, '087XX S WABASH AVE', 467),
#  (1, 9660, '028XX W ARTHINGTON ST', 442),
#  (1, 2399, '123XX S PERRY AVE', 248),
#  (1, 5357, '039XX W FLOURNOY ST', 262),
#  (1, 24394, '004XX N COLUMBUS DR', 11),
#  (1, 11234, '058XX S DAMEN AVE', 94),
#  (1, 7315, '082XX S SAGINAW AVE', 87),
#  (1, 7917, '0000X N LATROBE AVE', 63),
#  (1, 26756, '031XX N LUNA AVE', 162),
#  (1, 19032, '057XX S MEADE AVE', 486),
#  (1, 23053, '044XX N ARTESIAN AVE', 574),
#  (1, 9231, '091XX S CLYDE AVE', 284),
#  (1, 4789, '009XX W CUYLER AVE', 176),
#  (1, 10803, '045XX S MICHIGAN AVE', 770),
#  (1, 25730, '044XX W 76TH ST', 191),
#  (1, 9148, '007XX E 38TH ST', 739),
#  (1, 6821, '001XX W MAPLE ST', 31),
#  (1, 11235, '032XX W MONTROSE AVE', 99),
#  (1, 11750, '057XX N SHERIDAN RD', 320),
#  (1, 1988, '054XX W NORTH AVE', 205),
#  (1, 14468, '097XX S COMMERCIAL AVE', 130),
#  (1, 10004, '020XX S RACINE AVE', 304),
#  (1, 21654, '056XX W LE MOYNE ST', 42),
#  (1, 6912, '031XX W BERTEAU AVE', 99),
#  (1, 3830, '075XX S VERNON AVE', 196),
#  (1, 13416, '059XX S WESTERN AVE', 353),
#  (1, 2999, '007XX N RIDGEWAY AVE', 15),
#  (1, 26925, '020XX E 74TH ST', 234),
#  (1, 3124, '056XX W DIVERSEY AVE', 162),
#  (1, 14382, '036XX W AUGUSTA BLVD', 15),
#  (1, 11072, '028XX N SEMINARY AVE', 367),
#  (1, 12323, '016XX S RACINE AVE', 204),
#  (1, 18303, '071XX W DIVERSEY AVE', 159),
#  (1, 3453, '042XX W CERMAK RD', 79),
#  (1, 7370, '049XX W OHIO ST', 365),
#  (1, 25274, '016XX N CLEVELAND AVE', 303),
#  (1, 18426, '003XX W MONTROSE HARBOR DR', 176),
#  (1, 7597, '014XX W MARQUETTE RD', 274),
#  (1, 645, '002XX E PEARSON ST', 66),
#  (1, 21413, '028XX S HARDING AVE', 67),
#  (1, 4890, '028XX E 78TH ST', 104),
#  (1, 2878, '030XX W MARQUETTE RD', 18),
#  (1, 539, '035XX W BELDEN AVE', 230),
#  (1, 1456, '055XX W WASHINGTON BLVD', 14),
#  (1, 9646, '002XX W CERMAK RD', 781),
#  (1, 3734, '029XX W FULTON ST', 466),
#  (1, 805, '001XX S CALIFORNIA AVE', 321),
#  (1, 18915, '015XX W 82ND ST', 532),
#  (1, 6533, '045XX N CENTRAL PARK AVE', 318),
#  (1, 3188, '053XX S CALUMET AVE', 435),
#  (1, 16068, '040XX W MARQUETTE RD', 191),
#  (1, 3870, '102XX S OGLESBY AVE', 130),
#  (1, 4503, '072XX S PAXTON AVE', 234),
#  (1, 19680, '038XX N SEELEY AVE', 433),
#  (1, 2478, '011XX N WELLS ST', 273),
#  (1, 13666, '029XX W WALNUT ST', 482),
#  (1, 27385, '055XX S MC VICKER AVE', 486),
#  (1, 23311, '016XX N MC VICKER AVE', 178),
#  (1, 11686, '019XX W 17TH ST', 141),
#  (1, 2043, '0000X W 95TH ST', 319),
#  (1, 16849, '093XX S THROOP ST', 6),
#  (1, 15232, '014XX W 114TH PL', 65),
#  (1, 7342, '032XX N CLARK ST', 109),
#  (1, 7726, '055XX S WOOD ST', 94),
#  (1, 9546, '057XX W 59TH ST', 486),
#  (1, 14972, '042XX W CORTLAND ST', 272),
#  (1, 13206, '020XX N CICERO AVE', 390),
#  (1, 25261, '054XX S AVERS AVE', 246),
#  (1, 440, '003XX E ONTARIO ST', 11),
#  (1, 5660, '030XX N CLARK ST', 188),
#  (1, 24814, '065XX N CALDWELL AVE', 496),
#  (1, 14549, '045XX S ELLIS AVE', 846),
#  (1, 2378, '022XX W WASHINGTON BLVD', 148),
#  (1, 17933, '009XX W FULTON MARKET', 116),
#  (1, 16144, '066XX S KEDVALE AVE', 191),
#  (1, 634, '071XX S STONY ISLAND AVE', 97),
#  (1, 16310, '040XX N KEYSTONE AVE', 285),
#  (1, 6967, '037XX W POTOMAC AVE', 640),
#  (1, 13489, '064XX S FAIRFIELD AVE', 2),
#  (1, 2404, '006XX N CICERO AVE', 175),
#  (1, 4606, '055XX W CONGRESS PKWY', 14),
#  (1, 1406, '092XX S COMMERCIAL AVE', 48),
#  (1, 13006, '002XX S LOTUS AVE', 14),
#  (1, 15679, '028XX N MANGO AVE', 162),
#  (1, 3056, '002XX S LOCKWOOD AVE', 14),
#  (1, 95, '021XX N LATROBE AVE', 86),
#  (1, 4883, '029XX N LAWNDALE AVE', 333),
#  (1, 21571, '031XX W 51ST ST', 386),
#  (1, 17455, '042XX N BROADWAY', 176),
#  (1, 7120, '001XX N DEARBORN ST', 601),
#  (1, 1131, '082XX S DR MARTIN LUTHER KING JR DR', 487),
#  (1, 1726, '053XX S WESTERN AVE', 386),
#  (1, 17010, '042XX W THOMAS ST', 209),
#  (1, 8822, '069XX W ADDISON ST', 566),
#  (1, 6054, '005XX E 63RD ST', 217),
#  (1, 6559, '007XX W 124TH ST', 106),
#  (1, 7815, '096XX S WINSTON AVE', 577),
#  (1, 4781, '033XX W MAYPOLE AVE', 243),
#  (1, 5100, '090XX S PAXTON AVE', 284),
#  (1, 13937, '065XX S KOSTNER AVE', 191),
#  (1, 2209, '003XX E 43RD ST', 770),
#  (1, 17641, '028XX N WHIPPLE ST', 560),
#  (1, 12081, '110XX S WALLACE ST', 47),
#  (1, 722, '011XX N MONTICELLO AVE', 15),
#  (1, 15596, '051XX S WASHTENAW AVE', 386),
#  (1, 9067, '034XX W 23RD ST', 110),
#  (1, 10628, '103XX S KEDZIE AVE', 89),
#  (1, 9536, '054XX W JACKSON BLVD', 14),
#  (1, 20918, '0000X E 80TH ST', 239),
#  (1, 3712, '059XX N WINTHROP AVE', 320),
#  (1, 580, '038XX W ROOSEVELT RD', 408),
#  (1, 269, '052XX S WOLCOTT AVE', 105),
#  (1, 23032, '039XX N KOSTNER AVE', 291),
#  (1, 5240, '055XX S PRINCETON AVE', 267),
#  (1, 9122, '050XX S EVANS AVE', 536),
#  (1, 6486, '050XX W NORTH AVE', 60),
#  (1, 397, '045XX N SHERIDAN RD', 9),
#  (1, 3424, '008XX W GARFIELD BLVD', 649),
#  (1, 12796, '007XX W CHICAGO AVE', 232),
#  (1, 10434, '012XX N MASSASOIT AVE', 42),
#  (1, 3834, '015XX W 69TH ST', 274),
#  (1, 18525, '051XX W LAKE ST', 175),
#  (1, 11590, '062XX S CHAMPLAIN AVE', 217),
#  (1, 7633, '007XX W 59TH ST', 470),
#  (1, 12960, '026XX S PULASKI RD', 67),
#  (1, 3441, '012XX S KEDVALE AVE', 98),
#  (1, 9052, '043XX N NARRAGANSETT AVE', 46),
#  (1, 7775, '009XX W WEED ST', 299),
#  (1, 9738, '064XX W ARCHER AVE', 486),
#  (1, 6339, '0000X N DEARBORN ST', 336),
#  (1, 18101, '049XX N DAMEN AVE', 462),
#  (1, 9156, '013XX S WABASH AVE', 171),
#  (1, 9238, '066XX S BISHOP ST', 274),
#  (1, 5534, '082XX S CLYDE AVE', 157),
#  (1, 10973, '070XX S CLAREMONT AVE', 478),
#  (1, 3240, '007XX N CICERO AVE', 629),
#  (1, 10091, '005XX N WESTERN AVE', 348),
#  (1, 14375, '130XX S DREXEL AVE', 164),
#  (1, 3455, '038XX W 26TH ST', 67),
#  (1, 9834, '009XX E 45TH ST', 846),
#  (1, 5617, '074XX S YATES BLVD', 173),
#  (1, 5524, '016XX N SPAULDING AVE', 307),
#  (1, 9532, '034XX W LEXINGTON ST', 74),
#  (1, 20437, '096XX S PEORIA ST', 152),
#  (1, 3887, '013XX S KILDARE AVE', 98),
#  (1, 5084, '003XX N PULASKI RD', 85),
#  (1, 2621, '034XX W CHICAGO AVE', 114),
#  (1, 1107, '002XX W GARFIELD BLVD', 514),
#  (1, 8350, '045XX N ELSTON AVE', 380),
#  (1, 10761, '026XX S HOMAN AVE', 385),
#  (1, 7076, '013XX N CLAREMONT AVE', 193),
#  (1, 10196, '012XX N PARKSIDE AVE', 42),
#  (1, 4432, '026XX N FAIRFIELD AVE', 183),
#  (1, 16967, '050XX N MANGO AVE', 169),
#  (1, 3169, '026XX W EVERGREEN AVE', 420),
#  (1, 8355, '011XX N KEELER AVE', 209),
#  (1, 8043, '077XX S COLES AVE', 104),
#  (1, 16998, '038XX W ADAMS ST', 538),
#  (1, 9228, '062XX S EVANS AVE', 217),
#  (1, 7074, '014XX S CHRISTIANA AVE', 10),
#  (1, 11622, '008XX W BELDEN AVE', 115),
#  (1, 23193, '058XX S MOZART ST', 76),
#  (1, 3701, '056XX S ADA ST', 22),
#  (1, 10111, '082XX S SANGAMON ST', 28),
#  (1, 21371, '122XX S SANGAMON ST', 206),
#  (1, 930, '080XX S CHAPPEL AVE', 157),
#  (1, 19290, '003XX S KILPATRICK AVE', 258),
#  (1, 4332, '007XX N HARDING AVE', 15),
#  (1, 18656, '046XX S LEAMINGTON AVE', 308),
#  (1, 12274, '055XX S NAGLE AVE', 486),
#  (1, 20779, '030XX S EMERALD AVE', 56),
#  (1, 3232, '061XX S LAFLIN ST', 22),
#  (1, 17948, '061XX S WOOD ST', 416),
#  (1, 3247, '022XX W IOWA ST', 24),
#  (1, 22540, '042XX N ALBANY AVE', 99),
#  (1, 994, '060XX S PRAIRIE AVE', 459),
#  (1, 3174, '066XX S DREXEL AVE', 343),
#  (1, 3863, '068XX S INDIANA AVE', 312),
#  (1, 7943, '072XX S YATES BLVD', 173),
#  (1, 3503, '031XX N KEATING AVE', 92),
#  (1, 16480, '005XX W 60TH PL', 470),
#  (1, 1546, '050XX S ADA ST', 101),
#  (1, 5666, '020XX S PULASKI RD', 81),
#  (1, 786, '064XX S MAPLEWOOD AVE', 2),
#  (1, 18437, '116XX S HALE AVE', 108),
#  (1, 19678, '106XX S DREW ST', 389),
#  (1, 7896, '062XX N BROADWAY', 260),
#  (1, 2508, '009XX W CARMEN AVE', 451),
#  (1, 12048, '088XX S CARPENTER ST', 161),
#  (1, 496, '035XX W NORTH AVE', 307),
#  (1, 3841, '035XX W 57TH ST', 54),
#  (1, 19994, '003XX S KOSTNER AVE', 430),
#  (1, 22007, '031XX W TOUHY AVE', 166),
#  (1, 4645, '014XX W ESTES AVE', 90),
#  (1, 9591, '051XX S TROY ST', 386),
#  (1, 12374, '072XX N DAMEN AVE', 264),
#  (1, 1130, '077XX S PAULINA ST', 192),
#  (1, 502, '046XX S PRAIRIE AVE', 770),
#  (1, 554, '037XX W BELMONT AVE', 529),
#  (1, 897, '016XX N OAKLEY AVE', 238),
#  (1, 2896, '007XX E 90TH PL', 621),
#  (1, 20481, '032XX E 89TH ST', 691),
#  (1, 11300, '013XX E 57TH ST', 75),
#  (1, 1484, '043XX N KEDVALE AVE', 285),
#  (1, 1405, '001XX N CLARK ST', 601),
#  (1, 7482, '069XX S HARPER AVE', 199),
#  (1, 19, '073XX S SACRAMENTO AVE', 19),
#  (1, 4937, '008XX W NEWPORT AVE', 109),
#  (1, 5060, '020XX W MARQUETTE RD', 244),
#  (1, 22069, '024XX W BERWYN AVE', 212),
#  (1, 2563, '021XX S OAKLEY AVE', 141),
#  (1, 16034, '076XX S SANGAMON ST', 224),
#  (1, 2351, '067XX S BENNETT AVE', 199),
#  (1, 24600, '032XX S KEDZIE AVE', 385),
#  (1, 734, '048XX N CENTRAL AVE', 64),
#  (1, 13142, '045XX S ALBANY AVE', 469),
#  (1, 3646, '020XX W DEVON AVE', 32),
#  (1, 14161, '069XX S DANTE AVE', 199),
#  (1, 6656, '039XX W VAN BUREN ST', 262),
#  (1, 1537, '016XX N MAJOR AVE', 42),
#  (1, 4365, '057XX N ARTESIAN AVE', 534),
#  (1, 4212, '002XX E 43RD ST', 548),
#  (1, 7394, '078XX S EMERALD AVE', 224),
#  (1, 12471, '036XX W IRVING PARK RD', 237),
#  (1, 5185, '057XX W 63RD ST', 339),
#  (1, 3500, '039XX W CORNELIA AVE', 194),
#  (1, 8555, '031XX W 39TH PL', 93),
#  (1, 8945, '064XX S SEELEY AVE', 244),
#  (1, 357, '108XX S KEDZIE AVE', 89),
#  (1, 5161, '042XX W CONGRESS PKWY', 262),
#  (1, 18055, '058XX S NORMAL BLVD', 267),
#  (1, 9194, '001XX E 107TH ST', 293),
#  (1, 2949, '010XX W 103RD ST', 168),
#  (1, 17280, '078XX S CREGIER AVE', 8),
#  (1, 13150, '057XX W ROOSEVELT RD', 330),
#  (1, 2579, '020XX W AUGUSTA BLVD', 24),
#  (1, 8892, '064XX S WASHTENAW AVE', 2),
#  (1, 11537, '030XX W BELMONT AVE', 80),
#  (1, 3240, '007XX N CICERO AVE', 405),
#  (1, 3172, '011XX S MASON AVE', 330),
#  (1, 5121, '007XX W 117TH ST', 206),
#  (1, 2668, '081XX S ASHLAND AVE', 532),
#  (1, 24796, '021XX N CANNON DR', 377),
#  (1, 4989, '016XX S LAWNDALE AVE', 81),
#  (1, 19915, '022XX W OGDEN AVE', 648),
#  (1, 2689, '048XX S INDIANA AVE', 309),
#  (1, 325, '054XX W POTOMAC AVE', 205),
#  (1, 2788, '038XX W GRENSHAW ST', 408),
#  (1, 1044, '051XX W MAYPOLE AVE', 175),
#  (1, 7996, '001XX W DIVISION ST', 31),
#  (1, 11141, '066XX S INGLESIDE AVE', 343),
#  (1, 6628, '054XX N BROADWAY', 528),
#  (1, 12029, '121XX S HARVARD AVE', 106),
#  (1, 3370, '060XX S GREEN ST', 124),
#  (1, 2858, '039XX W MAYPOLE AVE', 538),
#  (1, 24889, '077XX W BALMORAL AVE', 146),
#  (1, 2204, '084XX S ESCANABA AVE', 48),
#  (1, 13870, '025XX S ALBANY AVE', 437),
#  (1, 18170, '049XX S DORCHESTER AVE', 68),
#  (1, 19710, '058XX W CORCORAN PL', 73),
#  (1, 9035, '079XX S HONORE ST', 96),
#  (1, 14596, '056XX S CAMPBELL AVE', 76),
#  (1, 5046, '015XX S TRUMBULL AVE', 10),
#  (1, 2184, '020XX W 71ST ST', 360),
#  (1, 4786, '057XX S MICHIGAN AVE', 766),
#  (1, 5159, '053XX W CHICAGO AVE', 111),
#  (1, 5068, '069XX S WESTERN AVE', 478),
#  (1, 14511, '029XX W 73RD ST', 19),
#  (1, 4692, '079XX S WABASH AVE', 239),
#  (1, 13492, '122XX S PARNELL AVE', 106),
#  (1, 6513, '073XX S WINCHESTER AVE', 360),
#  (1, 19529, '090XX S OGLESBY AVE', 284),
#  (1, 10767, '055XX S THROOP ST', 22),
#  (1, 6177, '003XX W 106TH ST', 107),
#  (1, 19805, '053XX S PRINCETON AVE', 514),
#  (1, 2393, '026XX S TRIPP AVE', 67),
#  (1, 6866, '074XX N ROGERS AVE', 271),
#  (1, 15022, '056XX S MAY ST', 124),
#  (1, 11626, '025XX W 83RD ST', 44),
#  (1, 17712, '004XX S DEARBORN ST', 798),
#  (1, 12016, '075XX S HERMITAGE AVE', 192),
#  (1, 1976, '062XX N CLARK ST', 598),
#  (1, 17171, '034XX W DIVISION ST', 359),
#  (1, 8410, '071XX S STATE ST', 184),
#  (1, 6265, '051XX S HYDE PARK BLVD', 704),
#  (1, 258, '054XX W AUGUSTA BLVD', 111),
#  (1, 7941, '026XX W ADAMS ST', 352),
#  (1, 10349, '002XX E 61ST ST', 459),
#  (1, 1156, '029XX N NATCHEZ AVE', 403),
#  (1, 24136, '008XX W UNIVERSITY LN', 322),
#  (1, 6095, '048XX W VAN BUREN ST', 227),
#  (1, 17878, '016XX N HAMLIN AVE', 640),
#  (1, 6811, '0000X N LAMON AVE', 453),
#  (1, 11409, '017XX W ROSCOE ST', 777),
#  (1, 16155, '022XX W BELDEN AVE', 432),
#  (1, 379, '073XX N SEELEY AVE', 264),
#  (1, 5321, '082XX S HOUSTON AVE', 691),
#  (1, 18824, '011XX W 31ST ST', 145),
#  (1, 10144, '077XX S NORMAL AVE', 518),
#  (1, 4031, '0000X E WASHINGTON ST', 601),
#  (1, 12463, '094XX S EWING AVE', 41),
#  (1, 11248, '0000X N HOMAN BLVD', 243),
#  (1, 2789, '068XX S DR MARTIN LUTHER KING JR DR', 312),
#  (1, 3468, '0000X E ROOSEVELT RD', 240),
#  (1, 25025, '019XX N RUTHERFORD AVE', 519),
#  (1, 10687, '027XX N MARSHFIELD AVE', 26),
#  (1, 3963, '023XX W 111TH ST', 108),
#  (1, 17796, '045XX N WESTERN AVE', 574),
#  (1, 6132, '089XX S LOWE AVE', 357),
#  (1, 7515, '044XX S KEDZIE AVE', 131),
#  (1, 776, '050XX W WABANSIA AVE', 60),
#  (1, 23108, '045XX W 87TH ST', 545),
#  (1, 4053, '046XX S SPAULDING AVE', 131),
#  (1, 3611, '018XX W 63RD ST', 244),
#  (1, 880, '111XX S MICHIGAN AVE', 91),
#  (1, 6304, '006XX S CENTRAL AVE', 330),
#  (1, 27018, '107XX S DRAKE AVE', 89),
#  (1, 8512, '058XX N LINCOLN AVE', 534),
#  (1, 1869, '113XX S STATE ST', 504),
#  (1, 18495, '034XX N PAULINA ST', 777),
#  (1, 20912, '080XX S KOMENSKY AVE', 127),
#  (1, 16661, '050XX S MAY ST', 101),
#  (1, 3065, '029XX N HALSTED ST', 188),
#  (1, 21075, '004XX S LEAVITT ST', 138),
#  (1, 1038, '019XX W DIVISION ST', 193),
#  (1, 24985, '052XX S MAYFIELD AVE', 486),
#  (1, 14836, '039XX W 21ST ST', 81),
#  (1, 14982, '036XX W FIFTH AVE', 641),
#  (1, 26822, '112XX S SACRAMENTO AVE', 89),
#  (1, 385, '013XX W HURON ST', 118),
#  (1, 7207, '069XX S MERRILL AVE', 396),
#  (1, 10195, '065XX S CLAREMONT AVE', 624),
#  (1, 13060, '055XX S NARRAGANSETT AVE', 486),
#  (1, 6284, '008XX N ST LOUIS AVE', 114),
#  (1, 17727, '045XX W 16TH ST', 79),
#  (1, 14812, '016XX N MOBILE AVE', 178),
#  (1, 5967, '012XX W MONTROSE AVE', 176),
#  (1, 2965, '012XX N WELLS ST', 59),
#  (1, 15909, '056XX S ST LOUIS AVE', 54),
#  (1, 4186, '027XX S LAWNDALE AVE', 385),
#  (1, 8873, '038XX N WESTERN AVE', 433),
#  (1, 3063, '043XX S INDIANA AVE', 310),
#  (1, 4282, '012XX W LELAND AVE', 358),
#  (1, 8516, '020XX N WHIPPLE ST', 4),
#  (1, 12164, '043XX N LINCOLN AVE', 58),
#  (1, 3125, '035XX W MC LEAN AVE', 230),
#  (1, 23708, '056XX S PEORIA ST', 124),
#  (1, 1772, '054XX W FULLERTON AVE', 86),
#  (1, 8263, '024XX N KOSTNER AVE', 531),
#  (1, 20992, '064XX S KNOX AVE', 220),
#  (1, 8633, '048XX W OHIO ST', 175),
#  (1, 12355, '017XX E 71ST ST', 199),
#  (1, 17802, '035XX W 16TH ST', 10),
#  (1, 15832, '062XX W KENNEDY EXPY IB', 169),
#  (1, 1071, '001XX W 87TH ST', 129),
#  (1, 9450, '006XX N AVERS AVE', 53),
#  (1, 26336, '072XX S LAFLIN ST', 421),
#  (1, 1644, '049XX W JACKSON BLVD', 453),
#  (1, 12605, '057XX W OHIO ST', 73),
#  (1, 4465, '005XX W 36TH ST', 215),
#  (1, 7088, '065XX S ASHLAND AVE', 62),
#  (1, 12246, '040XX N SHERIDAN RD', 176),
#  (1, 2415, '038XX W 63RD ST', 515),
#  (1, 27307, '020XX S ALBANY AVE', 126),
#  (1, 16456, '026XX W IOWA ST', 413),
#  (1, 18488, '053XX S AUSTIN AVE', 486),
#  (1, 3080, '070XX S ARTESIAN AVE', 624),
#  (1, 4632, '072XX S MARSHFIELD AVE', 360),
#  (1, 4710, '058XX S ABERDEEN ST', 124),
#  (1, 10104, '036XX W LEXINGTON ST', 74),
#  (1, 4577, '019XX W GARFIELD BLVD', 105),
#  (1, 18919, '027XX E 130TH ST', 112),
#  (1, 7579, '004XX E 48TH ST', 565),
#  (1, 1635, '071XX S CONSTANCE AVE', 97),
#  (1, 11095, '104XX S NORMAL AVE', 47),
#  (1, 423, '047XX W SCHOOL ST', 282),
#  (1, 15747, '032XX W OHIO ST', 114),
#  (1, 15964, '012XX W NORTH SHORE AVE', 128),
#  (1, 4249, '046XX S DAMEN AVE', 888),
#  (1, 21091, '033XX W 16TH ST', 10),
#  (1, 13588, '009XX N RIDGEWAY AVE', 15),
#  (1, 1129, '027XX W DIVISION ST', 420),
#  (1, 3989, '058XX S MICHIGAN AVE', 766),
#  (1, 18907, '012XX S HALSTED ST', 322),
#  (1, 2840, '010XX W 16TH ST', 322),
#  (1, 9775, '072XX S WOLCOTT AVE', 360),
#  ...]

# %% [markdown]
# # What is the query trying to achieve - use natural language
# This location gives counts of domestic crimes per locations which have been noted as a residence or apartment, this could be used to identify hot spots for domestic abuse, and could be used to provide educational material regarding domestic altercations to the household in question

# %%
# %%sql
# SELECT count(*) as number_of_domestic_crimes, lc.lc_id as location_id, location
# FROM crime_record cr JOIN crime_location cl ON cr.cl_id = cl.cl_id JOIN location_coordinate lc ON cl.lc_id = lc.lc_id JOIN location_description ld ON cl.ld_id = ld.ld_id
# WHERE domestic =  'true' AND location_description = 'RESIDENCE' OR location_description = 'APARTMENT' AND lc.lc_id !=0
# GROUP BY lc.lc_id, location
# ORDER BY count(*) DESC
# LIMIT 100
# Out:
#  * postgres://may96c:***@pgsql.dsa.lan/dsa_student
# 100 rows affected.
# [(69, 46580, '(41.762477718, -87.640020433)'),
#  (57, 51204, '(41.879267767, -87.763667741)'),
#  (55, 1605, '(41.777309867, -87.640802922)'),
#  (49, 0, None),
#  (40, 40384, '(41.912025769, -87.776529218)'),
#  (34, 6398, '(41.969078381, -87.65560801)'),
#  (34, 5652, '(41.908430535, -87.638509526)'),
#  (31, 2081, '(41.881088655, -87.720764494)'),
#  (31, 4231, '(41.705677782, -87.600944364)'),
#  (29, 40747, '(41.883339174, -87.697581932)'),
#  (28, 1150, '(41.907153315, -87.639680572)'),
#  (28, 16261, '(41.745808966, -87.547926023)'),
#  (26, 806, '(41.828762287, -87.614436164)'),
#  (26, 74957, '(41.981594396, -87.772002856)'),
#  (24, 44471, '(41.872561087, -87.723636388)'),
#  (24, 4571, '(41.759780594, -87.572455541)'),
#  (23, 2245, '(41.780946398, -87.621995369)'),
#  (23, 675, '(41.775429728, -87.640753492)'),
#  (22, 2800, '(41.751270583, -87.605938082)'),
#  (12, 28123, '(41.76916785, -87.566530745)'),
#  (12, 9335, '(41.751268534, -87.606048047)'),
#  (11, 3835, '(41.683938508, -87.721792427)'),
#  (11, 19507, '(41.756507401, -87.562686593)'),
#  (11, 9032, '(41.751214876, -87.571098146)'),
#  (11, 12155, '(41.697259038, -87.62205052)'),
#  (11, 31714, '(42.00711743, -87.670006581)'),
#  (11, 31829, '(41.74043773, -87.561193272)'),
#  (11, 29316, '(41.799596591, -87.6193466)'),
#  (11, 66339, '(41.874378587, -87.723788016)'),
#  (11, 53140, '(41.748600063, -87.658972758)'),
#  (11, 55918, '(41.959700021, -87.756286123)'),
#  (11, 7143, '(41.805139969, -87.621104286)'),
#  (11, 46076, '(41.884573898, -87.734825688)'),
#  (11, 10802, '(41.778646037, -87.671479104)'),
#  (11, 4018, '(41.732057875, -87.637427729)'),
#  (11, 9381, '(41.912929706, -87.701950642)'),
#  (11, 15692, '(41.761595148, -87.577114714)'),
#  (11, 39777, '(41.749584853, -87.670692969)'),
#  (10, 2082, '(41.777838294, -87.615566126)'),
#  (10, 38478, '(41.721016904, -87.627433285)'),
#  (10, 3870, '(42.019809042, -87.669491958)'),
#  (10, 5410, '(41.77029895, -87.628293582)'),
#  (10, 5179, '(41.807067906, -87.603843747)')]

# %% [markdown]
# # What is the query trying to achieve - use natural language
# lets say the city of chicago is considering hiring more officers, but aren't sure which district(s) to allocate the new help to. They could choose to do this based on the average crimes per day in the district

# %%
# %%sql
# SELECT AVG(count_per_day) as avg_crimes_per_day, district
#     FROM ( SELECT count(*) as count_per_day, district, date::date
#             FROM crime_record cr JOIN crime_location cl ON cr.cl_id = cl.cl_id JOIN location_area la ON cl.la_id = la.la_id
#             GROUP BY date::date, district ) as date_data
# GROUP BY district
# ORDER BY AVG(count_per_day) DESC
# Out:
#  * postgres://may96c:***@pgsql.dsa.lan/dsa_student
# 23 rows affected.
# [(Decimal('63.5382513661202186'), 8),
#  (Decimal('59.7377049180327869'), 11),
#  (Decimal('56.6775956284153005'), 25),
#  (Decimal('55.6229508196721311'), 7),
#  (Decimal('54.7049180327868852'), 4),
#  (Decimal('52.9672131147540984'), 6),
#  (Decimal('47.0573770491803279'), 3),
#  (Decimal('45.8633879781420765'), 9),
#  (Decimal('45.3770491803278689'), 12),
#  (Decimal('42.8715846994535519'), 5),
#  (Decimal('42.0956284153005464'), 19),
#  (Decimal('41.4836065573770492'), 10),
#  (Decimal('39.4617486338797814'), 15),
#  (Decimal('37.1912568306010929'), 18),
#  (Decimal('35.9071038251366120'), 14),
#  (Decimal('34.5792349726775956'), 2),
#  (Decimal('31.4644808743169399'), 16),
#  (Decimal('31.1010928961748634'), 22),
#  (Decimal('28.0928961748633880'), 17),
#  (Decimal('26.7295081967213115'), 24),
#  (Decimal('26.1693989071038251'), 1),
#  (Decimal('15.8005464480874317'), 20),
#  (Decimal('1.1111111111111111'), 31)]

# %% [markdown]
# ## End of Final Project

# %% [markdown]
# # Save your notebook, then `File > Close and Halt`
